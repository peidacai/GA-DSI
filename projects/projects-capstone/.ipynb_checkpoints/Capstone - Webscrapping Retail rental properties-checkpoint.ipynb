# %%
import re
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %% [markdown]
# ## Function to get entire listing

# %%
def get_listings(result):
    
    listings = []
    
    for d in result.findAll(class_ = "placard-details module"):

        listings.append(d)

    return listings

# %% [markdown]
# ## Combining all parameters of each property

# %%
58.176.46.248

proxies = {
    'http':'http://192.25.162.203'
    }
#, 'http://45.32.23.218', ,'http://168.63.20.19','http://168.63.24.174', 'http': 'http://142.0.128.218'
url = 'http://www.loopnet.com/for-lease/new-york-ny/retail/'

#results = []

r = requests.get(url, proxies=proxies)

page = r.content
soup = BeautifulSoup(page, 'lxml')

results = (get_listings(soup))

# %%
results
# Out:
# [<div class="placard-details module">\n<h5 class="listing-address">\n<a class="column-09" href="http://www.loopnet.com/Listing/19621797/134-West-37th-Street-New-York-NY/" ng-click="RedirectToProfile('http://www.loopnet.com/Listing/19621797/134-West-37th-Street-New-York-NY/'); $event.stopPropagation();" title="134 West 37th Street">\n<address itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">\n<span class="street-address" itemprop="streetAddress" title="134 West 37th Street">134 West 37th Street</span>\n<span itemprop="addressLocality" title="New York, NY">New York</span>,\r\n    <span itemprop="addressState" title="NY, NY">NY</span>\n<span itemprop="postalCode" title="10018">10018</span>\n</address>\n</a>\n<span class="listing-price column-04">$45-$79.20 SF/Year</span>\n</h5>\n<ul>\n<li>\n<span>Office Bldg</span>\n</li>\n<li>\n<i>2,500 - 10,000</i>\n<span>SF Available</span>\n</li>\n<li>\n<i>2</i>\n<span>Spaces</span>\n</li>\n<li>\n<i>120,000</i>\n<span>SF Bl
# ...

# %% [markdown]
# Every listing should include a list of :
#
# 1. listing webpage
# 2. street address, locality, state, postalcode
# 3. listing price
# 4. listing type (office building, restaurant, etc)
# 5. SF available
# 6. No. of spaces
# 7. SF building
# 8. property description

# %%
def get_listing_details(listing_placard):
    
    listing = []
    
    # listing website
    try:
        listing.append(re.findall('href="(.+)" ng-', str(listing_placard))[0])
        
         
    except:
        listing.append('')
    
    # listing streetaddress
    try:
        listing.append(re.findall('streetAddress" title="(.+)"', str(listing_placard))[0])
    except:
        listing.append('')
     
    # listing address locality
    try:
        listing.append(re.findall('addressLocality" title="(.+)"', str(listing_placard))[0])
    except:
        listing.append('')
    
    # listing state
    try:
        listing.append(re.findall('addressState" title="(.+),', str(listing_placard))[0])
    except:
        listing.append('')
    
    # listing postcode
    try:
        listing.append(re.findall('postalCode" title="(\d+)"', str(listing_placard))[0])
    except:
        listing.append('')
    
    # listing price
    try:
        listing.append(re.findall('listing-price.+>(.+)<', str(listing_placard))[0])
    except:
        listing.append('')
    
    # listing type
    try:
        listing.append(re.findall('h5>\n<ul>\n<li>\n<span>(.+)<', str(listing_placard))[0])
    except:
        listing.append('')
    
    # listing square feet available
    try:
        listing.append(re.findall('>(.+)</i>\n<span>SF Available', str(listing_placard))[0])
    except:
        listing.append('')

    # listing spaces available
    try:
        listing.append(re.findall('>(.+)</i>\n<span>Spaces', str(listing_placard))[0])
    except:
        listing.append('')
    
    # listing building square feet
    try:
        listing.append(re.findall('>(.+)</i>\n<span>SF Bldg', str(listing_placard))[0])
    except:
        listing.append('')
    
    #listing property description
    try:
        listing.append(re.findall('property-description">((.|\n|\r)*)<', str(listing_placard))[0])
    except:
        listing.append('')
    
    return listing

# %%
page_list = []
for i in results:
    page_list.append(get_listing_details(i))

# %%
col = ['Web_address', 'Street_address', 'Locality', 'State', 'Postcode', 'Price', 'Property_type', 'SF_avail', 'Spaces_avail', 'Bldg_SF', 'Prop_desc']

df = pd.DataFrame(page_list, columns= col)
df
# Out:
#                                           Web_address          Street_address  \
# 0   http://www.loopnet.com/Listing/19621797/134-We...    134 West 37th Street
# 1   http://www.loopnet.com/Listing/19852777/517-Co...     517 Columbus Avenue
# 2   http://www.loopnet.com/Listing/19584842/76-Woo...           76 Wooster St
# 3   http://www.loopnet.com/Listing/19632482/117-Ea...    117 East 15th Street
# 4   http://www.loopnet.com/Listing/19872387/250-Hu...           250 Hudson St
# 5   http://www.loopnet.com/Listing/19872550/485-Ma...         485 Madison Ave
# 6   http://www.loopnet.com/Listing/18803035/315-Ma...         315 Madison Ave
# 7   http://www.loopnet.com/Listing/19872441/315-Hu...           315 Hudson St
# 8   http://www.loopnet.com/Listing/20002133/261-Fi...           261 Fifth Ave
# 9   http://www.loopnet.com/Listing/19271844/100-Br...            100 Broad St
# 10  http://www.loopnet.com/Listing/19963876/143-Or...          143 Orchard St
# ...

# %%
len(page_list)
# Out:
# 20

# %%
url_template1 = "http://www.loopnet.com/for-lease/ny/retail/"
url_template2 = "/?view=list"

max_pages = 25

"""58.176.46.248
4.31.142.200
64.20.45.138"""

proxies = {
    'http':'http://4.31.142.200'
    }
    
for pg in range(2, max_pages+1, 1):

    url = url_template1 + str(pg) + url_template2

    r = requests.get(url, proxies=proxies)
    if str(r) == "<Response [200]>":

        page = r.content
        soup = BeautifulSoup(page, 'lxml')

        results.append(get_listings(soup))
        for i in results:
            page_list.append(get_listing_details(i))

    else:
        print "This url is not responding favorably."
        print "url =", url
        print "response =", r

# %%
col = ['Web_address', 'Street_address', 'Locality', 'State', \
       'Postcode', 'Price', 'Property_type', 'SF_avail', 'Spaces_avail', 'Bldg_SF', 'Prop_desc']

df = pd.DataFrame(page_list, columns= col)

# %%
df.shape
# Out:
# (1238, 11)

# %%
df.to_csv('listings.csv')

# %%
df
# Out:
#                                             Web_address  \
# 0     http://www.loopnet.com/Listing/19621797/134-We...
# 1     http://www.loopnet.com/Listing/19852777/517-Co...
# 2     http://www.loopnet.com/Listing/19584842/76-Woo...
# 3     http://www.loopnet.com/Listing/19632482/117-Ea...
# 4     http://www.loopnet.com/Listing/19872387/250-Hu...
# 5     http://www.loopnet.com/Listing/19872550/485-Ma...
# 6     http://www.loopnet.com/Listing/18803035/315-Ma...
# 7     http://www.loopnet.com/Listing/19872441/315-Hu...
# 8     http://www.loopnet.com/Listing/20002133/261-Fi...
# 9     http://www.loopnet.com/Listing/19271844/100-Br...
# 10    http://www.loopnet.com/Listing/19963876/143-Or...
# 11    http://www.loopnet.com/Listing/18922237/142-14...
# 12    http://www.loopnet.com/Listing/19814141/382-La...
# 13    http://www.loopnet.com/Listing/19857624/155-We...
# 14    http://www.loopnet.com/Listing/20056601/155-Ch...
# 15    http://www.loopnet.com/Listing/20056597/70-74-...
# ...

# %% [markdown]
# ### Editing address for geocoder

# %%
df['Full_street_address'] = df['Street_address'] + ', ' + df['State'] + ' ' + df['Postcode']
df.head()
# Out:
#                                          Web_address        Street_address  \
# 0  http://www.loopnet.com/Listing/19621797/134-We...  134 West 37th Street
# 1  http://www.loopnet.com/Listing/19852777/517-Co...   517 Columbus Avenue
# 2  http://www.loopnet.com/Listing/19584842/76-Woo...         76 Wooster St
# 3  http://www.loopnet.com/Listing/19632482/117-Ea...  117 East 15th Street
# 4  http://www.loopnet.com/Listing/19872387/250-Hu...         250 Hudson St
#
#        Locality State Postcode                 Price Property_type  \
# 0  New York, NY    NY    10018    $45-$79.20 SF/Year   Office Bldg
# 1  New York, NY    NY    10024       $204.60 SF/Year    Restaurant
# 2  New York, NY    NY    10012       $80-$84 SF/Year
# 3  New York, NY    NY    10003  $110.67-$120 SF/Year
# 4  New York, NY    NY    10013       $75-$90 SF/Year   Office Bldg
#
#          SF_avail Spaces_avail  Bldg_SF  \
# 0  2,500 - 10,000            2  120,000
# 1           2,346                 2,345
# ...

# %%
import geocoder
geocoder.google(df.loc[0, 'Full_street_address']).latlng[0]

#(37.3860517, -122.0838511)
# Out:
# 40.7523647

# %%
import numpy as np

lat = []
lon = []
for i in df['Full_street_address']:
    
    try:
        latlon = geocoder.google(i)
        lat.append(latlon.latlng[0])
        lon.append(latlon.latlng[1])
    
    except:
        lat.append(np.nan)
        lon.append(np.nan)
    
df['Latitude'] = lat
df['Longitude'] = lon
df.head()

# %%
df['Latitude'] = lat
df['Longitude'] = lon
df.head()
# Out:
#                                          Web_address        Street_address  \
# 0  http://www.loopnet.com/Listing/19621797/134-We...  134 West 37th Street
# 1  http://www.loopnet.com/Listing/19852777/517-Co...   517 Columbus Avenue
# 2  http://www.loopnet.com/Listing/19584842/76-Woo...         76 Wooster St
# 3  http://www.loopnet.com/Listing/19632482/117-Ea...  117 East 15th Street
# 4  http://www.loopnet.com/Listing/19872387/250-Hu...         250 Hudson St
#
#        Locality State Postcode                 Price Property_type  \
# 0  New York, NY    NY    10018    $45-$79.20 SF/Year   Office Bldg
# 1  New York, NY    NY    10024       $204.60 SF/Year    Restaurant
# 2  New York, NY    NY    10012       $80-$84 SF/Year
# 3  New York, NY    NY    10003  $110.67-$120 SF/Year
# 4  New York, NY    NY    10013       $75-$90 SF/Year   Office Bldg
#
#          SF_avail Spaces_avail  Bldg_SF  \
# 0  2,500 - 10,000            2  120,000
# 1           2,346                 2,345
# ...

# %%
df.loc[:, 'Price'] = df['Price'].apply(lambda x: np.nan if "Rate" in x else x)
df['Price']
# Out:
# 0         $45-$79.20 SF/Year
# 1            $204.60 SF/Year
# 2            $80-$84 SF/Year
# 3       $110.67-$120 SF/Year
# 4            $75-$90 SF/Year
# 5           $54-$550 SF/Year
# 6           $60-$355 SF/Year
# 7          $100-$175 SF/Year
# 8                        NaN
# 9                $94 SF/Year
# 10              $180 SF/Year
# 11               $85 SF/Year
# 12           $218.18 SF/Year
# 13                       NaN
# 14              $216 SF/Year
# 15            $58.50 SF/Year
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19           $187.20 SF/Year
# 20        $45-$79.20 SF/Year
# 21           $204.60 SF/Year
# 22           $80-$84 SF/Year
# 23      $110.67-$120 SF/Year
# 24           $75-$90 SF/Year
# 25          $54-$550 SF/Year
# 26          $60-$355 SF/Year
# 27         $100-$175 SF/Year
# 28                       NaN
# 29               $94 SF/Year
#                 ...
# 1208
# 1209
# 1210
# 1211
# 1212
# 1213
# ...

# %%
df1 = df.drop_duplicates()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 892
# Data columns (total 14 columns):
# Web_address            42 non-null object
# Street_address         42 non-null object
# Locality               42 non-null object
# State                  42 non-null object
# Postcode               42 non-null object
# Price                  33 non-null object
# Property_type          42 non-null object
# SF_avail               42 non-null object
# Spaces_avail           42 non-null object
# Bldg_SF                42 non-null object
# Prop_desc              42 non-null object
# Full_street_address    42 non-null object
# Latitude               20 non-null float64
# Longitude              20 non-null float64
# dtypes: float64(2), object(12)
# memory usage: 4.9+ KB

# %%
df['Price'].describe()
# Out:
# count     1098
# unique      17
# top
# freq       600
# Name: Price, dtype: object

# %% [markdown]
# ## Scraping from another website using Selenium and PhantomJS

# %%
from selenium import webdriver
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import time

# %%
pause = 5

driver = webdriver.PhantomJS(executable_path='/Users/peidacai/Downloads/phantomjs-2.1.1-macosx/bin/phantomjs')
dcap = dict(DesiredCapabilities.PHANTOMJS)
dcap['phantomjs.page.settings.userAgent'] = ("Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36")

driver = webdriver.PhantomJS(executable_path='/Users/peidacai/Downloads/phantomjs-2.1.1-macosx/bin/phantomjs', \
                             desired_capabilities = dcap, service_args = ['--ignore-ssl-errors=true'])

driver.implicitly_wait(20)
driver.set_window_size(1024, 768) 
driver.get('http://www.cityfeet.com/cont/ny/new-york-retail-space#')

lastHeight = driver.execute_script("return document.body.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(pause)
    newHeight = driver.execute_script("return document.body.scrollHeight")
    if newHeight == lastHeight:
        break
    lastHeight = newHeight

# %%
soup = BeautifulSoup(driver.page_source, "html.parser")

results = soup.find_all('div','property clearfix src-CF level-30')

cityfeet_results =[]
for d in results:
    cityfeet_results.append(d)

# %%
results = soup.find_all('div','property clearfix src-LN level-10')

for d in results:
    cityfeet_results.append(d)

# %%
len(cityfeet_results)
# Out:
# 257

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="cf js touch placeholder">
#  <head>
#   <style type="text/css">
#    .gm-style .gm-style-mtc label,.gm-style .gm-style-mtc div{font-weight:400}
#   </style>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700" rel="stylesheet" type="text/css">
#    <style type="text/css">
#     .gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px}
#    </style>
#    <style type="text/css">
#     @media print {  .gm-style .gmnoprint, .gmnoprint {    display:none  }}@media screen {  .gm-style .gmnoscreen, .gmnoscreen {    display:none  }}
#    </style>
#    <style type="text/css">
#     .gm-style{font-family:Roboto,Arial,sans-serif;font-size:11px;font-weight:400;text-decoration:none}.gm-style img{max-width:none}
#    </style>
#    <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#     <meta content="IE=edge" http-equiv="X-UA-Compatible">
# ...

# %%
print cityfeet_results[256]
# Out:
# <div class="property clearfix src-LN level-40" data-listing-id="LN19852777">
# <a class="listing" data-gaelabel="LN level-40" data-lid="LN19852777" href="/cont/ForLease/LN19852777/517-Columbus-Avenue-New-York-NY-10024">
# <div class="photo-wrapper">
# <div class="photo-stretchy-wrapper">
# <!-- http://s.lnimg.com/photo/thumb_480/da6b8860315b4dc8889030441608ae84.jpg -->
# <div class="photo-container" style="background-image: url(http://s.lnimg.com/photo/thumb_480/da6b8860315b4dc8889030441608ae84.jpg); filter: progid:DXImageTransform.Microsoft.AlphaImageLoader(src='http://s.lnimg.com/photo/thumb_480/da6b8860315b4dc8889030441608ae84.jpg', sizingMethod='scale');">
# <div class="media-shadow"></div>
# <div class="photo-count">
# <span><i class="icon-camera icon-white"></i> 10 photos</span>
# </div>
# </div>
# </div>
# </div>
# </a>
# <div class="description">
# <div class="contentLeft">
# <div class="description-left">
# <div class="row-fluid">
# <div class="span9">
# ...

# %%
def get_cityfeet_details(listing_placard):
    
    listing = []
    
    # listing streetaddress
    try:
        listing.append(re.findall('title="(.+)">', str(listing_placard))[0])
    except:
        listing.append('')
         
    # listing state
    try:
        listing.append((re.findall('<address>\n<div>(.+)</div>', str(listing_placard))[0]).strip())
    except:
        listing.append('')
    
    # listing price
    try:
        listing.append(re.findall('"price">(.+)</strong><strong>', str(listing_placard))[0])
    except:
        listing.append('')
        
    # listing square feet available
    try:
        listing.append(re.findall('<strong>(.+)</strong>', str(listing_placard))[0])
    except:
        listing.append('')
        
    #listing property description
    try:
        listing.append(re.findall('"propertydescription"><p>((.|\n|\r)*)</p>', str(listing_placard))[0])
    except:
        listing.append('')
    
    return listing

# %%
cityfeet_list = []

for i in cityfeet_results:
    cityfeet_list.append(get_cityfeet_details(i))

dfc = pd.DataFrame(cityfeet_list, columns = ['Street_address', 'State', 'Price', 'SF_avail', 'Prop_desc'])

# %%
dfc.head()
# Out:
#                                       Street_address               State  \
# 0   327 W 57th St. PRIME RESTAURANT-RETAIL FOR LEASE  New York, NY 10019
# 1                        118 West 14th Street Retail  New York, NY 10011
# 2               Prime Retail, 5th Avenue Ladies Mile  New York, NY 10011
# 3           BELOW MARKET!! PRIME MEATPACKING 14th ST  New York, NY 10014
# 4  W 14th St Between Fifth &amp; Sixth Avenues~RE...  NEW YORK, NY 10011
#
#               Price  SF_avail  \
# 0  $118.75 /sf/year  3,840 SF
# 1  $140.00 /sf/year  4,200 SF
# 2    Rent Upon Req.  2,500 SF
# 3   $65.00 /sf/year  3,100 SF
# 4    Rent Upon Req.  2,100 SF
#
#                                            Prop_desc
# 0  (Amazing Location! Perfect for Restaurant or R...
# 1  (Prime retail at the base of a luxury resident...
# 2  (This impeccably maintained boutique cast iron...
# 3  (Boutique building located in the heart of the...
# 4  (Rent - 29,500 month \nTerms- 7 years and 4mon...

# %%
df_c = dfc[dfc['Price']!="Rent Upon Req."]

# %%
df_c.shape
# Out:
# (132, 5)

# %%
df_c[df_c['Price'].str.contains("/sf/year")].shape
# Out:
# (132, 5)

# %%
df_c.head(20)
# Out:
#                                       Street_address               State  \
# 0   327 W 57th St. PRIME RESTAURANT-RETAIL FOR LEASE  New York, NY 10019
# 1                        118 West 14th Street Retail  New York, NY 10011
# 3           BELOW MARKET!! PRIME MEATPACKING 14th ST  New York, NY 10014
# 10                               155 Chambers Street  New York, NY 10007
# 11                               321 Bleecker Street  New York, NY 10014
# 12                               323 Bleecker Street  New York, NY 10014
# 13                                     71 2nd Avenue  New York, NY 10003
# 14                                178 Stanton Street  New York, NY 10002
# 15                                     99 1st Avenue  New York, NY 10003
# 16                                   1750 1st Avenue  New York, NY 10128
# 17                             27 Street Marks Place  New York, NY 10003
# 26                                638 W 174th Street  New York, NY 10033
# ...

# %%
def get_zips(x):
    return re.findall('\d{5}', x)[0]

# %%
df_c.loc[:,'Postcode'] = df_c['State'].apply(get_zips)

# %%
df_c.head()
# Out:
#                                       Street_address               State  \
# 0   327 W 57th St. PRIME RESTAURANT-RETAIL FOR LEASE  New York, NY 10019
# 1                        118 West 14th Street Retail  New York, NY 10011
# 3           BELOW MARKET!! PRIME MEATPACKING 14th ST  New York, NY 10014
# 10                               155 Chambers Street  New York, NY 10007
# 11                               321 Bleecker Street  New York, NY 10014
#
#                Price  SF_avail  \
# 0   $118.75 /sf/year  3,840 SF
# 1   $140.00 /sf/year  4,200 SF
# 3    $65.00 /sf/year  3,100 SF
# 10  $216.00 /sf/year    750 SF
# 11  $370.00 /sf/year    600 SF
#
#                                             Prop_desc Postcode
# 0   (Amazing Location! Perfect for Restaurant or R...    10019
# 1   (Prime retail at the base of a luxury resident...    10011
# 3   (Boutique building located in the heart of the...    10014
# 10  ($13,500/month\nSuper High Traffic Retail Stor...    10007
# ...

# %%
s = "BELOW MARKET!! PRIME MEATPACKING 14th ST"
s.lower()
# Out:
# 'below market!! prime meatpacking 14th st'

# %%
def get_proper_add(x):
    
    proper_add = ['street', 'avenue', 'st', 'st.', 'ave', 'ave.', 'broadway', 'place', 'pl.', 'pl']
    
    x = x.lower()
    x = x.split()
    
    
    if x[-1] not in proper_add:
        return True
    else:
        return False

# %%
df_c['Address_to_correct'] = df_c['Street_address'].apply(get_proper_add)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_c.head()
# Out:
#                                       Street_address               State  \
# 0   327 W 57th St. PRIME RESTAURANT-RETAIL FOR LEASE  New York, NY 10019
# 1                        118 West 14th Street Retail  New York, NY 10011
# 3           BELOW MARKET!! PRIME MEATPACKING 14th ST  New York, NY 10014
# 10                               155 Chambers Street  New York, NY 10007
# 11                               321 Bleecker Street  New York, NY 10014
#
#                Price  SF_avail  \
# 0   $118.75 /sf/year  3,840 SF
# 1   $140.00 /sf/year  4,200 SF
# 3    $65.00 /sf/year  3,100 SF
# 10  $216.00 /sf/year    750 SF
# 11  $370.00 /sf/year    600 SF
#
#                                             Prop_desc Postcode  \
# 0   (Amazing Location! Perfect for Restaurant or R...    10019
# 1   (Prime retail at the base of a luxury resident...    10011
# 3   (Boutique building located in the heart of the...    10014
# 10  ($13,500/month\nSuper High Traffic Retail Stor...    10007
# ...

# %%
df_d = df_c[df_c['Address_to_correct'] == True]
df_d.shape
# Out:
# (10, 7)

# %%
df_d
# Out:
#                                        Street_address                State  \
# 0    327 W 57th St. PRIME RESTAURANT-RETAIL FOR LEASE   New York, NY 10019
# 1                         118 West 14th Street Retail   New York, NY 10011
# 62                         599 Avenue Of The Americas   New York, NY 10011
# 79                                         169 Bowery   New York, NY 10002
# 89                                        95 Avenue B   New York, NY 10009
# 92                         360 Avenue Of The Americas   New York, NY 10014
# 175                                  130 7th Avenue S   New York, NY 10014
# 185                 2496 Frederick Douglass Boulevard   New York, NY 10030
# 214                26 W 14th Street New York Ny 10011   New York, NY 10001
# 240                   1395 Madison Avenue approximate  Manhattan, NY 10029
#
#                 Price  SF_avail  \
# 0    $118.75 /sf/year  3,840 SF
# 1    $140.00 /sf/year  4,200 SF
# 62    $90.00 /sf/year  2,400 SF
# ...

# %%
# Correcting individually

df_c.loc[0, 'Street_address'] = '327 W 57th St'
df_c.loc[1, 'Street_address'] = '118 West 14th Street'
df_c.loc[214, 'Street_address'] = '26 W 14th Street'
df_c.loc[240, 'Street_address'] = '1395 Madison Avenue'
# Out:
# //anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_c.head()
# Out:
#                               Street_address               State  \
# 0                              327 W 57th St  New York, NY 10019
# 1                       118 West 14th Street  New York, NY 10011
# 3   BELOW MARKET!! PRIME MEATPACKING 14th ST  New York, NY 10014
# 10                       155 Chambers Street  New York, NY 10007
# 11                       321 Bleecker Street  New York, NY 10014
#
#                Price  SF_avail  \
# 0   $118.75 /sf/year  3,840 SF
# 1   $140.00 /sf/year  4,200 SF
# 3    $65.00 /sf/year  3,100 SF
# 10  $216.00 /sf/year    750 SF
# 11  $370.00 /sf/year    600 SF
#
#                                             Prop_desc Postcode  \
# 0   (Amazing Location! Perfect for Restaurant or R...    10019
# 1   (Prime retail at the base of a luxury resident...    10011
# 3   (Boutique building located in the heart of the...    10014
# 10  ($13,500/month\nSuper High Traffic Retail Stor...    10007
# ...

# %%
def get_price(x):
    return re.findall('\d+\.\d\d', x)[0]

# %%
df_c['Price_per_sf_per_year'] = df_c['Price'].apply(get_price)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_c.head()
# Out:
#                               Street_address               State  \
# 0                              327 W 57th St  New York, NY 10019
# 1                       118 West 14th Street  New York, NY 10011
# 3   BELOW MARKET!! PRIME MEATPACKING 14th ST  New York, NY 10014
# 10                       155 Chambers Street  New York, NY 10007
# 11                       321 Bleecker Street  New York, NY 10014
#
#                Price  SF_avail  \
# 0   $118.75 /sf/year  3,840 SF
# 1   $140.00 /sf/year  4,200 SF
# 3    $65.00 /sf/year  3,100 SF
# 10  $216.00 /sf/year    750 SF
# 11  $370.00 /sf/year    600 SF
#
#                                             Prop_desc Postcode  \
# 0   (Amazing Location! Perfect for Restaurant or R...    10019
# 1   (Prime retail at the base of a luxury resident...    10011
# 3   (Boutique building located in the heart of the...    10014
# 10  ($13,500/month\nSuper High Traffic Retail Stor...    10007
# ...

# %%
df_c.drop(3, axis = 0, inplace = True)
df_c.head()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#           Street_address               State             Price  SF_avail  \
# 0          327 W 57th St  New York, NY 10019  $118.75 /sf/year  3,840 SF
# 1   118 West 14th Street  New York, NY 10011  $140.00 /sf/year  4,200 SF
# 10   155 Chambers Street  New York, NY 10007  $216.00 /sf/year    750 SF
# 11   321 Bleecker Street  New York, NY 10014  $370.00 /sf/year    600 SF
# 12   323 Bleecker Street  New York, NY 10014  $295.77 /sf/year  1,420 SF
#
#                                             Prop_desc Postcode  \
# 0   (Amazing Location! Perfect for Restaurant or R...    10019
# 1   (Prime retail at the base of a luxury resident...    10011
# ...

# %%
s.replace()
# Out:
# '$65.00 /sf/year'

# %%
df_c.loc[:, 'SF_avail'] = df_c['SF_avail'].apply(lambda x : x.replace(' SF', ''))
df_c.head()
# Out:
#           Street_address               State             Price SF_avail  \
# 0          327 W 57th St  New York, NY 10019  $118.75 /sf/year    3,840
# 1   118 West 14th Street  New York, NY 10011  $140.00 /sf/year    4,200
# 10   155 Chambers Street  New York, NY 10007  $216.00 /sf/year      750
# 11   321 Bleecker Street  New York, NY 10014  $370.00 /sf/year      600
# 12   323 Bleecker Street  New York, NY 10014  $295.77 /sf/year    1,420
#
#                                             Prop_desc Postcode  \
# 0   (Amazing Location! Perfect for Restaurant or R...    10019
# 1   (Prime retail at the base of a luxury resident...    10011
# 10  ($13,500/month\nSuper High Traffic Retail Stor...    10007
# 11  (Store fully renovated, turn key opportunity. ...    10014
# 12  (All renovated, turn key retail opportunity wi...    10014
#
#    Address_to_correct Price_per_sf_per_year
# 0                True                118.75
# 1                True                140.00
# ...

# %%
df_c.loc[:, 'SF_avail'] = df_c['SF_avail'].apply(lambda x : x.replace(',', ''))
df_c.head()
# Out:
#           Street_address               State             Price SF_avail  \
# 0          327 W 57th St  New York, NY 10019  $118.75 /sf/year     3840
# 1   118 West 14th Street  New York, NY 10011  $140.00 /sf/year     4200
# 10   155 Chambers Street  New York, NY 10007  $216.00 /sf/year      750
# 11   321 Bleecker Street  New York, NY 10014  $370.00 /sf/year      600
# 12   323 Bleecker Street  New York, NY 10014  $295.77 /sf/year     1420
#
#                                             Prop_desc Postcode  \
# 0   (Amazing Location! Perfect for Restaurant or R...    10019
# 1   (Prime retail at the base of a luxury resident...    10011
# 10  ($13,500/month\nSuper High Traffic Retail Stor...    10007
# 11  (Store fully renovated, turn key opportunity. ...    10014
# 12  (All renovated, turn key retail opportunity wi...    10014
#
#    Address_to_correct Price_per_sf_per_year
# 0                True                118.75
# 1                True                140.00
# ...

# %%
df_c.loc[:, 'Street_address'] = df_c['Street_address'] + ', NY ' + df_c['Postcode']
df_c.head()
# Out:
#                     Street_address               State             Price  \
# 0          327 W 57th St, NY 10019  New York, NY 10019  $118.75 /sf/year
# 1   118 West 14th Street, NY 10011  New York, NY 10011  $140.00 /sf/year
# 10   155 Chambers Street, NY 10007  New York, NY 10007  $216.00 /sf/year
# 11   321 Bleecker Street, NY 10014  New York, NY 10014  $370.00 /sf/year
# 12   323 Bleecker Street, NY 10014  New York, NY 10014  $295.77 /sf/year
#
#    SF_avail                                          Prop_desc Postcode  \
# 0      3840  (Amazing Location! Perfect for Restaurant or R...    10019
# 1      4200  (Prime retail at the base of a luxury resident...    10011
# 10      750  ($13,500/month\nSuper High Traffic Retail Stor...    10007
# 11      600  (Store fully renovated, turn key opportunity. ...    10014
# 12     1420  (All renovated, turn key retail opportunity wi...    10014
#
#    Address_to_correct Price_per_sf_per_year
# 0                True                118.75
# ...

# %%
df_cityfeet = pd.concat([df_c['Street_address'], df_c['SF_avail'], df_c['Price_per_sf_per_year'], df_c['Prop_desc']], axis = 1)
df_cityfeet.reset_index(inplace = True, drop = True)
df_cityfeet.head()
# Out:
#                    Street_address SF_avail Price_per_sf_per_year  \
# 0         327 W 57th St, NY 10019     3840                118.75
# 1  118 West 14th Street, NY 10011     4200                140.00
# 2   155 Chambers Street, NY 10007      750                216.00
# 3   321 Bleecker Street, NY 10014      600                370.00
# 4   323 Bleecker Street, NY 10014     1420                295.77
#
#                                            Prop_desc
# 0  (Amazing Location! Perfect for Restaurant or R...
# 1  (Prime retail at the base of a luxury resident...
# 2  ($13,500/month\nSuper High Traffic Retail Stor...
# 3  (Store fully renovated, turn key opportunity. ...
# 4  (All renovated, turn key retail opportunity wi...

# %%
def clean_sf(x):
    if '-' in x:
        return int(x.split('-')[1])
    else:
        return int(x)

# %%
s = '1200 - 1500'
clean_sf(s)
# Out:
# 1500

# %%
df_cityfeet.loc[:, 'SF_avail'] = df_cityfeet['SF_avail'].apply(clean_sf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-247-e0c80a273e98> in <module>()
# ----> 1 df_cityfeet.loc[:, 'SF_avail'] = df_cityfeet['SF_avail'].apply(clean_sf)
#       2 df_cityfeet.info()
#
# //anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62658)()
#
# <ipython-input-244-3504659620bf> in clean_sf(x)
#       1 def clean_sf(x):
# ----> 2     if '-' in x:
#       3         return int(x.split('-')[1])
#       4     else:
#       5         return int(x)
#
# TypeError: argument of type 'int' is not iterable

# %%
df_cityfeet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 4 columns):
# Street_address           131 non-null object
# SF_avail                 131 non-null int64
# Price_per_sf_per_year    131 non-null float64
# Prop_desc                131 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ KB

# %%
df_cityfeet.loc[:, 'Price_per_sf_per_year'] = df_cityfeet['Price_per_sf_per_year'].astype(float)

# %%
import numpy as np

lat = []
lon = []
for i in df_cityfeet['Street_address']:
    
    try:
        latlon = geocoder.google(i)
        lat.append(latlon.latlng[0])
        lon.append(latlon.latlng[1])
    
    except:
        lat.append(np.nan)
        lon.append(np.nan)
    
df_cityfeet['Latitude'] = lat
df_cityfeet['Longitude'] = lon
df_cityfeet.head()
# Out:
#                    Street_address  SF_avail  Price_per_sf_per_year  \
# 0         327 W 57th St, NY 10019      3840                 118.75
# 1  118 West 14th Street, NY 10011      4200                 140.00
# 2   155 Chambers Street, NY 10007       750                 216.00
# 3   321 Bleecker Street, NY 10014       600                 370.00
# 4   323 Bleecker Street, NY 10014      1420                 295.77
#
#                                            Prop_desc   Latitude  Longitude
# 0  (Amazing Location! Perfect for Restaurant or R...  40.767498 -73.984111
# 1  (Prime retail at the base of a luxury resident...  40.737629 -73.997937
# 2  ($13,500/month\nSuper High Traffic Retail Stor...  40.716076 -74.009971
# 3  (Store fully renovated, turn key opportunity. ...  40.733199 -74.003924
# 4  (All renovated, turn key retail opportunity wi...  40.733286 -74.003929

# %%
df_cityfeet['Zipcode'] = list(df_c['Postcode'])
df_cityfeet.head()
# Out:
#                    Street_address  SF_avail  Price_per_sf_per_year  \
# 0         327 W 57th St, NY 10019      3840                 118.75
# 1  118 West 14th Street, NY 10011      4200                 140.00
# 2   155 Chambers Street, NY 10007       750                 216.00
# 3   321 Bleecker Street, NY 10014       600                 370.00
# 4   323 Bleecker Street, NY 10014      1420                 295.77
#
#                                            Prop_desc   Latitude  Longitude  \
# 0  (Amazing Location! Perfect for Restaurant or R...  40.767498 -73.984111
# 1  (Prime retail at the base of a luxury resident...  40.737629 -73.997937
# 2  ($13,500/month\nSuper High Traffic Retail Stor...  40.716076 -74.009971
# 3  (Store fully renovated, turn key opportunity. ...  40.733199 -74.003924
# 4  (All renovated, turn key retail opportunity wi...  40.733286 -74.003929
#
#   Zipcode
# 0   10019
# 1   10011
# 2   10007
# 3   10014
# 4   10014

# %%
df_cityfeet.loc[:,'Zipcode'] = df_cityfeet['Zipcode'].astype(int)

# %%
df_cityfeet.describe()
# Out:
#             SF_avail  Price_per_sf_per_year    Latitude   Longitude  \
# count     131.000000             131.000000  131.000000  131.000000
# mean     8403.114504             134.322824   40.755279  -73.978563
# std     48950.738279              98.794998    0.038811    0.024065
# min       279.000000              18.000000   40.703561  -74.012465
# 25%       800.000000              64.845000   40.724422  -74.000122
# 50%      1500.000000             105.000000   40.738547  -73.986773
# 75%      2694.000000             163.930000   40.785749  -73.953785
# max    520000.000000             600.000000   40.862353  -73.925560
#
#             Zipcode
# count    131.000000
# mean   10020.282443
# std       21.166110
# min    10001.000000
# 25%    10010.000000
# 50%    10014.000000
# 75%    10028.500000
# max    10128.000000

# %%
df_cityfeet[df_cityfeet['SF_avail'] > 50000]
# Out:
#                       Street_address  SF_avail  Price_per_sf_per_year  \
# 64         2340 5th Avenue, NY 10037    520000                   49.0
# 67  2005 2023 Third Avenue, NY 10029    121500                   50.0
# 68       315 E 94th Street, NY 10128    185000                   60.0
#
#                                             Prop_desc   Latitude  Longitude  \
# 64  (Build to Suit Commercial Development in Harle...  40.816982 -73.934953
# 67  (Build to Suit Commercial Development in East ...  40.794119 -73.942374
# 68  (Build to Suit Commercial Development in the U...  40.782479 -73.946914
#
#     Zipcode
# 64    10037
# 67    10029
# 68    10128

# %%
df_cityfeet.to_csv('cityfeet_retail_rental.csv')

# %%
pd.pivot_table(df_cityfeet, values = ['SF_avail', 'Price_per_sf_per_year'], index = ['Zipcode'], aggfunc='count')
# Out:
#          Price_per_sf_per_year  SF_avail
# Zipcode
# 10001                        1         1
# 10002                       15        15
# 10003                       10        10
# 10004                        1         1
# 10005                        1         1
# 10007                        3         3
# 10009                        2         2
# 10011                        8         8
# 10012                       11        11
# 10013                        8         8
# 10014                       10        10
# 10016                        1         1
# 10017                        2         2
# 10018                        3         3
# 10019                        1         1
# 10021                        3         3
# 10022                        5         5
# 10023                        1         1
# 10024                        4         4
# 10025                        2         2
# 10026                        1         1
# 10027                        3         3
# ...

# %%
df.head(1)
# Out:
#                                          Web_address        Street_address  \
# 0  http://www.loopnet.com/Listing/19621797/134-We...  134 West 37th Street
#
#        Locality State Postcode               Price Property_type  \
# 0  New York, NY    NY    10018  $45-$79.20 SF/Year   Office Bldg
#
#          SF_avail Spaces_avail  Bldg_SF  \
# 0  2,500 - 10,000            2  120,000
#
#                                            Prop_desc  \
# 0  Extremely desirable office space in the heart ...
#
#               Full_street_address   Latitude  Longitude
# 0  134 West 37th Street, NY 10018  40.752365 -73.988503

# %%
sample = cityfeet_results[0]
sp = BeautifulSoup(sample, "lxml")

b = soup.find_all('div','propertydescription')
print b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-171-831e1d4ee14a> in <module>()
#       1 sample = cityfeet_results[0]
# ----> 2 sp = BeautifulSoup(sample, "lxml")
#       3
#       4 b = soup.find_all('div','propertydescription')
#       5 print b
#
# //anaconda/lib/python2.7/site-packages/bs4/__init__.pyc in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     173
#     174         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 175             markup = markup.read()
#     176         elif len(markup) <= 256:
#     177             # Print out warnings for a couple beginner problems
#
# TypeError: 'NoneType' object is not callable

# %%
<div class="property clearfix src-CF level-30" data-listing-id="CF2791462">
<a class="listing" data-gaelabel="CF level-30" data-lid="CF2791462" href="/cont/ForLease/CF2791462/327-W-57th-St-PRIME-RESTAURANT-RETAIL-FOR-LEASE-New-York-NY-10019">
<div class="photo-wrapper">
<div class="photo-stretchy-wrapper">
<!-- http://images.cityfeet.com/ListingImages/2791462_1_tn.jpg -->
<div class="photo-container" style="background-image: url(http://images.cityfeet.com/ListingImages/2791462_1_tn.jpg); filter: progid:DXImageTransform.Microsoft.AlphaImageLoader(src='http://images.cityfeet.com/ListingImages/2791462_1_tn.jpg', sizingMethod='scale');">
<div class="media-shadow"></div>
<div class="photo-count">
<span><i class="icon-camera icon-white"></i> 4 photos</span>
</div>
</div>
</div>
</div>
</a>
<div class="description">
<div class="contentLeft">
<div class="description-left">
<div class="row-fluid">
<div class="span9">
<h2><a class="listing" data-lid="CF2791462" href="/cont/ForLease/CF2791462/327-W-57th-St-PRIME-RESTAURANT-RETAIL-FOR-LEASE-New-York-NY-10019" title="327 W 57th St. PRIME RESTAURANT-RETAIL FOR LEASE">327 W 57th St. PRIME RESTAURANT-RETAIL FOR LEASE</a></h2>
</div>
</div>
<address>
<div>New York, NY 10019</div>
</address>
<p class="propertyTypes"><span>Retail</span></p>
</div>
<div class="description-right">
<p class="stats"><strong class="price">$118.75 /sf/year</strong><strong>3,840 SF</strong></p>
</div>
<div class="propertydescription"><p>Amazing Location! Perfect for Restaurant or Retail! By Columbus Circle! 

RENT: Only $119 / SF ($38,000 per month)

SPACE: 3,840 SF Ground Floor
1,200 SF Basement
Total: 5,040 SF

TERM: 10 years

COMMENTS: Built as a restaurant. 170 people capacity
3 bars, 4 walk in boxes, working fireplace.
Possibility for outdoor seating. 

LOCATION: Columbus Circle Area. 

NEIGHBORS: Central Park, Columbus Circle, TJ Max, Ricky's, Wallgreens, Baked by Melissa, CVS, Time Warner Shops, City MD, Starbucks, MT Sinai Hospital, Dunkin Donuts.

CONTACT: Elena 718-300-0917, commercialspacesgroup@gmail.com. I have access to all retail spaces in NY. Just contact me with your requirements. For more of my listings please follow the link: http://commercialspacesgroup.com/team/elena-samasiuk</p></div>
</div>
</div>
</div>

# %%
url = 'http://www.cityfeet.com/cont/ny/new-york-retail-space#'

"""58.176.46.248
4.31.142.200
64.20.45.138"""

proxies = {
    'http':'http://4.31.142.200'
    }

cityfeet_results = []

r = requests.get(url, proxies=proxies)
if str(r) == "<Response [200]>":

    page = r.content
    soup = BeautifulSoup(page, 'lxml')
    
    
    for d in soup.find_all(class_ = 'property clearfix src-CF level-30'):
        cityfeet_results.append(d)

# %%
len(cityfeet_results)
# Out:
# 0

# %%
for pg in range(2, max_pages+1, 1):

    url = url_template1 + str(pg) + url_template2

    r = requests.get(url, proxies=proxies)
    if str(r) == "<Response [200]>":

        page = r.content
        soup = BeautifulSoup(page, 'lxml')

        results.append(get_listings(soup))
        for i in results:
            page_list.append(get_listing_details(i))

    else:
        print "This url is not responding favorably."
        print "url =", url
        print "response =", r



s = BeautifulSoup(driver.page_source)
r = re.compile(r'jobdetail\.ftl\?job=\d+$')

for a in s.findAll('a', href=r):
    tr = a.findParent('tr')
    td = tr.findAll('td')

    job = {}
    job['title'] = a.text
    job['url'] = urlparse.urljoin(link, a['href'])
    job['location'] = td[2].text
    jobs.append(job)

next_page_elem = self.driver.find_element_by_id('next')
next_page_link = s.find('a', text='%d' % pageno)

if next_page_link:
    next_page_elem.click()
    pageno += 1
    sleep(1)
else:
    break

return jobs

# %% [markdown]
# ## Get demographic website

# %%
df.loc[40, 'Web_address'] = 'http://www.loopnet.com/Listing/19271844/100-Broad-St-New-York-NY/'
df.loc[40, 'Web_address']
# Out:
# 'http://www.loopnet.com/Listing/19271844/100-Broad-St-New-York-NY/'

# %%
def get_demo_web(result):
    

    for d in result.findAll(class_ = "research"):

        demo = re.findall('href="(.+)">Demographics',str(d))

        return demo[0]

# %%
url = 'http://www.loopnet.com/Listing/19850409/55-Wythe-Avenue-Brooklyn-NY/'

#results = []

r = requests.get(url)

page = r.content
soup = BeautifulSoup(page, 'lxml')

results = get_demo_web(soup)

# %%
demo_web = []

for n,i in enumerate(df['Web_address']):
    url = i
    
    try:

        r = requests.get(url)
        page = r.content
        soup = BeautifulSoup(page, 'lxml')
        demo_web.append(get_demo_web(soup))
    
    except:
        demo_web.append('')
        print "This url is not responding favorably."
        print n, "url =", url
        print "response =", r
        print

# %%
len(demo_web)
# Out:
# 0

# %% [markdown]
# ## Resources and references

# %% [markdown]
# 1. Source for property listings - http://www.loopnet.com/

# %% [markdown]
# # Getting started
#
# Once you've chosen your scenario, download the data from [the Iowa website](https://data.iowa.gov/Economy/Iowa-Liquor-Sales/m3tr-qhgy) in csv format. Start by loading the data with pandas. You may need to parse the date columns appropriately.

# %% [markdown]
# #### Scenario 2: Market research for new store locations
#
# A liquor store owner in Iowa is looking to expand to new locations and has hired you to investigate the market data for potential new locations. The business owner is interested in the details of the best model you can fit to the data so that his team can evaluate potential locations for a new storefront.
#
# **Goal for Scenario #2:** Your task is to:
#
# * Build models of total sales based on location, price per bottle, total bottles sold. You may find it useful to build models for each county, zip code, or city.
# * Provide a table of the best performing stores by location type of your choice (city, county, or zip code) and the predictions of your model(s).
# * Based on your models and the table of data, recommend some general locations to the business owner, taking into account model performance. Validate your model's performance and ability to predict future sales using cross-validation.
# * _Bonus_: Recommend targets for volume sold and price per bottle!
#
# ---

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import pprint

# %%
## Load the data into a DataFrame
df = pd.read_csv("Iowa_Liquor_sales_sample_10pct.csv")

## Transform the dates if needed, e.g.
# df["Date"] = pd.to_datetime(df["Date"], format="%m-%d-%y")

df.head()
# Out:
#          Date  Store Number         City Zip Code  County Number      County  \
# 0  11/04/2015          3717       SUMNER    50674            9.0      Bremer
# 1  03/02/2016          2614    DAVENPORT    52807           82.0       Scott
# 2  02/11/2016          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3  02/03/2016          2501         AMES    50010           85.0       Story
# 4  08/18/2015          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750             $4.50
# 1                    Tin Cup                 750            $13.75
# 2                   Jim Beam                1000            $12.59
# 3    1800 Ultimate Margarita                1750             $9.50
# 4         Five O'clock Vodka                1750             $7.20
#
#   State Bottle Retail  Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 0               $6.75            12         $81.00                   9.0
# 1              $20.63             2         $41.26                   1.5
# 2              $18.89            24        $453.36                  24.0
# 3              $14.25             6         $85.50                  10.5
# 4              $10.80            12        $129.60                  21.0
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40
# 2                   6.34
# 3                   2.77
# 4                   5.55

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 18 columns):
# Date                     270955 non-null object
# Store Number             270955 non-null int64
# City                     270955 non-null object
# Zip Code                 270955 non-null object
# County Number            269878 non-null float64
# County                   269878 non-null object
# Category                 270887 non-null float64
# Category Name            270323 non-null object
# Vendor Number            270955 non-null int64
# Item Number              270955 non-null int64
# Item Description         270955 non-null object
# Bottle Volume (ml)       270955 non-null int64
# State Bottle Cost        270955 non-null object
# State Bottle Retail      270955 non-null object
# Bottles Sold             270955 non-null int64
# Sale (Dollars)           270955 non-null object
# Volume Sold (Liters)     270955 non-null float64
# Volume Sold (Gallons)    270955 non-null float64
# dtypes: float64(4), int64(5), object(9)
# memory usage: 37.2+ MB

# %% [markdown]
# ### Data Munging

# %%
df['Date'] = df['Date'].apply(pd.to_datetime)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-168-16f001acf7c7> in <module>()
# ----> 1 df['Date'] = df['Date'].apply(pd.to_datetime)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62658)()
#
# //anaconda/lib/python2.7/site-packages/pandas/util/decorators.pyc in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# //anaconda/lib/python2.7/site-packages/pandas/tseries/tools.pyc in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, coerce, unit, infer_datetime_format)
#     289                         yearfirst=yearfirst,
#     290                         utc=utc, box=box, format=format, exact=exact,
# --> 291                         unit=unit, infer_datetime_format=infer_datetime_format)
#     292
#     293
#
# //anaconda/lib/python2.7/site-packages/pandas/tseries/tools.pyc in _to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, freq, infer_datetime_format)
#     427         return _convert_listlike(arg, box, format)
#     428
# --> 429     return _convert_listlike(np.array([arg]), box, format)[0]
#     430
#     431 # mappings for assembling units
#
# //anaconda/lib/python2.7/site-packages/pandas/tseries/tools.pyc in _convert_listlike(arg, box, format, name)
#     396                     yearfirst=yearfirst,
#     397                     freq=freq,
# --> 398                     require_iso8601=require_iso8601
#     399                 )
#     400
#
# pandas/tslib.pyx in pandas.tslib.array_to_datetime (pandas/tslib.c:41972)()
#
# pandas/tslib.pyx in pandas.tslib.array_to_datetime (pandas/tslib.c:40293)()
#
# pandas/tslib.pyx in pandas.tslib.parse_datetime_string (pandas/tslib.c:31806)()
#
# //anaconda/lib/python2.7/site-packages/dateutil/parser.pyc in parse(timestr, parserinfo, **kwargs)
#    1162         return parser(parserinfo).parse(timestr, **kwargs)
#    1163     else:
# -> 1164         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1165
#    1166
#
# //anaconda/lib/python2.7/site-packages/dateutil/parser.pyc in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     550             effective_dt = default
#     551
# --> 552         res, skipped_tokens = self._parse(timestr, **kwargs)
#     553
#     554         if res is None:
#
# //anaconda/lib/python2.7/site-packages/dateutil/parser.pyc in _parse(self, timestr, dayfirst, yearfirst, fuzzy, fuzzy_with_tokens)
#     690                 try:
#     691                     value_repr = l[i]
# --> 692                     value = float(value_repr)
#     693                 except ValueError:
#     694                     value = None
#
# KeyboardInterrupt:

# %%
df['Bottle Volume (ml)'].hist(bins = 200)

# %% [markdown]
# Most common bottle type is 750ml. 1750ml is second most popular.

# %%
# Function to convert money columns from string to float

def conv_money(x):
    x = x.split('.')
    return (float(x[0][1:]) + (float(x[1]) / 100))

# %%
# Converting columns with money value to float

df[['State Bottle Cost', 'State Bottle Retail', "Sale (Dollars)"]] = \
df[['State Bottle Cost', 'State Bottle Retail', "Sale (Dollars)"]].applymap(conv_money)

# %%
df['Item Description'] = df['Item Description'].apply(lambda x: x.strip())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 18 columns):
# Date                     270955 non-null object
# Store Number             270955 non-null int64
# City                     270955 non-null object
# Zip Code                 270955 non-null object
# County Number            269878 non-null float64
# County                   269878 non-null object
# Category                 270887 non-null float64
# Category Name            270323 non-null object
# Vendor Number            270955 non-null int64
# Item Number              270955 non-null int64
# Item Description         270955 non-null object
# Bottle Volume (ml)       270955 non-null int64
# State Bottle Cost        270955 non-null float64
# State Bottle Retail      270955 non-null float64
# Bottles Sold             270955 non-null int64
# Sale (Dollars)           270955 non-null float64
# Volume Sold (Liters)     270955 non-null float64
# Volume Sold (Gallons)    270955 non-null float64
# dtypes: float64(7), int64(5), object(6)
# memory usage: 37.2+ MB

# %% [markdown]
# ## Cleaning Zipcodes

# %%
## Checking to see if all zipcodes have length of 5

df[df['Zip Code'].apply(lambda x: len(x) != 5)]
# Out:
# Empty DataFrame
# Columns: [Date, Store Number, City, Zip Code, County Number, County, Category, Category Name, Vendor Number, Item Number, Item Description, Bottle Volume (ml), State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters), Volume Sold (Gallons)]
# Index: []

# %%
# Since all has 5, change all to int types

df[df['Zip Code'].apply(lambda x: int(x))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-222-05561b6a6522> in <module>()
#       1 # Since all has 5, change all to int types
#       2
# ----> 3 df[df['Zip Code'].apply(lambda x: int(x))]
#
# //anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62658)()
#
# <ipython-input-222-05561b6a6522> in <lambda>(x)
#       1 # Since all has 5, change all to int types
#       2
# ----> 3 df[df['Zip Code'].apply(lambda x: int(x))]
#
# ValueError: invalid literal for int() with base 10: '712-2'

# %%
# Even all is length 5, 1 entry was '712-2'
# Googled this, turned out to be area code, change to 51529

df[df['Zip Code'].apply(lambda x: x == '712-2')]
# Out:
#               Date  Store Number    City Zip Code  County Number    County  \
# 114     01/16/2015          4307  DUNLAP    712-2           43.0  Harrison
# 2695    01/05/2015          4307  DUNLAP    712-2           43.0  Harrison
# 4129    10/19/2015          4307  DUNLAP    712-2           43.0  Harrison
# 5506    01/05/2015          4307  DUNLAP    712-2           43.0  Harrison
# 5512    11/20/2015          4307  DUNLAP    712-2           43.0  Harrison
# 8186    03/14/2016          4307  DUNLAP    712-2            NaN       NaN
# 8642    11/02/2015          4307  DUNLAP    712-2           43.0  Harrison
# 9347    03/21/2016          4307  DUNLAP    712-2            NaN       NaN
# 16502   12/26/2015          4307  DUNLAP    712-2           43.0  Harrison
# 16928   11/09/2015          4307  DUNLAP    712-2           43.0  Harrison
# 19076   08/31/2015          4307  DUNLAP    712-2           43.0  Harrison
# 20226   11/30/2015          4307  DUNLAP    712-2           43.0  Harrison
# 21339   12/18/2015          4307  DUNLAP    712-2           43.0  Harrison
# 22113   07/20/2015          4307  DUNLAP    712-2           43.0  Harrison
# 22766   08/24/2015          4307  DUNLAP    712-2           43.0  Harrison
# 24006   04/20/2015          4307  DUNLAP    712-2           43.0  Harrison
# 25494   09/04/2015          4307  DUNLAP    712-2           43.0  Harrison
# 26430   05/04/2015          4307  DUNLAP    712-2           43.0  Harrison
# 28964   03/07/2016          4307  DUNLAP    712-2            NaN       NaN
# 29975   02/08/2016          4307  DUNLAP    712-2            NaN       NaN
# 31946   06/08/2015          4307  DUNLAP    712-2           43.0  Harrison
# 32470   04/06/2015          4307  DUNLAP    712-2           43.0  Harrison
# 32650   11/09/2015          4307  DUNLAP    712-2           43.0  Harrison
# 32708   06/01/2015          4307  DUNLAP    712-2           43.0  Harrison
# 33082   07/20/2015          4307  DUNLAP    712-2           43.0  Harrison
# 33756   02/22/2016          4307  DUNLAP    712-2            NaN       NaN
# 35270   10/05/2015          4307  DUNLAP    712-2           43.0  Harrison
# 35970   03/28/2016          4307  DUNLAP    712-2            NaN       NaN
# 36903   05/18/2015          4307  DUNLAP    712-2           43.0  Harrison
# 37245   03/02/2015          4307  DUNLAP    712-2           43.0  Harrison
# ...            ...           ...     ...      ...            ...       ...
# 232069  05/11/2015          4307  DUNLAP    712-2           43.0  Harrison
# 232947  02/22/2016          4307  DUNLAP    712-2            NaN       NaN
# 234018  02/22/2016          4307  DUNLAP    712-2            NaN       NaN
# 235210  08/24/2015          4307  DUNLAP    712-2           43.0  Harrison
# 235281  11/16/2015          4307  DUNLAP    712-2           43.0  Harrison
# 236875  09/21/2015          4307  DUNLAP    712-2           43.0  Harrison
# 237354  07/20/2015          4307  DUNLAP    712-2           43.0  Harrison
# 237368  08/31/2015          4307  DUNLAP    712-2           43.0  Harrison
# 241349  09/28/2015          4307  DUNLAP    712-2           43.0  Harrison
# 242629  06/08/2015          4307  DUNLAP    712-2           43.0  Harrison
# 242728  04/20/2015          4307  DUNLAP    712-2           43.0  Harrison
# 248752  11/16/2015          4307  DUNLAP    712-2           43.0  Harrison
# 249944  11/16/2015          4307  DUNLAP    712-2           43.0  Harrison
# 250288  06/26/2015          4307  DUNLAP    712-2           43.0  Harrison
# 250568  11/09/2015          4307  DUNLAP    712-2           43.0  Harrison
# 251748  02/02/2015          4307  DUNLAP    712-2           43.0  Harrison
# 253689  06/15/2015          4307  DUNLAP    712-2           43.0  Harrison
# 255048  02/01/2016          4307  DUNLAP    712-2            NaN       NaN
# 255330  11/16/2015          4307  DUNLAP    712-2           43.0  Harrison
# 258405  02/02/2015          4307  DUNLAP    712-2           43.0  Harrison
# 258613  06/15/2015          4307  DUNLAP    712-2           43.0  Harrison
# 259037  03/23/2015          4307  DUNLAP    712-2           43.0  Harrison
# 260821  02/02/2015          4307  DUNLAP    712-2           43.0  Harrison
# 262219  04/06/2015          4307  DUNLAP    712-2           43.0  Harrison
# 262829  12/18/2015          4307  DUNLAP    712-2           43.0  Harrison
# 264511  03/23/2015          4307  DUNLAP    712-2           43.0  Harrison
# 265297  08/10/2015          4307  DUNLAP    712-2           43.0  Harrison
# 269354  12/18/2015          4307  DUNLAP    712-2           43.0  Harrison
# 270252  11/16/2015          4307  DUNLAP    712-2           43.0  Harrison
# 270643  12/26/2015          4307  DUNLAP    712-2           43.0  Harrison
#
#          Category                       Category Name  Vendor Number  \
# 114     1062300.0                        FLAVORED RUM             35
# 2695    1012100.0                   CANADIAN WHISKIES            115
# 4129    1012100.0                   CANADIAN WHISKIES            115
# 5506    1081380.0              MISCELLANEOUS SCHNAPPS             65
# 5512    1051140.0                      PEACH BRANDIES            434
# 8186    1031080.0                      VODKA 80 PROOF             55
# 8642    1081400.0                          TRIPLE SEC            434
# 9347    1081400.0                          TRIPLE SEC            434
# 16502   1031200.0                      VODKA FLAVORED            380
# 16928   1062300.0                        FLAVORED RUM            260
# 19076   1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS            461
# 20226   1051100.0                    APRICOT BRANDIES            434
# 21339   1012100.0                   CANADIAN WHISKIES            260
# 22113   1071100.0                  AMERICAN COCKTAILS            395
# 22766   1032080.0                      IMPORTED VODKA             35
# 24006   1031080.0                      VODKA 80 PROOF            322
# 25494   1062300.0                        FLAVORED RUM            370
# 26430   1062300.0                        FLAVORED RUM             35
# 28964   1081390.0                   IMPORTED SCHNAPPS            260
# 29975   1081365.0             TROPICAL FRUIT SCHNAPPS             65
# 31946   1081700.0         DISTILLED SPIRITS SPECIALTY            346
# 32470   1081315.0                   CINNAMON SCHNAPPS            380
# 32650   1062300.0                        FLAVORED RUM             35
# 32708   1012100.0                   CANADIAN WHISKIES            260
# 33082   1011300.0                  TENNESSEE WHISKIES             85
# 33756   1012100.0                   CANADIAN WHISKIES             65
# 35270   1031080.0                      VODKA 80 PROOF            301
# 35970   1062300.0                        FLAVORED RUM            370
# 36903   1012200.0                     SCOTCH WHISKIES            240
# 37245   1081315.0                   CINNAMON SCHNAPPS            380
# ...           ...                                 ...            ...
# 232069  1042100.0                   IMPORTED DRY GINS            240
# 232947  1011100.0                    BLENDED WHISKIES             65
# 234018  1012100.0                   CANADIAN WHISKIES            260
# 235210  1081250.0               WHITE CREME DE MENTHE            434
# 235281  1012200.0                     SCOTCH WHISKIES            260
# 236875  1062310.0                          SPICED RUM            260
# 237354  1011300.0                  TENNESSEE WHISKIES             85
# 237368  1031080.0                      VODKA 80 PROOF             55
# 241349  1081030.0                     COFFEE LIQUEURS            370
# 242629  1012100.0                   CANADIAN WHISKIES            115
# 242728  1071100.0                  AMERICAN COCKTAILS            395
# 248752  1081370.0                 WATERMELON SCHNAPPS             65
# 249944  1081390.0                   IMPORTED SCHNAPPS            421
# 250288  1081390.0                   IMPORTED SCHNAPPS            421
# 250568  1081200.0                      CREAM LIQUEURS            305
# 251748  1012100.0                   CANADIAN WHISKIES            260
# 253689  1012100.0                   CANADIAN WHISKIES            260
# 255048  1011100.0                    BLENDED WHISKIES            297
# 255330        NaN                                 NaN             85
# 258405  1081390.0                   IMPORTED SCHNAPPS            260
# 258613  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM             35
# 259037  1031080.0                      VODKA 80 PROOF            434
# 260821  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM            434
# 262219  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS            192
# 262829  1062310.0                          SPICED RUM            260
# 264511  1011200.0           STRAIGHT BOURBON WHISKIES             65
# 265297  1012100.0                   CANADIAN WHISKIES             65
# 269354  1012100.0                   CANADIAN WHISKIES            260
# 270252  1032080.0                      IMPORTED VODKA            229
# 270643  1011100.0                    BLENDED WHISKIES            492
#
#         Item Number                          Item Description  \
# 114           43136                             Bacardi Limon
# 2695          11777                              Black Velvet
# 4129          10553                Black Velvet Cinnamon Rush
# 5506          82627                    Dekuyper Cherry Pucker
# 5512          56206           Paramount Peach Flavored Brandy
# 8186          35314                              Barton Vodka
# 8642          86310                       La Prima Triple Sec
# 9347          86310                       La Prima Triple Sec
# 16502         41783              Uv Blue Raspberry Vodka Mini
# 16928         43287           Captain Morgan Parrot Bay Mango
# 19076         67192                    X Rated Fusion Liqueur
# 20226         54447         Paramount Apricot Flavored Brandy
# 21339         11298               Crown Royal Canadian Whisky
# 22113         58838      Jose Cuervo Authentic Lime Margarita
# 22766         34433                          Grey Goose Vodka
# 24006         37145                              Opulent Mini
# 25494         42717                        Malibu Coconut Rum
# 26430         43197                    Bacardi Torched Cherry
# 28964         69947  Rumple Minze Peppermint Schnapps Liqueur
# 29975         82857              Dekuyper Island Punch Pucker
# 31946         86731            Ole Smoky Lemon Drop Moonshine
# 32470         84636        Phillips Hot 100 Cinnamon Schnapps
# 32650         43137                             Bacardi Limon
# 32708        902415                  Crown Royal Spec Reserve
# 33082         26586                            Gentleman Jack
# 33756         10628                      Canadian Club Whisky
# 35270         38177                      Titos Handmade Vodka
# 35970         42717                        Malibu Coconut Rum
# 36903          6997                     Clan Macgregor Scotch
# 37245         84636        Phillips Hot 100 Cinnamon Schnapps
# ...             ...                                       ...
# 232069        28627                            Hendrick's Gin
# 232947        24457                     Kessler Blend Whiskey
# 234018        11297               Crown Royal Canadian Whisky
# 235210        79816           Paramount Creme De Menthe/white
# 235281         5346                        Johnnie Walker Red
# 236875        43338                 Captain Morgan Spiced Rum
# 237354        26827             Jack Daniels Old #7 Black Lbl
# 237368        35317                              Barton Vodka
# 241349        67527                     Kahlua Coffee Liqueur
# 242629        11777                              Black Velvet
# 242728        58842             Jose Cuervo Coconut Pineapple
# 248752        82866                Dekuyper Watermelon Pucker
# 249944        69634        Dr. Mcgillicuddy's Cherry Schnapps
# 250288        69637        Dr. Mcgillicuddy's Cherry Schnapps
# 250568        80488                   Tippy Cow Shamrock Mint
# 251748        11297               Crown Royal Canadian Whisky
# 253689        11290          Crown Royal Canadian Whisky Mini
# 255048        23827                                 Five Star
# 255330          475   Southern Comfort w/Shot Glass & Lanyard
# 258405        69947  Rumple Minze Peppermint Schnapps Liqueur
# 258613        43124                      Bacardi Superior Rum
# 259037        36307                             Hawkeye Vodka
# 260821        45274                       Paramount White Rum
# 262219        65257                      Jagermeister Liqueur
# 262829        43334                 Captain Morgan Spiced Rum
# 264511        19067                                  Jim Beam
# 265297        10628                      Canadian Club Whisky
# 269354        11366               Crown Royal Special Reserve
# 270252        36399                   Penthouse Spirits Vodka
# 270643        27692      Bird Dog Apple Flavored Whiskey Mini
#
#         Bottle Volume (ml)  State Bottle Cost  State Bottle Retail  \
# 114                    750               8.50                12.75
# 2695                  1000               6.63                 9.95
# 4129                   750               6.75                10.13
# 5506                  1000               7.62                11.43
# 5512                   750               5.48                 8.22
# 8186                   375               1.71                 2.57
# 8642                  1000               3.00                 4.50
# 9347                  1000               3.00                 4.50
# 16502                  500               4.89                 7.34
# 16928                  750               7.49                11.24
# 19076                  750              14.66                21.99
# 20226                 1000               6.53                 9.80
# 21339                 1750              31.99                47.99
# 22113                 1750               8.20                12.30
# 22766                  750              18.49                27.74
# 24006                  500               4.95                 7.43
# 25494                 1000              10.49                15.74
# 26430                  750               8.26                12.39
# 28964                 1000              15.75                23.63
# 29975                 1000               7.87                11.81
# 31946                  750              11.00                16.50
# 32470                  750               7.45                11.18
# 32650                 1000               9.50                14.25
# 32708                 1750              40.00                60.00
# 33082                  750              20.01                30.02
# 33756                 1750              15.75                23.63
# 35270                 1000              11.92                17.88
# 35970                 1000              10.49                15.74
# 36903                 1000               6.66                 9.99
# 37245                  750               7.45                11.18
# ...                    ...                ...                  ...
# 232069                1000              21.17                31.76
# 232947                1000               7.08                10.62
# 234018                1000              18.75                28.13
# 235210                 750               4.75                 7.13
# 235281                 750              14.49                21.74
# 236875                1750              18.00                27.00
# 237354                1000              18.38                27.57
# 237368                1000               3.97                 5.96
# 241349                1000              15.49                23.24
# 242629                1000               6.63                 9.95
# 242728                1750               8.20                12.30
# 248752                 750               6.30                 9.45
# 249944                 375               5.33                 8.00
# 250288                1000              11.00                16.50
# 250568                 750              10.00                15.00
# 251748                1000              18.50                27.75
# 253689                 300               7.35                11.03
# 255048                1000               4.40                 6.60
# 255330                 750              10.33                15.50
# 258405                1000              15.75                23.63
# 258613                 375               4.50                 6.75
# 259037                1000               4.05                 6.08
# 260821                 375               2.96                 4.44
# 262219                1000              15.54                23.31
# 262829                 375               5.00                 7.50
# 264511                1000              12.59                18.89
# 265297                1750              15.75                23.63
# 269354                 750              25.00                37.50
# 270252                 750              13.49                20.24
# 270643                 600               6.00                 9.00
#
#         Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 114                2           25.50                  1.50
# 2695              12          119.40                 12.00
# 4129               3           30.39                  2.25
# 5506               1           11.43                  1.00
# 5512               1            8.22                  0.75
# 8186               3            7.71                  1.12
# 8642               1            4.50                  1.00
# 9347               3           13.50                  3.00
# 16502              1            7.34                  0.50
# 16928              1           11.24                  0.75
# 19076              6          131.94                  4.50
# 20226             12          117.60                 12.00
# 21339              6          287.94                 10.50
# 22113              6           73.80                 10.50
# 22766              1           27.74                  0.75
# 24006              1            7.43                  0.50
# 25494             12          188.88                 12.00
# 26430              1           12.39                  0.75
# 28964              2           47.26                  2.00
# 29975              2           23.62                  2.00
# 31946              1           16.50                  0.75
# 32470              3           33.54                  2.25
# 32650             12          171.00                 12.00
# 32708              6          360.00                 10.50
# 33082              1           30.02                  0.75
# 33756              6          141.78                 10.50
# 35270              2           35.76                  2.00
# 35970              3           47.22                  3.00
# 36903             12          119.88                 12.00
# 37245              2           22.36                  1.50
# ...              ...             ...                   ...
# 232069             1           31.76                  1.00
# 232947             5           53.10                  5.00
# 234018            12          337.56                 12.00
# 235210             1            7.13                  0.75
# 235281             1           21.74                  0.75
# 236875             6          162.00                 10.50
# 237354            12          330.84                 12.00
# 237368            12           71.52                 12.00
# 241349             1           23.24                  1.00
# 242629            12          119.40                 12.00
# 242728             6           73.80                 10.50
# 248752             2           18.90                  1.50
# 249944             2           16.00                  0.75
# 250288            12          198.00                 12.00
# 250568             6           90.00                  4.50
# 251748            12          333.00                 12.00
# 253689             1           11.03                  0.30
# 255048             2           13.20                  2.00
# 255330             2           31.00                  1.50
# 258405             2           47.26                  2.00
# 258613             1            6.75                  0.38
# 259037            12           72.96                 12.00
# 260821             2            8.88                  0.75
# 262219             2           46.62                  2.00
# 262829             3           22.50                  1.12
# 264511            12          226.68                 12.00
# 265297             6          141.78                 10.50
# 269354             1           37.50                  0.75
# 270252             6          121.44                  4.50
# 270643             1            9.00                  0.60
#
#         Volume Sold (Gallons)
# 114                      0.40
# 2695                     3.17
# 4129                     0.59
# 5506                     0.26
# 5512                     0.20
# 8186                     0.30
# 8642                     0.26
# 9347                     0.79
# 16502                    0.13
# 16928                    0.20
# 19076                    1.19
# 20226                    3.17
# 21339                    2.77
# 22113                    2.77
# 22766                    0.20
# 24006                    0.13
# 25494                    3.17
# 26430                    0.20
# 28964                    0.53
# 29975                    0.53
# 31946                    0.20
# 32470                    0.59
# 32650                    3.17
# 32708                    2.77
# 33082                    0.20
# 33756                    2.77
# 35270                    0.53
# 35970                    0.79
# 36903                    3.17
# 37245                    0.40
# ...                       ...
# 232069                   0.26
# 232947                   1.32
# 234018                   3.17
# 235210                   0.20
# 235281                   0.20
# 236875                   2.77
# 237354                   3.17
# 237368                   3.17
# 241349                   0.26
# 242629                   3.17
# 242728                   2.77
# 248752                   0.40
# 249944                   0.20
# 250288                   3.17
# 250568                   1.19
# 251748                   3.17
# 253689                   0.08
# 255048                   0.53
# 255330                   0.40
# 258405                   0.53
# 258613                   0.10
# 259037                   3.17
# 260821                   0.20
# 262219                   0.53
# 262829                   0.30
# 264511                   3.17
# 265297                   2.77
# 269354                   0.20
# 270252                   1.19
# 270643                   0.16
#
# [217 rows x 18 columns]

# %%
# Changed erroneous zipcode

df.loc[df['Zip Code'] == '712-2', 'Zip Code'] = '51529'

# %%
# Changed zipcodes to int type

df['Zip Code'] = df['Zip Code'].apply(lambda x: int(x))

# %% [markdown]
# ## Cleaning City Values

# %%
list(df['City'].unique())
# Out:
# ['SUMNER',
#  'DAVENPORT',
#  'CEDAR FALLS',
#  'AMES',
#  'BELMOND',
#  'CEDAR RAPIDS',
#  'OTTUMWA',
#  'CLEAR LAKE',
#  'BONDURANT',
#  'SHELLSBURG',
#  'WEST DES MOINES',
#  'OSKALOOSA',
#  'WEST POINT',
#  'CORALVILLE',
#  'WATERLOO',
#  'NEWTON',
#  'TOLEDO',
#  'SIOUX CENTER',
#  'MASON CITY',
#  'MILFORD',
#  'IOWA CITY',
#  'COUNCIL BLUFFS',
#  'GRIMES',
#  'KEOKUK',
#  'INDIANOLA',
#  'FORT DODGE',
#  'DES MOINES',
#  'HUXLEY',
#  'LA PORTE CITY',
#  'MARION',
#  'ANKENY',
#  'DYSART',
#  'EAGLE GROVE',
#  'OGDEN',
#  'MAQUOKETA',
#  'CARROLL',
#  'WEBSTER CITY',
#  'SIOUX CITY',
#  'WASHINGTON',
#  'CHARLES CITY',
#  'MANCHESTER',
#  'SHELDON',
#  'ALTOONA',
#  'STORM LAKE',
#  'GRUNDY CENTER',
#  'SPIRIT LAKE',
#  'DUBUQUE',
#  'STUART',
#  'SCHLESWIG',
#  'MOUNT PLEASANT',
#  'GUTHRIE CENTER',
#  'FORT ATKINSON',
#  'SPENCER',
#  'MUSCATINE',
#  'LENOX',
#  'MISSOURI VALLEY',
#  'IOWA FALLS',
#  'ALGONA',
#  'WAUKEE',
#  'LECLAIRE',
#  'LAMONI',
#  'CLINTON',
#  'PARKERSBURG',
#  'BURLINGTON',
#  'DUNLAP',
#  'ORANGE CITY',
#  'MANNING',
#  'LOHRVILLE',
#  'JOHNSTON',
#  'OELWEIN',
#  'MONTICELLO',
#  'BRITT',
#  'BELLE PLAINE',
#  'WILLIAMSBURG',
#  'NEVADA',
#  'ADEL',
#  'CRESCO',
#  'CENTERVILLE',
#  'FAIRFIELD',
#  'ESTHERVILLE',
#  'MARSHALLTOWN',
#  'WILTON',
#  'SHENANDOAH',
#  'STANWOOD',
#  'CORNING',
#  'SAC CITY',
#  'PLEASANT HILL',
#  'CLIVE',
#  'EVANSDALE',
#  'ONAWA',
#  'TIFFIN',
#  'DECORAH',
#  'PERRY',
#  'WELLMAN',
#  'WAUKON',
#  'ELKADER',
#  'LAKE MILLS',
#  'TRIPOLI',
#  'BOONE',
#  'BAXTER',
#  'GRINNELL',
#  'PELLA',
#  'ANAMOSA',
#  'NORTH LIBERTY',
#  'INDEPENDENCE',
#  'HAMPTON',
#  'MEDIAPOLIS',
#  'CHEROKEE',
#  'HUMBOLDT',
#  'MONONA',
#  'JEFFERSON',
#  'WINDSOR HEIGHTS',
#  'WEST BURLINGTON',
#  'URBANDALE',
#  'OTTUWMA',
#  'KNOXVILLE',
#  'BETTENDORF',
#  'ANTHON',
#  'SIGOURNEY',
#  'FOREST CITY',
#  'LEMARS',
#  'STORY CITY',
#  'ROCK VALLEY',
#  'HARLAN',
#  'WAVERLY',
#  'ALDEN',
#  'CLARKSVILLE',
#  'OSCEOLA',
#  'LE CLAIRE',
#  'MONTEZUMA',
#  'FAIRFAX',
#  'MELCHER-DALLAS',
#  'ARNOLDS PARK',
#  'DENISON',
#  'ELDRIDGE',
#  'EMMETSBURG',
#  'MAPLETON',
#  'ATLANTIC',
#  'KINGSLEY',
#  'WEST LIBERTY',
#  'LOGAN',
#  'LARCHWOOD',
#  'GARNER',
#  'MADRID',
#  'URBANA',
#  'FORT MADISON',
#  'DELAWARE',
#  'MT VERNON',
#  'ROCK RAPIDS',
#  'LAURENS',
#  'CASCADE',
#  'HOLSTEIN',
#  'RAYMOND',
#  'MARENGO',
#  'TIPTON',
#  'CRESTON',
#  'SERGEANT BLUFF',
#  'HAMBURG',
#  'RED OAK',
#  'MT PLEASANT',
#  'DOWS',
#  'COLUMBUS JUNCTION',
#  'CONRAD',
#  'EDDYVILLE',
#  'FONTANELLE',
#  'PRAIRIE CITY',
#  'WEST BRANCH',
#  'SANBORN',
#  'OSAGE',
#  'DENVER',
#  'ELDORA',
#  'PACIFIC JUNCTION',
#  'WINTERSET',
#  'POLK CITY',
#  'MOUNT VERNON',
#  'CLARINDA',
#  'GEORGE',
#  'HAWARDEN',
#  'ELMA',
#  'BLOOMFIELD',
#  'CHARITON',
#  'BROOKLYN',
#  'JESUP',
#  'MONROE',
#  'SOLON',
#  'BELLEVUE',
#  'OAKLAND',
#  'LAKE CITY',
#  'DURANT',
#  'STRAWBERRY POINT',
#  'GREENFIELD',
#  'POCAHONTAS',
#  'WAPELLO',
#  'CAMBRIDGE',
#  'DYERSVILLE',
#  'IDA GROVE',
#  'ELLSWORTH',
#  'GUTTENBURG',
#  'EXIRA',
#  'CORYDON',
#  'ST ANSGAR',
#  'NORWALK',
#  'PRIMGHAR',
#  'LANSING',
#  'LE GRAND',
#  'LAKE PARK',
#  'NEW SHARON',
#  'ACKLEY',
#  'VINTON',
#  'SUTHERLAND',
#  'STRATFORD',
#  'LE MARS',
#  'WESLEY',
#  'AVOCA',
#  'GRANGER',
#  "ARNOLD'S PARK",
#  'SIBLEY',
#  'NEW HAMPTON',
#  'FARMINGTON',
#  'WEST UNION',
#  'NORTHWOOD',
#  'CARTER LAKE',
#  'ALBIA',
#  'BUFFALO CENTER',
#  'BLUE GRASS',
#  'BANCROFT',
#  'GREENE',
#  'WALNUT',
#  'DELMAR',
#  'MALVERN',
#  'HIAWATHA',
#  'GRAND JUNCTION',
#  'GLENWOOD',
#  'COLFAX',
#  'PEOSTA',
#  'FLOYD',
#  'DUMONT',
#  'COON RAPIDS',
#  'PANORA',
#  'MONTROSE',
#  'SIOUX RAPIDS',
#  'CLARION',
#  'RIVERSIDE',
#  'BEVINGTON',
#  'LISBON',
#  'FREDERICKSBURG',
#  'KEOTA',
#  'DE SOTO',
#  'FAIRBANK',
#  'KEOSAUQUA',
#  'HARTLEY',
#  'PLEASANTVILLE',
#  'CENTER POINT',
#  'MANSON',
#  'DANVILLE',
#  'WEST BEND',
#  'ELY',
#  'KELLOGG',
#  'OKOBOJI',
#  'DAKOTA CITY',
#  'POSTVILLE',
#  'LAWLER',
#  'GUTTENBERG',
#  'HARPERS FERRY',
#  'SWISHER',
#  'LAKE VIEW',
#  'PAULLINA',
#  'EDGEWOOD',
#  'CENTRAL CITY',
#  'AKRON',
#  'ALLISON',
#  'LEON',
#  'AFTON',
#  'VICTOR',
#  'INWOOD',
#  'SHEFFIELD',
#  'GOWRIE',
#  'GLIDDEN',
#  'HUDSON',
#  'GRAND MOUND',
#  'GILMORE CITY',
#  'TRAER',
#  'BEDFORD',
#  'FAYETTE',
#  'ELDON',
#  'WOODWARD',
#  'NASHUA',
#  'NEOLA',
#  'GRAETTINGER',
#  'STATE CENTER',
#  'SLOAN',
#  'ROCKWELL',
#  'PRINCETON',
#  'SCRANTON',
#  'ZWINGLE',
#  'ADAIR',
#  'CAMANCHE',
#  'ROLFE',
#  'WOODBINE',
#  'SLATER',
#  'MOUNT AYR',
#  'AUDUBON',
#  'VILLISCA',
#  'LOVILIA',
#  'EARLY',
#  'HUBBARD',
#  'CARLISLE',
#  'BUFFALO',
#  'ANITA',
#  'WINTHROP',
#  'DONNELLSON',
#  'HOLY CROSS',
#  'PALO',
#  'IRETON',
#  'HAZLETON',
#  'CRESCENT',
#  'ROCKWELL CITY',
#  'REMSEN',
#  'ARLINGTON',
#  'MECHANICSVILLE',
#  'DEWITT',
#  'REINBECK',
#  'RUTHVEN',
#  'SULLY',
#  'SPRINGVILLE',
#  'GLADBROOK',
#  'LOST NATION',
#  'EVERLY',
#  'NORA SPRINGS',
#  'COLO',
#  'ST CHARLES',
#  'DAYTON',
#  'BALDWIN',
#  'SWEA CITY',
#  'MAXWELL',
#  'CASEY',
#  'EARLHAM',
#  'BUSSEY',
#  'VAN METER',
#  'WELLSBURG',
#  'NORTH ENGLISH',
#  'MORAVIA',
#  'KELLOG',
#  'RICEVILLE',
#  'MARCUS',
#  'JEWELL',
#  'HOSPERS',
#  'WALL LAKE',
#  'FARLEY',
#  'TREYNOR',
#  'DELHI',
#  'NEW VIRGINIA',
#  'MARTENSDALE',
#  'HUMESTON',
#  'WHEATLAND',
#  'ST LUCAS',
#  'MANLY',
#  'SCHALLER',
#  'LATIMER',
#  'WASHBURN',
#  'CUMMING',
#  'GILBERTVILLE',
#  'WALFORD',
#  'WALKER',
#  'OTHO',
#  'ALTA',
#  'ARMSTRONG',
#  'MINDEN',
#  'TABOR',
#  'FONDA',
#  'AURELIA',
#  'CORWITH',
#  'SEYMOUR',
#  'ROBINS',
#  'GOLDFIELD',
#  'GRISWOLD',
#  'MERRILL',
#  'MELBOURNE',
#  'RUNNELLS']

# %%
# There are some 'City' entries which are in lower case while the majority is in Upper Case. 
# To prevent double counting, all "City" entries are changed to upper case

df['City'] = df['City'].apply(lambda x: x.upper())

# %% [markdown]
# ## Cleaning NaN County entries

# %%
# Create a new dataframe for rows with NaNs in any cells

df_nan = df[pd.isnull(df).any(axis = 1)]

# %%
df_nan.head()
# Out:
#            Date  Store Number          City  Zip Code  County Number County  \
# 135  01/20/2016          5222  CEDAR RAPIDS     52402            NaN    NaN
# 198  03/02/2016          3820    SIOUX CITY     51103            NaN    NaN
# 272  03/21/2016          4222     EVANSDALE     50707            NaN    NaN
# 290  03/21/2016          5236       ANAMOSA     52205            NaN    NaN
# 321  02/23/2016          4203       WAVERLY     50677            NaN    NaN
#
#       Category            Category Name  Vendor Number  Item Number  \
# 135  1051010.0  AMERICAN GRAPE BRANDIES            115        53214
# 198  1032080.0           IMPORTED VODKA             35        34359
# 272  1062300.0             FLAVORED RUM            370        42716
# 290  1081600.0          WHISKEY LIQUEUR            421        64868
# 321  1051100.0         APRICOT BRANDIES            434        55084
#
#                     Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 135  Paul Masson Grande Amber Brandy                 375               3.22
# 198                 Grey Goose Vodka                 200               5.00
# 272               Malibu Coconut Rum                 750               7.49
# 290        Fireball Cinnamon Whiskey                1750              15.33
# 321      Paramount Blackberry Brandy                 375               3.55
#
#      State Bottle Retail  Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 135                 4.83            24          115.92                  9.00
# 198                 7.50            12           90.00                  2.40
# 272                11.24             3           33.72                  2.25
# 290                23.00             6          138.00                 10.50
# 321                 5.33            24          127.92                  9.00
#
#      Volume Sold (Gallons)
# 135                   2.38
# 198                   0.63
# 272                   0.59
# 290                   2.77
# 321                   2.38

# %%
# Printing columns that contain "NaN" and count the number of NaN entries per column

tbc_list = []

for col in df.columns:
    x = sum(pd.isnull(df[col]))
    if x != 0:
        tbc_list.append(col)
        print col, x
# Out:
# County Number 1077
# County 1077
# Category 68
# Category Name 632

# %%
# Some counties and county numbers are not filled.
# Since "City" column does not contain NaN and Cities are a subset of counties,
# we try to see if there are similar cities with non-empty county values which we can then copy to the NaN county cells


# Create a set of Cities with NaN for county or county Number

city_nan_list = list(df_nan['City'].unique())

city_nan_list
# Out:
# ['CEDAR RAPIDS',
#  'SIOUX CITY',
#  'EVANSDALE',
#  'ANAMOSA',
#  'WAVERLY',
#  'HAMPTON',
#  'DES MOINES',
#  'WATERLOO',
#  'BELMOND',
#  'MASON CITY',
#  'CORALVILLE',
#  'DAVENPORT',
#  'SIGOURNEY',
#  'CLINTON',
#  'NORWALK',
#  'SIBLEY',
#  'CLARINDA',
#  'DUBUQUE',
#  'IOWA FALLS',
#  'AMES',
#  'NORTH LIBERTY',
#  'WINDSOR HEIGHTS',
#  'PLEASANTVILLE',
#  'STORM LAKE',
#  'ALTOONA',
#  'WEST BURLINGTON',
#  'MOUNT PLEASANT',
#  'URBANDALE',
#  'DUNLAP',
#  'ATLANTIC',
#  'CHARITON',
#  'ANKENY',
#  'MUSCATINE',
#  'CEDAR FALLS',
#  'CRESCO',
#  'GRINNELL',
#  'WESLEY',
#  'MOUNT VERNON',
#  'COUNCIL BLUFFS',
#  'NORTHWOOD',
#  'ACKLEY',
#  'GREENFIELD',
#  'ROCKWELL',
#  'CLIVE',
#  'JEFFERSON',
#  'BURLINGTON',
#  'HARLAN',
#  'FORT DODGE',
#  'WASHINGTON',
#  'LAMONI',
#  'MARSHALLTOWN',
#  'BOONE',
#  'OELWEIN',
#  'CLEAR LAKE',
#  'ALBIA',
#  'PACIFIC JUNCTION',
#  'WEST BRANCH',
#  'OSKALOOSA',
#  'WEBSTER CITY',
#  'ROCK RAPIDS',
#  'WEST DES MOINES',
#  'OTTUWMA',
#  'NEWTON',
#  'CENTERVILLE',
#  'IOWA CITY',
#  'JOHNSTON',
#  'TABOR',
#  'AUDUBON',
#  'LANSING',
#  'SEYMOUR',
#  'ELKADER',
#  'GUTTENBERG',
#  'CHEROKEE',
#  'FORT MADISON',
#  'DECORAH',
#  'OTTUMWA',
#  'LARCHWOOD',
#  'FAIRFIELD',
#  'MONTICELLO',
#  'INDIANOLA',
#  'TIPTON',
#  'MARION',
#  'PLEASANT HILL',
#  'TOLEDO',
#  'KNOXVILLE',
#  'BETTENDORF',
#  'RED OAK',
#  'DENISON',
#  'OSCEOLA',
#  'ELDRIDGE',
#  'POLK CITY',
#  'ESTHERVILLE',
#  'PERRY',
#  'LATIMER',
#  'SHENANDOAH',
#  'SIOUX CENTER',
#  'SHELLSBURG',
#  'MT PLEASANT',
#  'MILFORD',
#  'RIVERSIDE',
#  'CHARLES CITY',
#  'KEOKUK',
#  'LE CLAIRE',
#  'CARROLL',
#  'INDEPENDENCE',
#  'MOUNT AYR',
#  'PELLA',
#  'RUNNELLS',
#  'EAGLE GROVE',
#  'MISSOURI VALLEY',
#  'SPIRIT LAKE',
#  'SWISHER',
#  'MANCHESTER',
#  'WAUKEE',
#  'GUTHRIE CENTER',
#  'CARLISLE',
#  'NEVADA',
#  'LECLAIRE',
#  'MAQUOKETA',
#  'LEMARS',
#  'ZWINGLE',
#  'ARNOLDS PARK',
#  'DENVER',
#  'HUBBARD',
#  'GRIMES',
#  'HIAWATHA',
#  'ANITA',
#  'ELDORA']

# %%
# Creating a dictionary with "City" as key and collecting all possible corresponding "County" and "County Name"
# as values of the dictionary

nan_cty_dict = {}

for j in city_nan_list:
    c_set = {x for x in df[df['City']==j]['County'] if x > 0} # x > 0 to skip NaN values
    num_set = {x for x in df[df['City']==j]['County Number'] if x > 0}
    nan_cty_dict[j] = [list(c_set), list(num_set)]

nan_cty_dict
# Out:
# {'ACKLEY': [['Webster', 'Hardin'], [42.0, 94.0]],
#  'ALBIA': [['Monroe'], [68.0]],
#  'ALTOONA': [['Polk'], [77.0]],
#  'AMES': [['Story'], [85.0]],
#  'ANAMOSA': [['Jones'], [53.0]],
#  'ANITA': [['Cass'], [15.0]],
#  'ANKENY': [['Polk'], [77.0]],
#  'ARNOLDS PARK': [['Dickinson'], [30.0]],
#  'ATLANTIC': [['Cass'], [15.0]],
#  'AUDUBON': [['Audubon'], [5.0]],
#  'BELMOND': [['Wright'], [99.0]],
#  'BETTENDORF': [['Iowa', 'Scott'], [48.0, 82.0]],
#  'BOONE': [['Boone'], [8.0]],
#  'BURLINGTON': [['Des Moines'], [29.0]],
#  'CARLISLE': [['Warren'], [91.0]],
#  'CARROLL': [['Carroll'], [14.0]],
#  'CEDAR FALLS': [['Black Hawk'], [7.0]],
#  'CEDAR RAPIDS': [['Linn'], [57.0]],
#  'CENTERVILLE': [['Appanoose'], [4.0]],
#  'CHARITON': [['Lucas'], [59.0]],
#  'CHARLES CITY': [['Floyd'], [34.0]],
#  'CHEROKEE': [['Cherokee'], [18.0]],
#  'CLARINDA': [['Page'], [73.0]],
#  'CLEAR LAKE': [['Cerro Gordo'], [17.0]],
#  'CLINTON': [['Clinton'], [23.0]],
#  'CLIVE': [['Polk', 'Dallas'], [25.0, 77.0]],
#  'CORALVILLE': [['Johnson'], [52.0]],
#  'COUNCIL BLUFFS': [['Pottawattamie'], [78.0]],
#  'CRESCO': [['Howard'], [45.0]],
#  'DAVENPORT': [['Scott'], [82.0]],
#  'DECORAH': [['Winneshiek'], [96.0]],
#  'DENISON': [['Crawford'], [24.0]],
#  'DENVER': [['Bremer'], [9.0]],
#  'DES MOINES': [['Polk'], [77.0]],
#  'DUBUQUE': [['Dubuque'], [31.0]],
#  'DUNLAP': [['Harrison'], [43.0]],
#  'EAGLE GROVE': [['Wright'], [99.0]],
#  'ELDORA': [['Hardin'], [42.0]],
#  'ELDRIDGE': [['Scott'], [82.0]],
#  'ELKADER': [['Clayton'], [22.0]],
#  'ESTHERVILLE': [['Emmet'], [32.0]],
#  'EVANSDALE': [['Black Hawk'], [7.0]],
#  'FAIRFIELD': [['Jefferson'], [51.0]],
#  'FORT DODGE': [['Webster', 'Hardin'], [42.0, 94.0]],
#  'FORT MADISON': [['Lee'], [56.0]],
#  'GREENFIELD': [['Adair'], [1.0]],
#  'GRIMES': [['Polk'], [77.0]],
#  'GRINNELL': [['Poweshiek'], [79.0]],
#  'GUTHRIE CENTER': [['Guthrie'], [39.0]],
#  'GUTTENBERG': [['Clayton'], [22.0]],
#  'HAMPTON': [['Franklin'], [35.0]],
#  'HARLAN': [['Shelby'], [83.0]],
#  'HIAWATHA': [['Linn'], [57.0]],
#  'HUBBARD': [['Hardin'], [42.0]],
#  'INDEPENDENCE': [['Buchanan'], [10.0]],
#  'INDIANOLA': [['Warren'], [91.0]],
#  'IOWA CITY': [['Johnson'], [52.0]],
#  'IOWA FALLS': [['Hardin'], [42.0]],
#  'JEFFERSON': [['Greene'], [37.0]],
#  'JOHNSTON': [['Polk'], [77.0]],
#  'KEOKUK': [['Lee'], [56.0]],
#  'KNOXVILLE': [['Marion'], [63.0]],
#  'LAMONI': [['Decatur'], [27.0]],
#  'LANSING': [['Allamakee'], [3.0]],
#  'LARCHWOOD': [['Lyon'], [60.0]],
#  'LATIMER': [['Franklin'], [35.0]],
#  'LE CLAIRE': [['Scott'], [82.0]],
#  'LECLAIRE': [['Scott'], [82.0]],
#  'LEMARS': [['Plymouth'], [75.0]],
#  'MANCHESTER': [['Delaware'], [28.0]],
#  'MAQUOKETA': [['Jackson'], [49.0]],
#  'MARION': [['Linn'], [57.0]],
#  'MARSHALLTOWN': [['Marshall'], [64.0]],
#  'MASON CITY': [['Cerro Gordo'], [17.0]],
#  'MILFORD': [['Dickinson'], [30.0]],
#  'MISSOURI VALLEY': [['Harrison'], [43.0]],
#  'MONTICELLO': [['Jones'], [53.0]],
#  'MOUNT AYR': [['Ringgold'], [80.0]],
#  'MOUNT PLEASANT': [['Henry'], [44.0]],
#  'MOUNT VERNON': [['Linn'], [57.0]],
#  'MT PLEASANT': [['Henry'], [44.0]],
#  'MUSCATINE': [['Muscatine'], [70.0]],
#  'NEVADA': [['Story'], [85.0]],
#  'NEWTON': [['Webster', 'Jasper'], [50.0, 94.0]],
#  'NORTH LIBERTY': [['Iowa', 'Johnson'], [48.0, 52.0]],
#  'NORTHWOOD': [['Worth'], [98.0]],
#  'NORWALK': [['Warren'], [91.0]],
#  'OELWEIN': [['Fayette'], [33.0]],
#  'OSCEOLA': [['Clarke'], [20.0]],
#  'OSKALOOSA': [['Buchanan', 'Mahaska'], [10.0, 62.0]],
#  'OTTUMWA': [['Wapello'], [90.0]],
#  'OTTUWMA': [['Wapello'], [90.0]],
#  'PACIFIC JUNCTION': [['Mills'], [65.0]],
#  'PELLA': [['Marion'], [63.0]],
#  'PERRY': [['Boone', 'Dallas'], [8.0, 25.0]],
#  'PLEASANT HILL': [['Polk'], [77.0]],
#  'PLEASANTVILLE': [['Marion'], [63.0]],
#  'POLK CITY': [['Polk'], [77.0]],
#  'RED OAK': [['Montgomery'], [69.0]],
#  'RIVERSIDE': [['Washington'], [92.0]],
#  'ROCK RAPIDS': [['Lyon'], [60.0]],
#  'ROCKWELL': [['Cerro Gordo'], [17.0]],
#  'RUNNELLS': [[], []],
#  'SEYMOUR': [[], []],
#  'SHELLSBURG': [['Benton'], [6.0]],
#  'SHENANDOAH': [['Page'], [73.0]],
#  'SIBLEY': [['Osceola'], [72.0]],
#  'SIGOURNEY': [['Keokuk'], [54.0]],
#  'SIOUX CENTER': [['Sioux'], [84.0]],
#  'SIOUX CITY': [['Woodbury'], [97.0]],
#  'SPIRIT LAKE': [['Dickinson'], [30.0]],
#  'STORM LAKE': [['Buena Vista'], [11.0]],
#  'SWISHER': [['Johnson'], [52.0]],
#  'TABOR': [[], []],
#  'TIPTON': [['Cedar'], [16.0]],
#  'TOLEDO': [['Tama'], [86.0]],
#  'URBANDALE': [['Polk'], [77.0]],
#  'WASHINGTON': [['Washington'], [92.0]],
#  'WATERLOO': [['Black Hawk'], [7.0]],
#  'WAUKEE': [['Dallas'], [25.0]],
#  'WAVERLY': [['Bremer'], [9.0]],
#  'WEBSTER CITY': [['Hamilton'], [40.0]],
#  'WESLEY': [['Kossuth'], [55.0]],
#  'WEST BRANCH': [['Cedar'], [16.0]],
#  'WEST BURLINGTON': [['Des Moines'], [29.0]],
#  'WEST DES MOINES': [['Polk', 'Dallas'], [25.0, 77.0]],
#  'WINDSOR HEIGHTS': [['Polk'], [77.0]],
#  'ZWINGLE': [['Jackson'], [49.0]]}

# %%
## Replacing NaN county cells using corresponding city value as key

for cty in nan_cty_dict:
    try:
        df.loc[df['City'] == cty, 'County'] = nan_cty_dict[cty][0][0]
        df.loc[df['City'] == cty, "County Number"] = nan_cty_dict[cty][1][0]
    except:
        pass

# %%
# Recreate a new df to check remaining NaN row
df_nan = df[pd.isnull(df[['County','County Number']]).any(axis = 1)]

# %%
# Collect cities with NaN values
city_nan_list = list(df_nan['City'].unique())

city_nan_list
# Out:
# ['TABOR', 'SEYMOUR', 'RUNNELLS']

# %%
nan_cty_dict = {}

for j in city_nan_list:
    c_set = {x for x in df[df['City']==j]['County']} # x > 0 to skip NaN values
    num_set = {x for x in df[df['City']==j]['County Number']}
    nan_cty_dict[j] = [list(c_set), list(num_set)]

nan_cty_dict
# Out:
# {'RUNNELLS': [[nan], [nan, nan, nan]],
#  'SEYMOUR': [[nan], [nan, nan, nan, nan, nan, nan]],
#  'TABOR': [[nan], [nan, nan, nan]]}

# %%
# Updating counties by hand

df.loc[df['City'] == 'TABOR', 'County'] = 'Fremont'
df.loc[df['City'] == 'RUNNELLS', 'County'] = 'Polk'
df.loc[df['City'] == 'SEYMOUR', 'County'] = 'Wayne'

# %%
# Recreate a new df to check remaining NaN row
df_nan = df[pd.isnull(df['County'])]

# %%
len(df_nan)
# Out:
# 0

# %% [markdown]
# #### Comments:
#
# Remaining 12 rows with empty counties were filled manually. Without a reference of how county numbers were developed, we left the empty county numbers empty. Analyses based on counties will be performed on 'County' instead of 'County Number'.

# %% [markdown]
# # ---------------------------------------------------------------

# %% [markdown]
# ## Cleaning Empty Category Name using Item Decription

# %%
df_nan = df[pd.isnull(df['Category Name'])]
print len(df_nan)
df_nan
# Out:
# 632
#               Date  Store Number             City  Zip Code  County Number  \
# 896     02/05/2015          4829       DES MOINES     50314           77.0
# 901     02/25/2016          4647         WATERLOO     50707            7.0
# 1514    02/18/2016          2515       MASON CITY     50401           17.0
# 1684    02/08/2016          3747        SIGOURNEY     52591           54.0
# 2203    02/16/2016          4589           SIBLEY     51249           72.0
# 2894    02/09/2016          2413          DUBUQUE     52001           31.0
# 3071    02/15/2016          2539       IOWA FALLS     50126           42.0
# 3482    02/10/2016          3524             AMES     50010           85.0
# 4596    02/03/2016          2594       SIOUX CITY     51106           97.0
# 4989    02/23/2016          2620  WINDSOR HEIGHTS     50311           77.0
# 5372    02/16/2016          2465          DUBUQUE     52003           31.0
# 6193    02/10/2016          2576       STORM LAKE     50588           11.0
# 6258    02/24/2016          5131       DES MOINES     50316           77.0
# 6744    11/16/2015          4857  WEST BURLINGTON     52655           29.0
# 7473    02/17/2016          2500             AMES     50010           85.0
# 8080    02/22/2016          2558   MOUNT PLEASANT     52641           44.0
# 8154    02/25/2016          2663        URBANDALE     50322           77.0
# 8992    02/18/2016          2190       DES MOINES     50314           77.0
# 9456    02/11/2016          2663        URBANDALE     50322           77.0
# 10629   02/24/2016          2502           ANKENY     50021           77.0
# 11241   10/27/2015          3625           ANKENY     50021           77.0
# 11513   02/22/2016          3563        MUSCATINE     52761           70.0
# 12230   02/15/2016          2647     CEDAR RAPIDS     52411           57.0
# 12317   02/16/2016          2854        URBANDALE     50323           77.0
# 12400   02/17/2016          4640        DAVENPORT     52807           82.0
# 12774   02/17/2016          2572      CEDAR FALLS     50613            7.0
# 12984   02/03/2016          4162     CEDAR RAPIDS     52404           57.0
# 13158   02/17/2016          5131       DES MOINES     50316           77.0
# 13803   02/11/2016          2579         GRINNELL     50112           79.0
# 13931   02/09/2016          4015             AMES     50010           85.0
# ...            ...           ...              ...       ...            ...
# 256674  11/23/2015          3869       CORALVILLE     52241           52.0
# 256784  02/17/2016          3447       SIOUX CITY     51106           97.0
# 256902  02/15/2016          2190       DES MOINES     50314           77.0
# 257455  02/22/2016          3591           ACKLEY     50601           42.0
# 257708  09/10/2015          4829       DES MOINES     50314           77.0
# 257886  02/16/2016          4167          DUBUQUE     52001           31.0
# 259398  02/22/2016          2560           MARION     52302           57.0
# 260315  02/15/2016          2527       DES MOINES     50315           77.0
# 260362  02/02/2016          4446        URBANDALE     50322           77.0
# 262574  02/25/2016          2190       DES MOINES     50314           77.0
# 262677  02/09/2016          3477   COUNCIL BLUFFS     51501           78.0
# 262757  02/08/2016          2569     CEDAR RAPIDS     52402           57.0
# 264022  02/16/2016          5166     MARSHALLTOWN     50158           64.0
# 264881  02/01/2016          2588     CEDAR RAPIDS     52403           57.0
# 264895  02/10/2016          2501             AMES     50010           85.0
# 265388  02/10/2016          5225    NORTH LIBERTY     52317           48.0
# 265671  02/08/2016          2591         ATLANTIC     50022           15.0
# 265898  02/15/2016          4250           ELDORA     50627           42.0
# 265904  02/18/2016          2248       DES MOINES     50312           77.0
# 266646  12/17/2015          2633       DES MOINES     50320           77.0
# 266852  02/23/2016          4167          DUBUQUE     52001           31.0
# 267727  02/23/2016          4712          DUBUQUE     52001           31.0
# 268016  02/17/2016          2596          OTTUMWA     52501           90.0
# 268130  02/22/2016          4794       BURLINGTON     52601           29.0
# 269457  10/19/2015          2633       DES MOINES     50320           77.0
# 269751  02/17/2016          5128       DES MOINES     50310           77.0
# 269885  02/04/2016          4648         WATERLOO     50703            7.0
# 269953  11/30/2015          4229           HARLAN     51537           83.0
# 270046  02/17/2016          2637        DAVENPORT     52804           82.0
# 270654  02/17/2016          2572      CEDAR FALLS     50613            7.0
#
#                County   Category Category Name  Vendor Number  Item Number  \
# 896              Polk  1022200.0           NaN             85         3657
# 901        Black Hawk  1052100.0           NaN            420        48099
# 1514      Cerro Gordo  1082100.0           NaN            420        67487
# 1684           Keokuk  1052100.0           NaN            420        48106
# 2203          Osceola  1032100.0           NaN            115        34821
# 2894          Dubuque  1082100.0           NaN            130        64136
# 3071           Hardin  1052100.0           NaN            420        48106
# 3482            Story  1032100.0           NaN            115        34821
# 4596         Woodbury  1052100.0           NaN            420        48099
# 4989             Polk  1091100.0           NaN            208        27439
# 5372          Dubuque  1052100.0           NaN            420        48106
# 6193      Buena Vista  1032100.0           NaN            115        34820
# 6258             Polk  1052100.0           NaN            420        48099
# 6744       Des Moines        NaN           NaN             85          333
# 7473            Story  1052100.0           NaN            420        48099
# 8080            Henry  1091100.0           NaN            208        27439
# 8154             Polk  1052100.0           NaN            420        48105
# 8992             Polk  1052100.0           NaN            420        48105
# 9456             Polk  1052100.0           NaN            420        48099
# 10629            Polk  1062500.0           NaN            260        43299
# 11241            Polk        NaN           NaN            259        59100
# 11513       Muscatine  1052100.0           NaN            420        48106
# 12230            Linn  1082100.0           NaN            420        65126
# 12317            Polk  1082100.0           NaN            130        64136
# 12400           Scott  1052100.0           NaN            420        48106
# 12774      Black Hawk  1091300.0           NaN            346        86749
# 12984            Linn  1082200.0           NaN            421        69713
# 13158            Polk  1052100.0           NaN            420        48106
# 13803       Poweshiek  1082100.0           NaN            305        65017
# 13931           Story  1032100.0           NaN            115        34820
# ...               ...        ...           ...            ...          ...
# 256674        Johnson        NaN           NaN            255          297
# 256784       Woodbury  1052100.0           NaN            420        48106
# 256902           Polk  1082100.0           NaN             35        47863
# 257455        Webster  1082100.0           NaN            130        64136
# 257708           Polk  1022200.0           NaN             85         3657
# 257886        Dubuque  1052100.0           NaN            420        48099
# 259398           Linn  1091100.0           NaN            208        27439
# 260315           Polk  1032100.0           NaN            277        34746
# 260362           Polk  1052100.0           NaN            420        48105
# 262574           Polk  1032100.0           NaN            115        34820
# 262677  Pottawattamie  1032100.0           NaN            115        34821
# 262757           Linn  1032100.0           NaN            115        34821
# 264022       Marshall  1052100.0           NaN            420        48154
# 264881           Linn  1052100.0           NaN            420        48106
# 264895          Story  1032100.0           NaN            115        34821
# 265388           Iowa  1032100.0           NaN            115        34817
# 265671           Cass  1082100.0           NaN            420        65127
# 265898         Hardin  1032100.0           NaN            115        34821
# 265904           Polk  1052100.0           NaN            420        48105
# 266646           Polk  1091100.0           NaN            434       933934
# 266852        Dubuque  1052100.0           NaN            420        48105
# 267727        Dubuque  1052100.0           NaN            420        48105
# 268016        Wapello  1052100.0           NaN            420        48106
# 268130     Des Moines  1032100.0           NaN            277        34746
# 269457           Polk  1022200.0           NaN             85         3657
# 269751           Polk  1032100.0           NaN            115        34821
# 269885     Black Hawk  1052100.0           NaN            420        48106
# 269953         Shelby        NaN           NaN            255          297
# 270046          Scott  1082100.0           NaN            420        65126
# 270654     Black Hawk  1032100.0           NaN            277        34746
#
#                                          Item Description  Bottle Volume (ml)  \
# 896                          Herradura Gold Reposado 6pak                 750
# 901                                           Hennessy VS                 200
# 1514                        Grand Marnier Raspberry Peach                 750
# 1684                                   Hennessy Vs Cognac                 750
# 2203                                         Svedka Vodka                1750
# 2894                                   Disaronno Amaretto                 750
# 3071                                   Hennessy Vs Cognac                 750
# 3482                                         Svedka Vodka                1750
# 4596                                          Hennessy VS                 200
# 4989                         Tim Smith's Climax Moonshine                 750
# 5372                                   Hennessy Vs Cognac                 750
# 6193                                         Svedka Vodka                 750
# 6258                                          Hennessy VS                 200
# 6744    Jack Daniels TN Honey & Jack Daniels TN Fire 7...                1500
# 7473                                          Hennessy VS                 200
# 8080                         Tim Smith's Climax Moonshine                 750
# 8154                                          Hennessy VS                 375
# 8992                                          Hennessy VS                 375
# 9456                                          Hennessy VS                 200
# 10629                              Captain Morgan Coconut                 750
# 11241                               Evan Williams Egg Nog                 750
# 11513                                  Hennessy Vs Cognac                 750
# 12230                          Grand Marnier Cordon Rouge                 750
# 12317                                  Disaronno Amaretto                 750
# 12400                                  Hennessy Vs Cognac                 750
# 12774                          Ole Smoky Cherry Moonshine                 750
# 12984                       Dr. McGillicuddy's Peach Mini                 500
# 13158                                  Hennessy Vs Cognac                 750
# 13803                                    Galliano Liqueur                 375
# 13931                                        Svedka Vodka                 750
# ...                                                   ...                 ...
# 256674                              Templeton Rye w/Flask                 750
# 256784                                 Hennessy Vs Cognac                 750
# 256902                                        D'usse VSOP                 375
# 257455                                 Disaronno Amaretto                 750
# 257708                       Herradura Gold Reposado 6pak                 750
# 257886                                        Hennessy VS                 200
# 259398                       Tim Smith's Climax Moonshine                 750
# 260315                   Stolichnaya Premium Vodka 80 Prf                 750
# 260362                                        Hennessy VS                 375
# 262574                                       Svedka Vodka                 750
# 262677                                       Svedka Vodka                1750
# 262757                                       Svedka Vodka                1750
# 264022                                     Hennessy Black                 375
# 264881                                 Hennessy Vs Cognac                 750
# 264895                                       Svedka Vodka                1750
# 265388                                             Svedka                 375
# 265671                         Grand Marnier Cordon Rouge                1000
# 265898                                       Svedka Vodka                1750
# 265904                                        Hennessy VS                 375
# 266646                                      Pearl Caramel                1000
# 266852                                        Hennessy VS                 375
# 267727                                        Hennessy VS                 375
# 268016                                 Hennessy Vs Cognac                 750
# 268130                   Stolichnaya Premium Vodka 80 Prf                 750
# 269457                       Herradura Gold Reposado 6pak                 750
# 269751                                       Svedka Vodka                1750
# 269885                                 Hennessy Vs Cognac                 750
# 269953                              Templeton Rye w/Flask                 750
# 270046                         Grand Marnier Cordon Rouge                 750
# 270654                   Stolichnaya Premium Vodka 80 Prf                 750
#
#         State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 896                 23.58                35.37             6          212.22
# 901                  5.74                 8.61            24          206.64
# 1514                23.31                34.97             2           69.94
# 1684                18.99                28.49             2           56.98
# 2203                14.74                22.11             2           44.22
# 2894                13.86                20.79            12          249.48
# 3071                18.99                28.49             3           85.47
# 3482                14.74                22.11             6          132.66
# 4596                 5.74                 8.61             1            8.61
# 4989                17.50                26.25             6          157.50
# 5372                18.99                28.49             4          113.96
# 6193                 8.25                12.38             3           37.14
# 6258                 5.74                 8.61            24          206.64
# 6744                15.07                22.61             1           22.61
# 7473                 5.74                 8.61             6           51.66
# 8080                17.50                26.25             6          157.50
# 8154                 9.99                14.99             6           89.94
# 8992                 9.99                14.99            24          359.76
# 9456                 5.74                 8.61            12          103.32
# 10629                8.50                12.75             3           38.25
# 11241                4.46                 6.69            10           66.90
# 11513               18.99                28.49            12          341.88
# 12230               23.31                34.97             2           69.94
# 12317               13.86                20.79             6          124.74
# 12400               18.99                28.49            12          341.88
# 12774               11.00                16.50             3           49.50
# 12984                4.96                 7.44            12           89.28
# 13158               18.99                28.49            12          341.88
# 13803               10.75                16.13             1           16.13
# 13931                8.25                12.38            12          148.56
# ...                   ...                  ...           ...             ...
# 256674              18.09                27.14             3           81.42
# 256784              18.99                28.49            24          683.76
# 256902              16.34                24.51             2           49.02
# 257455              13.86                20.79             2           41.58
# 257708              23.58                35.37             6          212.22
# 257886               5.74                 8.61            72          619.92
# 259398              17.50                26.25             6          157.50
# 260315              11.99                17.99             2           35.98
# 260362               9.99                14.99             2           29.98
# 262574               8.25                12.38             1           12.38
# 262677              14.74                22.11             6          132.66
# 262757              14.74                22.11             6          132.66
# 264022              12.49                18.74             2           37.48
# 264881              18.99                28.49             3           85.47
# 264895              14.74                22.11             6          132.66
# 265388               4.76                 7.14            12           85.68
# 265671              25.55                38.33             4          153.32
# 265898              14.74                22.11             6          132.66
# 265904               9.99                14.99             4           59.96
# 266646               8.67                13.01            24          312.24
# 266852               9.99                14.99            72         1079.28
# 267727               9.99                14.99             2           29.98
# 268016              18.99                28.49             1           28.49
# 268130              11.99                17.99            12          215.88
# 269457              23.58                35.37             6          212.22
# 269751              14.74                22.11             6          132.66
# 269885              18.99                28.49            12          341.88
# 269953              18.09                27.14            12          325.68
# 270046              23.31                34.97             4          139.88
# 270654              11.99                17.99             2           35.98
#
#         Volume Sold (Liters)  Volume Sold (Gallons)
# 896                     4.50                   1.19
# 901                     4.80                   1.27
# 1514                    1.50                   0.40
# 1684                    1.50                   0.40
# 2203                    3.50                   0.92
# 2894                    9.00                   2.38
# 3071                    2.25                   0.59
# 3482                   10.50                   2.77
# 4596                    0.20                   0.05
# 4989                    4.50                   1.19
# 5372                    3.00                   0.79
# 6193                    2.25                   0.59
# 6258                    4.80                   1.27
# 6744                    1.50                   0.40
# 7473                    1.20                   0.32
# 8080                    4.50                   1.19
# 8154                    2.25                   0.59
# 8992                    9.00                   2.38
# 9456                    2.40                   0.63
# 10629                   2.25                   0.59
# 11241                   7.50                   1.98
# 11513                   9.00                   2.38
# 12230                   1.50                   0.40
# 12317                   4.50                   1.19
# 12400                   9.00                   2.38
# 12774                   2.25                   0.59
# 12984                   6.00                   1.59
# 13158                   9.00                   2.38
# 13803                   0.38                   0.10
# 13931                   9.00                   2.38
# ...                      ...                    ...
# 256674                  2.25                   0.59
# 256784                 18.00                   4.76
# 256902                  0.75                   0.20
# 257455                  1.50                   0.40
# 257708                  4.50                   1.19
# 257886                 14.40                   3.80
# 259398                  4.50                   1.19
# 260315                  1.50                   0.40
# 260362                  0.75                   0.20
# 262574                  0.75                   0.20
# 262677                 10.50                   2.77
# 262757                 10.50                   2.77
# 264022                  0.75                   0.20
# 264881                  2.25                   0.59
# 264895                 10.50                   2.77
# 265388                  4.50                   1.19
# 265671                  4.00                   1.06
# 265898                 10.50                   2.77
# 265904                  1.50                   0.40
# 266646                 24.00                   6.34
# 266852                 27.00                   7.13
# 267727                  0.75                   0.20
# 268016                  0.75                   0.20
# 268130                  9.00                   2.38
# 269457                  4.50                   1.19
# 269751                 10.50                   2.77
# 269885                  9.00                   2.38
# 269953                  9.00                   2.38
# 270046                  3.00                   0.79
# 270654                  1.50                   0.40
#
# [632 rows x 18 columns]

# %%
# Create a list of "Item Description" with NaN in rows
item_nan_list = list(df_nan['Item Description'].unique())

item_nan_list
# Out:
# ['Herradura Gold Reposado 6pak',
#  'Hennessy VS',
#  'Grand Marnier Raspberry Peach',
#  'Hennessy Vs Cognac',
#  'Svedka Vodka',
#  'Disaronno Amaretto',
#  "Tim Smith's Climax Moonshine",
#  'Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls',
#  'Captain Morgan Coconut',
#  'Evan Williams Egg Nog',
#  'Grand Marnier Cordon Rouge',
#  'Ole Smoky Cherry Moonshine',
#  "Dr. McGillicuddy's Peach Mini",
#  'Galliano Liqueur',
#  'Grey Goose w/2 Martini Glasses',
#  'Exotico Blanco',
#  'Disaronno Amaretto Cavalli Mignon 3-50ml Pack',
#  '1800 Silver',
#  'Hennessy Black',
#  'Hennessy Vs Cognac 100ml',
#  'Captain Morgan Grapefruit',
#  'Tres Generaciones Anejo',
#  'Stolichnaya Premium Vodka 80 Proof (lv)',
#  'Bombay Sapphire w/Glass',
#  'Three Olives Cake Flavored Vodka',
#  'Captain Morgan Pineapple',
#  "Gosling's Black Seal",
#  'Blue Chair Bay Coconut',
#  'Licor 43',
#  'Rondiaz Rum Spiced',
#  'Stolichnaya Premium Vodka 80 Prf',
#  'Olmeca Altos Reposado',
#  "Dr. McGillicuddy's Apple Pie Mini",
#  'Exotico Reposado',
#  'Domaine de Canton',
#  'Blue Chair Bay Coconut Spiced',
#  'Pinnacle Candy Cane Trial Pack',
#  'Sauza Cien Anos Reposado',
#  'Hennessy VSOP Privilege',
#  'American Born Moonshine Original',
#  'Wild Turkey American Honey Shot Tap',
#  "D'usse VSOP",
#  'Leblon Cachaca',
#  'Woodford Reserve MC 1838 White Corn',
#  "Dr. McGillicuddy's Peach",
#  'Rothman & Winter Orchard Peach',
#  'La Collection Santa Claus',
#  'Stolichnaya Russian Vodka 80 Prf',
#  'Templeton Rye w/Flask',
#  'Captain Morgan Coconut Mini',
#  'Il Tramonto Limoncello',
#  'Blue Chair Bay Banana',
#  'Remy Martin VSOP',
#  'Rondiaz Rum Spiced Black Cherry Mini',
#  'Glenfiddich 1963 Replica HA',
#  'Ricura Mini',
#  'Gentleman Jack w/2 Glasses',
#  'Parkers Heritage Collection Malt Whiskey HA',
#  'Absolut w/Ginger Beer',
#  'High Stick Vodka',
#  'Passoa Liqueur',
#  'Ciroc Ten HA',
#  'Belvedere Vodka',
#  'Belvedere Intense Unfiltered',
#  'Svedka',
#  'Captain Morgan Pineapple Mini',
#  'Knob Creek w/ Crystal Decanter',
#  'Crystal Head Aurora Vodka',
#  'Southern Comfort w/Shot Glass & Lanyard',
#  'Giffard Creme de Pamplemousse Rose Pink Grapefruit Liqueur',
#  'Casa Noble Reposado',
#  'Peligroso Silver',
#  'Rondiaz Mini',
#  'Courvoisier Vsop Cognac',
#  'American Born Moonshine Apple Pie',
#  'Pearl Caramel']

# %%
item_dict = {}

for j in item_nan_list:
    c_set = {x for x in df[df['Item Description']==j]['Category Name'] if x > 0}
    item_dict[j] = list(c_set)

item_dict
# Out:
# {'1800 Silver': ['TEQUILA'],
#  'Absolut w/Ginger Beer': [],
#  'American Born Moonshine Apple Pie': ['DISTILLED SPIRITS SPECIALTY'],
#  'American Born Moonshine Original': ['DISTILLED SPIRITS SPECIALTY'],
#  'Belvedere Intense Unfiltered': ['IMPORTED VODKA'],
#  'Belvedere Vodka': ['IMPORTED VODKA'],
#  'Blue Chair Bay Banana': ['BARBADOS RUM', 'FLAVORED RUM'],
#  'Blue Chair Bay Coconut': ['BARBADOS RUM', 'FLAVORED RUM'],
#  'Blue Chair Bay Coconut Spiced': ['BARBADOS RUM', 'FLAVORED RUM'],
#  'Bombay Sapphire w/Glass': [],
#  'Captain Morgan Coconut': ['FLAVORED RUM'],
#  'Captain Morgan Coconut Mini': ['FLAVORED RUM'],
#  'Captain Morgan Grapefruit': ['FLAVORED RUM'],
#  'Captain Morgan Pineapple': ['FLAVORED RUM'],
#  'Captain Morgan Pineapple Mini': ['FLAVORED RUM'],
#  'Casa Noble Reposado': ['TEQUILA'],
#  'Ciroc Ten HA': [],
#  'Courvoisier Vsop Cognac': ['IMPORTED GRAPE BRANDIES'],
#  'Crystal Head Aurora Vodka': ['DECANTERS & SPECIALTY PACKAGES'],
#  "D'usse VSOP": ['IMPORTED GRAPE BRANDIES',
#   'MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Disaronno Amaretto': ['MISC. IMPORTED CORDIALS & LIQUEURS',
#   'IMPORTED AMARETTO'],
#  'Disaronno Amaretto Cavalli Mignon 3-50ml Pack': ['DECANTERS & SPECIALTY PACKAGES'],
#  'Domaine de Canton': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  "Dr. McGillicuddy's Apple Pie Mini": ['IMPORTED SCHNAPPS',
#   'MISC. IMPORTED CORDIALS & LIQUEURS'],
#  "Dr. McGillicuddy's Peach": ['IMPORTED SCHNAPPS'],
#  "Dr. McGillicuddy's Peach Mini": ['IMPORTED SCHNAPPS'],
#  'Evan Williams Egg Nog': [],
#  'Exotico Blanco': ['TEQUILA'],
#  'Exotico Reposado': ['TEQUILA'],
#  'Galliano Liqueur': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Gentleman Jack w/2 Glasses': ['DECANTERS & SPECIALTY PACKAGES'],
#  'Giffard Creme de Pamplemousse Rose Pink Grapefruit Liqueur': [],
#  'Glenfiddich 1963 Replica HA': [],
#  "Gosling's Black Seal": ['FLAVORED RUM'],
#  'Grand Marnier Cordon Rouge': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Grand Marnier Raspberry Peach': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Grey Goose w/2 Martini Glasses': ['DECANTERS & SPECIALTY PACKAGES'],
#  'Hennessy Black': ['IMPORTED GRAPE BRANDIES'],
#  'Hennessy VS': ['IMPORTED GRAPE BRANDIES'],
#  'Hennessy VSOP Privilege': ['IMPORTED GRAPE BRANDIES',
#   'MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Hennessy Vs Cognac': ['IMPORTED GRAPE BRANDIES'],
#  'Hennessy Vs Cognac 100ml': ['IMPORTED GRAPE BRANDIES'],
#  'Herradura Gold Reposado 6pak': ['TEQUILA'],
#  'High Stick Vodka': [],
#  'Il Tramonto Limoncello': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls': [],
#  'Knob Creek w/ Crystal Decanter': [],
#  'La Collection Santa Claus': ['IMPORTED VODKA'],
#  'Leblon Cachaca': ['DISTILLED SPIRITS SPECIALTY'],
#  'Licor 43': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Ole Smoky Cherry Moonshine': ['DISTILLED SPIRITS SPECIALTY'],
#  'Olmeca Altos Reposado': ['TEQUILA'],
#  'Parkers Heritage Collection Malt Whiskey HA': [],
#  'Passoa Liqueur': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Pearl Caramel': [],
#  'Peligroso Silver': ['TEQUILA'],
#  'Pinnacle Candy Cane Trial Pack': [],
#  'Remy Martin VSOP': ['IMPORTED GRAPE BRANDIES'],
#  'Ricura Mini': ['MISC. AMERICAN CORDIALS & LIQUEURS'],
#  'Rondiaz Mini': ['SPICED RUM'],
#  'Rondiaz Rum Spiced': ['SPICED RUM'],
#  'Rondiaz Rum Spiced Black Cherry Mini': ['SPICED RUM'],
#  'Rothman & Winter Orchard Peach': [],
#  'Sauza Cien Anos Reposado': ['TEQUILA'],
#  'Southern Comfort w/Shot Glass & Lanyard': ['DECANTERS & SPECIALTY PACKAGES'],
#  'Stolichnaya Premium Vodka 80 Prf': ['IMPORTED VODKA'],
#  'Stolichnaya Premium Vodka 80 Proof (lv)': ['IMPORTED VODKA'],
#  'Stolichnaya Russian Vodka 80 Prf': ['IMPORTED VODKA'],
#  'Svedka': ['IMPORTED VODKA'],
#  'Svedka Vodka': ['IMPORTED VODKA'],
#  'Templeton Rye w/Flask': ['DECANTERS & SPECIALTY PACKAGES'],
#  'Three Olives Cake Flavored Vodka': ['IMPORTED VODKA - MISC'],
#  "Tim Smith's Climax Moonshine": ['DISTILLED SPIRITS SPECIALTY'],
#  'Tres Generaciones Anejo': ['TEQUILA'],
#  'Wild Turkey American Honey Shot Tap': [],
#  'Woodford Reserve MC 1838 White Corn': []}

# %%
for drink in item_dict:
    try:
        df.loc[df['Item Description'] == drink, 'Category Name'] = item_dict[drink][0]
    except:
        pass

# %%
df_nan = df[pd.isnull(df['Category Name'])]
print len(df_nan)
df_nan
# Out:
# 46
#               Date  Store Number             City  Zip Code  County Number  \
# 6744    11/16/2015          4857  WEST BURLINGTON     52655           29.0
# 11241   10/27/2015          3625           ANKENY     50021           77.0
# 18996   11/19/2015          3664        NORTHWOOD     50459           98.0
# 24190   10/20/2015          5097     CEDAR RAPIDS     52402           57.0
# 29798   10/12/2015          2643         WATERLOO     50701            7.0
# 34063   10/13/2015          2666           ANKENY     50023           77.0
# 44595   10/28/2015          2513        IOWA CITY     52240           52.0
# 48348   11/18/2015          3735        OSKALOOSA     52577           10.0
# 49712   10/12/2015          3833         ATLANTIC     50022           15.0
# 53329   10/13/2015          2597         CHEROKEE     51012           18.0
# 54674   10/13/2015          2552     CEDAR RAPIDS     52404           57.0
# 55347   11/16/2015          2584     FORT MADISON     52627           56.0
# 57995   10/14/2015          3819          DECORAH     52101           96.0
# 59896   04/06/2015          2601        FAIRFIELD     52556           51.0
# 60370   10/26/2015          3628     CEDAR RAPIDS     52402           57.0
# 67879   10/27/2015          2544     MARSHALLTOWN     50158           64.0
# 69822   10/12/2015          3868           MARION     52302           57.0
# 85858   11/19/2015          3732         ELDRIDGE     52748           82.0
# 87425   11/16/2015          4910         WATERLOO     50702            7.0
# 89897   08/10/2015          3549     FORT MADISON     52627           56.0
# 91043   02/08/2016          4604           NEWTON     50208           50.0
# 91606   07/13/2015          5102     MOUNT VERNON     52314           57.0
# 93441   10/12/2015          4114         ATLANTIC     50022           15.0
# 98880   09/23/2015          4677       CORALVILLE     52241           52.0
# 99045   12/07/2015          3385     CEDAR RAPIDS     52402           57.0
# 100333  01/12/2016          2666           ANKENY     50023           77.0
# 101633  10/12/2015          3790      MT PLEASANT     52641           44.0
# 102627  10/12/2015          4098       WASHINGTON     52353           92.0
# 105372  07/15/2015          3926        IOWA CITY     52240           52.0
# 138964  10/28/2015          2637        DAVENPORT     52804           82.0
# 142979  11/09/2015          2653       WASHINGTON     52353           92.0
# 147629  11/02/2015          2653       WASHINGTON     52353           92.0
# 178003  10/12/2015          2648  WEST DES MOINES     50265           25.0
# 178533  10/14/2015          4947      CEDAR FALLS     50647            7.0
# 191577  08/25/2015          2665           WAUKEE     50263           25.0
# 192015  10/20/2015          2509     CEDAR RAPIDS     52404           57.0
# 196086  11/02/2015          2662        MUSCATINE     52761           70.0
# 210035  10/13/2015          2518          RED OAK     51566           69.0
# 216660  10/22/2015          3713       MASON CITY     50401           17.0
# 221370  10/12/2015          3934        MAQUOKETA     52060           49.0
# 224617  10/15/2015          3647          CLINTON     52732           23.0
# 224979  10/12/2015          2549        INDIANOLA     50125           91.0
# 242130  09/09/2015          3762  WINDSOR HEIGHTS     50322           77.0
# 242572  10/13/2015          2552     CEDAR RAPIDS     52404           57.0
# 251421  12/01/2015          3944          DUBUQUE     52002           31.0
# 266646  12/17/2015          2633       DES MOINES     50320           77.0
#
#              County   Category Category Name  Vendor Number  Item Number  \
# 6744     Des Moines        NaN           NaN             85          333
# 11241          Polk        NaN           NaN            259        59100
# 18996         Worth        NaN           NaN             85          333
# 24190          Linn        NaN           NaN            259        59100
# 29798    Black Hawk        NaN           NaN             35         1475
# 34063          Polk        NaN           NaN            259        59100
# 44595       Johnson        NaN           NaN             65          725
# 48348      Buchanan        NaN           NaN            461         3337
# 49712          Cass        NaN           NaN            259        59100
# 53329      Cherokee        NaN           NaN            259        59100
# 54674          Linn        NaN           NaN            461         3337
# 55347           Lee        NaN           NaN             85        22227
# 57995    Winneshiek        NaN           NaN             35         1475
# 59896     Jefferson        NaN           NaN            305       900419
# 60370          Linn        NaN           NaN            259        59100
# 67879      Marshall        NaN           NaN            259        59100
# 69822          Linn        NaN           NaN            259        59100
# 85858         Scott        NaN           NaN             85          333
# 87425    Black Hawk        NaN           NaN             85          333
# 89897           Lee        NaN           NaN            461         3337
# 91043       Webster        NaN           NaN             85          333
# 91606          Linn        NaN           NaN            240       994992
# 93441          Cass        NaN           NaN             35         1475
# 98880       Johnson        NaN           NaN            259       927221
# 99045          Linn  1032100.0           NaN            370       900185
# 100333         Polk  1032100.0           NaN            356       936425
# 101633        Henry        NaN           NaN            259        59100
# 102627   Washington        NaN           NaN            259        59100
# 105372      Johnson  1032100.0           NaN            260       933513
# 138964        Scott        NaN           NaN             65          725
# 142979   Washington        NaN           NaN             65          237
# 147629   Washington        NaN           NaN             65          725
# 178003         Polk        NaN           NaN            259        59100
# 178533   Black Hawk        NaN           NaN             35         1475
# 191577       Dallas  1082100.0           NaN            305       965074
# 192015         Linn        NaN           NaN            259        59100
# 196086    Muscatine        NaN           NaN             65          725
# 210035   Montgomery        NaN           NaN            259        59100
# 216660  Cerro Gordo        NaN           NaN            259        59100
# 221370      Jackson        NaN           NaN            259        59100
# 224617      Clinton        NaN           NaN            259        59100
# 224979       Warren        NaN           NaN            259        59100
# 242130         Polk  1032100.0           NaN            260       933513
# 242572         Linn        NaN           NaN            259        59100
# 251421      Dubuque  1032100.0           NaN            370       900185
# 266646         Polk  1091100.0           NaN            434       933934
#
#                                          Item Description  Bottle Volume (ml)  \
# 6744    Jack Daniels TN Honey & Jack Daniels TN Fire 7...                1500
# 11241                               Evan Williams Egg Nog                 750
# 18996   Jack Daniels TN Honey & Jack Daniels TN Fire 7...                1500
# 24190                               Evan Williams Egg Nog                 750
# 29798                             Bombay Sapphire w/Glass                 750
# 34063                               Evan Williams Egg Nog                 750
# 44595                      Pinnacle Candy Cane Trial Pack                6000
# 48348                 Wild Turkey American Honey Shot Tap                 750
# 49712                               Evan Williams Egg Nog                 750
# 53329                               Evan Williams Egg Nog                 750
# 54674                 Wild Turkey American Honey Shot Tap                 750
# 55347                 Woodford Reserve MC 1838 White Corn                 750
# 57995                             Bombay Sapphire w/Glass                 750
# 59896                      Rothman & Winter Orchard Peach                 750
# 60370                               Evan Williams Egg Nog                 750
# 67879                               Evan Williams Egg Nog                 750
# 69822                               Evan Williams Egg Nog                 750
# 85858   Jack Daniels TN Honey & Jack Daniels TN Fire 7...                1500
# 87425   Jack Daniels TN Honey & Jack Daniels TN Fire 7...                1500
# 89897                 Wild Turkey American Honey Shot Tap                 750
# 91043   Jack Daniels TN Honey & Jack Daniels TN Fire 7...                1500
# 91606                         Glenfiddich 1963 Replica HA                 750
# 93441                             Bombay Sapphire w/Glass                 750
# 98880         Parkers Heritage Collection Malt Whiskey HA                 750
# 99045                               Absolut w/Ginger Beer                1750
# 100333                                   High Stick Vodka                 750
# 101633                              Evan Williams Egg Nog                 750
# 102627                              Evan Williams Egg Nog                 750
# 105372                                       Ciroc Ten HA                1000
# 138964                     Pinnacle Candy Cane Trial Pack                6000
# 142979                     Knob Creek w/ Crystal Decanter                1750
# 147629                     Pinnacle Candy Cane Trial Pack                6000
# 178003                              Evan Williams Egg Nog                 750
# 178533                            Bombay Sapphire w/Glass                 750
# 191577  Giffard Creme de Pamplemousse Rose Pink Grapef...                 750
# 192015                              Evan Williams Egg Nog                 750
# 196086                     Pinnacle Candy Cane Trial Pack                6000
# 210035                              Evan Williams Egg Nog                 750
# 216660                              Evan Williams Egg Nog                 750
# 221370                              Evan Williams Egg Nog                 750
# 224617                              Evan Williams Egg Nog                 750
# 224979                              Evan Williams Egg Nog                 750
# 242130                                       Ciroc Ten HA                1000
# 242572                              Evan Williams Egg Nog                 750
# 251421                              Absolut w/Ginger Beer                1750
# 266646                                      Pearl Caramel                1000
#
#         State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 6744                15.07                22.61             1           22.61
# 11241                4.46                 6.69            10           66.90
# 18996               15.07                22.61             4           90.44
# 24190                4.46                 6.69            12           80.28
# 29798               13.50                20.25             5          101.25
# 34063                4.46                 6.69             2           13.38
# 44595               52.50                78.75             1           78.75
# 48348               10.50                15.75             6           94.50
# 49712                4.46                 6.69            24          160.56
# 53329                4.46                 6.69            24          160.56
# 54674               10.50                15.75             6           94.50
# 55347               49.75                74.63             2          149.26
# 57995               13.50                20.25             6          121.50
# 59896               12.42                18.63            12          223.56
# 60370                4.46                 6.69            10           66.90
# 67879                4.46                 6.69            10           66.90
# 69822                4.46                 6.69             1            6.69
# 85858               15.07                22.61             4           90.44
# 87425               15.07                22.61             4           90.44
# 89897               10.50                15.75            18          283.50
# 91043               15.07                22.61             3           67.83
# 91606               56.00                84.00             3          252.00
# 93441               13.50                20.25             6          121.50
# 98880               49.95                74.93             1           74.93
# 99045               19.99                29.99            80         2399.20
# 100333              40.00                60.00             6          360.00
# 101633               4.46                 6.69            36          240.84
# 102627               4.46                 6.69            24          160.56
# 105372             125.00               187.50             2          375.00
# 138964              52.50                78.75             4          315.00
# 142979              35.55                53.34             3          160.02
# 147629              52.50                78.75             5          393.75
# 178003               4.46                 6.69            36          240.84
# 178533              13.50                20.25             4           81.00
# 191577              13.25                19.88             6          119.28
# 192015               4.46                 6.69            12           80.28
# 196086              52.50                78.75             1           78.75
# 210035               4.46                 6.69            12           80.28
# 216660               4.46                 6.69            24          160.56
# 221370               4.46                 6.69            24          160.56
# 224617               4.46                 6.69             1            6.69
# 224979               4.46                 6.69            12           80.28
# 242130             125.00               187.50             1          187.50
# 242572               4.46                 6.69             1            6.69
# 251421              19.99                29.99            80         2399.20
# 266646               8.67                13.01            24          312.24
#
#         Volume Sold (Liters)  Volume Sold (Gallons)
# 6744                    1.50                   0.40
# 11241                   7.50                   1.98
# 18996                   6.00                   1.59
# 24190                   9.00                   2.38
# 29798                   3.75                   0.99
# 34063                   1.50                   0.40
# 44595                   6.00                   1.59
# 48348                   4.50                   1.19
# 49712                  18.00                   4.76
# 53329                  18.00                   4.76
# 54674                   4.50                   1.19
# 55347                   1.50                   0.40
# 57995                   4.50                   1.19
# 59896                   9.00                   2.38
# 60370                   7.50                   1.98
# 67879                   7.50                   1.98
# 69822                   0.75                   0.20
# 85858                   6.00                   1.59
# 87425                   6.00                   1.59
# 89897                  13.50                   3.57
# 91043                   4.50                   1.19
# 91606                   2.25                   0.59
# 93441                   4.50                   1.19
# 98880                   0.75                   0.20
# 99045                 140.00                  36.98
# 100333                  4.50                   1.19
# 101633                 27.00                   7.13
# 102627                 18.00                   4.76
# 105372                  2.00                   0.53
# 138964                 24.00                   6.34
# 142979                  5.25                   1.39
# 147629                 30.00                   7.93
# 178003                 27.00                   7.13
# 178533                  3.00                   0.79
# 191577                  4.50                   1.19
# 192015                  9.00                   2.38
# 196086                  6.00                   1.59
# 210035                  9.00                   2.38
# 216660                 18.00                   4.76
# 221370                 18.00                   4.76
# 224617                  0.75                   0.20
# 224979                  9.00                   2.38
# 242130                  1.00                   0.26
# 242572                  0.75                   0.20
# 251421                140.00                  36.98
# 266646                 24.00                   6.34

# %%
df_nan['Item Description'].unique()
# Out:
# array(['Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls',
#        'Evan Williams Egg Nog', 'Bombay Sapphire w/Glass',
#        'Pinnacle Candy Cane Trial Pack',
#        'Wild Turkey American Honey Shot Tap',
#        'Woodford Reserve MC 1838 White Corn',
#        'Rothman & Winter Orchard Peach', 'Glenfiddich 1963 Replica HA',
#        'Parkers Heritage Collection Malt Whiskey HA',
#        'Absolut w/Ginger Beer', 'High Stick Vodka', 'Ciroc Ten HA',
#        'Knob Creek w/ Crystal Decanter',
#        'Giffard Creme de Pamplemousse Rose Pink Grapefruit Liqueur',
#        'Pearl Caramel'], dtype=object)

# %%
package = ['Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls', 'Bombay Sapphire w/Glass',\
           'Evan Williams Egg Nog', 'Pinnacle Candy Cane Trial Pack', 'Wild Turkey American Honey Shot Tap',\
           'Knob Creek w/ Crystal Decanter']

for i in package:
    df.loc[df['Item Description'] == i,'Category Name'] = 'DECANTERS & SPECIALTY PACKAGES'

# %%
df.loc[df['Item Description'] == 'Woodford Reserve MC 1838 White Corn',\
       'Category Name'] = 'CORN WHISKIES'

# %%
lique = ['Rothman & Winter Orchard Peach', 'Giffard Creme de Pamplemousse Rose Pink Grapefruit Liqueur',\
        'Pearl Caramel']

for i in lique:
    df.loc[df['Item Description'] == i,'Category Name'] ='MISC. IMPORTED CORDIALS & LIQUEURS'

# %%
df.loc[df['Item Description'] == 'Glenfiddich 1963 Replica HA',\
       'Category Name'] ='SINGLE MALT SCOTCH'

# %%
df.loc[df['Item Description'] == 'Parkers Heritage Collection Malt Whiskey HA',\
       'Category Name'] = "STRAIGHT BOURBON WHISKIES"

# %%
vod = ['High Stick Vodka', 'Ciroc Ten HA']

for i in vod:
    df.loc[df['Item Description'] == i,'Category Name'] = 'IMPORTED VODKA'

df.loc[df['Item Description'] == 'Absolut w/Ginger Beer','Category Name'] = 'VODKA FLAVORED'

# %% [markdown]
# #### Comments:
#
# There are still cells in 'Category' with NaN values, however, since we will only be using "Category Name" for analyses, NaNs in 'Category' were not cleaned.

# %% [markdown]
# ## Groupby County

# %%
pd.pivot_table(df, index = ['County', 'Store Number'], values = ['Sale (Dollars)'], \
               aggfunc = [np.mean, max, min, np.sum]).\
                sort_values([('sum', "Sale (Dollars)")], ascending = False).head(10)
# Out:
#                                mean            max            min  \
#                      Sale (Dollars) Sale (Dollars) Sale (Dollars)
# County  Store Number
# Polk    2633             491.080519       36392.40           4.50
#         4829             473.544726       13233.60           6.00
# Johnson 2512             302.767702       16542.00           7.26
# Linn    3385             855.724814       15414.00          64.02
# Polk    3420             936.223395       16200.00          38.40
# Iowa    3952             344.255640        6616.80           9.50
# Polk    3814            2234.074820       32184.00         121.56
# Linn    3773             253.965306        2538.72           7.05
# Scott   3354             750.236802        7404.60          64.02
# Johnson 2670             187.347078        6444.00           4.95
#
#                                 sum
#                      Sale (Dollars)
# County  Store Number
# Polk    2633             1220335.09
#         4829             1089152.87
# Johnson 2512              532265.62
# Linn    3385              506589.09
# Polk    3420              402576.06
# Iowa    3952              392451.43
# Polk    3814              310536.40
# Linn    3773              298663.20
# Scott   3354              295593.30
# Johnson 2670              282144.70

# %%
pd.pivot_table(df, index = ['County', 'Store Number'], values = ['Sale (Dollars)'], \
               aggfunc = [np.mean, max, min, np.sum]).\
                sort_values([('mean', "Sale (Dollars)")], ascending = False).head(10)
# Out:
#                                      mean            max            min  \
#                            Sale (Dollars) Sale (Dollars) Sale (Dollars)
# County        Store Number
# Dubuque       9018            6435.000000        6435.00        6435.00
# Polk          3814            2234.074820       32184.00         121.56
# Johnson       4677            1782.670108       29327.76          66.93
#               9001            1204.865000       14602.50         110.70
# Polk          3420             936.223395       16200.00          38.40
# Linn          3385             855.724814       15414.00          64.02
# Scott         9002             797.615510        6226.08          91.56
# Polk          5144             787.377406        8279.52          62.28
# Scott         3354             750.236802        7404.60          64.02
# Pottawattamie 3477             736.431774       16542.00          42.00
#
#                                       sum
#                            Sale (Dollars)
# County        Store Number
# Dubuque       9018                6435.00
# Polk          3814              310536.40
# Johnson       4677              165788.32
#               9001               28916.76
# Polk          3420              402576.06
# Linn          3385              506589.09
# Scott         9002               39083.16
# Polk          5144              166924.01
# Scott         3354              295593.30
# Pottawattamie 3477              182635.08

# %% [markdown]
# ## Groupby Zipcode

# %%
pd.pivot_table(df, index = ['Zip Code', 'Store Number'], values = ['Sale (Dollars)'], \
               aggfunc = [np.mean, max, min, np.sum]).\
                sort_values([('sum', 'Sale (Dollars)')], ascending = False).head(10)
# Out:
#                                 mean            max            min  \
#                       Sale (Dollars) Sale (Dollars) Sale (Dollars)
# Zip Code Store Number
# 50320    2633             491.080519       36392.40           4.50
# 50314    4829             473.544726       13233.60           6.00
# 52240    2512             302.767702       16542.00           7.26
# 52402    3385             855.724814       15414.00          64.02
# 50311    3420             936.223395       16200.00          38.40
# 52722    3952             344.255640        6616.80           9.50
# 50266    3814            2234.074820       32184.00         121.56
# 52401    3773             253.965306        2538.72           7.05
# 52807    3354             750.236802        7404.60          64.02
# 52241    2670             187.347078        6444.00           4.95
#
#                                  sum
#                       Sale (Dollars)
# Zip Code Store Number
# 50320    2633             1220335.09
# 50314    4829             1089152.87
# 52240    2512              532265.62
# 52402    3385              506589.09
# 50311    3420              402576.06
# 52722    3952              392451.43
# 50266    3814              310536.40
# 52401    3773              298663.20
# 52807    3354              295593.30
# 52241    2670              282144.70

# %%
pd.pivot_table(df, index = ['Zip Code'], values = ['Sale (Dollars)'], \
               aggfunc = [np.mean, max, min, np.sum]).\
                sort_values([('mean', 'Sale (Dollars)')], ascending = False).head(10)
# Out:
#                    mean            max            min            sum
#          Sale (Dollars) Sale (Dollars) Sale (Dollars) Sale (Dollars)
# Zip Code
# 50061        429.840000         818.40         129.24        2579.04
# 50320        400.454243       36392.40           4.50     1306281.74
# 50540        346.300000         648.00          64.80        2077.80
# 50314        293.858874       13233.60           4.95     1336470.16
# 50830        271.840000         564.48          94.20        3262.08
# 52401        245.139833        2538.72           7.05      309121.33
# 50266        238.291152       32184.00           5.10      678653.20
# 52154        235.232683         846.24          35.30        9644.54
# 52337        231.973333        1335.30          43.56        2087.76
# 52314        224.290505        3542.40           8.31      270942.93

# %% [markdown]
# ## Groupby City

# %%
pd.pivot_table(df, index = ['City', 'Store Number'], values = ['Sale (Dollars)'],\
               aggfunc = [np.mean, np.sum, np.std]).sort_values([('mean', 'Sale (Dollars)')], \
                                                                ascending = False).head(10)
# Out:
#                                        mean            sum            std
#                              Sale (Dollars) Sale (Dollars) Sale (Dollars)
# City            Store Number
# DUBUQUE         9018            6435.000000        6435.00            NaN
# WEST DES MOINES 3814            2234.074820      310536.40    4325.581435
# CORALVILLE      4677            1782.670108      165788.32    3746.167251
# SWISHER         9001            1204.865000       28916.76    2895.308462
# WINDSOR HEIGHTS 3420             936.223395      402576.06    1810.604731
# CEDAR RAPIDS    3385             855.724814      506589.09    1789.637834
# LECLAIRE        9002             797.615510       39083.16    1005.067525
# ANKENY          5144             787.377406      166924.01    1411.192674
# DAVENPORT       3354             750.236802      295593.30    1316.226035
# COUNCIL BLUFFS  3477             736.431774      182635.08    1845.011697

# %%
pd.pivot_table(df, index = ['City', 'Store Number'], values = ['Sale (Dollars)'],\
               aggfunc = [np.mean, np.sum, np.std]).sort_values([('sum', 'Sale (Dollars)')], \
                                                                ascending = False).head(10)
# Out:
#                                        mean            sum            std
#                              Sale (Dollars) Sale (Dollars) Sale (Dollars)
# City            Store Number
# DES MOINES      2633             491.080519     1220335.09    1581.816646
#                 4829             473.544726     1089152.87     795.966563
# IOWA CITY       2512             302.767702      532265.62     720.721560
# CEDAR RAPIDS    3385             855.724814      506589.09    1789.637834
# WINDSOR HEIGHTS 3420             936.223395      402576.06    1810.604731
# BETTENDORF      3952             344.255640      392451.43     506.144333
# WEST DES MOINES 3814            2234.074820      310536.40    4325.581435
# CEDAR RAPIDS    3773             253.965306      298663.20     305.082510
# DAVENPORT       3354             750.236802      295593.30    1316.226035
# CORALVILLE      2670             187.347078      282144.70     358.161785

# %% [markdown]
# # Explore the data
#
# Perform some exploratory statistical analysis and make some plots, such as histograms of transaction totals, bottles sold, etc.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Record your findings
#
# Be sure to write out anything observations from your exploratory analysis.

# %% [markdown]
# # Mine the data
# Now you are ready to compute the variables you will use for your regression from the data. For example, you may want to
# compute total sales per store from Jan to March of 2015, mean price per bottle, etc. Refer to the readme for more ideas appropriate to your scenario.
#
# Pandas is your friend for this task. Take a look at the operations [here](http://pandas.pydata.org/pandas-docs/stable/groupby.html) for ideas on how to make the best use of pandas and feel free to search for blog and Stack Overflow posts to help you group data by certain variables and compute sums, means, etc. You may find it useful to create a new data frame to house this summary data.

# %% [markdown]
# # Refine the data
# Look for any statistical relationships, correlations, or other relevant properties of the dataset.

# %% [markdown]
# # Build your models
#
# Using scikit-learn or statsmodels, build the necessary models for your scenario. Evaluate model fit.

# %%
from sklearn import linear_model

# %% [markdown]
# ## Plot your results
#
# Again make sure that you record any valuable information. For example, in the tax scenario, did you find the sales from the first three months of the year to be a good predictor of the total sales for the year? Plot the predictions versus the true values and discuss the successes and limitations of your models

# %% [markdown]
# # Present the Results
#
# Present your conclusions and results. If you have more than one interesting model feel free to include more than one along with a discussion. Use your work in this notebook to prepare your write-up.

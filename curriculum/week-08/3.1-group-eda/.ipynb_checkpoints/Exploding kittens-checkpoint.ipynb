# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('more_data.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-3-df38df850526> in <module>()
# ----> 1 df = pd.read_csv('more_data.csv')
#       2 df.head()
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# amt.pledged         float64
# blurb                object
# category             object
# currency             object
# goal                float64
# location             object
# num.backers           int64
# num.backers.tier     object
# pledge.tier          object
# title                object
# url                  object
# dtype: object

# %%
df['category'].value_counts().hist()

# %%
df['category'].nunique()
# Out:
# 115

# %%
df['category'].unique()
# Out:
# array(['Tabletop Games', 'Product Design', 'Web', 'Narrative Film',
#        'Video Games', 'Technology', 'Gaming Hardware', 'Television',
#        'Hardware', 'Music', 'Space Exploration', 'Radio &amp; Podcasts',
#        'Flight', 'Sound', 'Animation', 'Games', 'Action', 'Gadgets',
#        'Documentary', '3D Printing', 'DIY Electronics', 'Publishing',
#        'Fashion', 'Comics', 'Typography', "Children's Books", 'Apparel',
#        'Food', 'Crafts', 'Camera Equipment', 'Comedy', 'Design',
#        'Graphic Design', 'Apps', 'Hip-Hop', 'World Music',
#        'Film &amp; Video', 'Drinks', 'Wearables', 'Accessories',
#        'Footwear', 'Science Fiction', 'Art Books', 'Nonfiction', 'Robots',
#        'Art', 'Software', 'Chiptune', 'Webseries', 'Webcomics', 'Rock',
#        'Playing Cards', 'Cookbooks', 'Fantasy', 'Photography',
#        'Anthologies', 'Faith', 'Mixed Media', 'Metal', 'Small Batch',
#        'Classical Music', 'Architecture', 'Pop', 'Dance',
# ...

# %%
df[df['category'] == 'Tabletop Games']
# Out:
#       Unnamed: 0  amt.pledged  \
# 0              0    8782571.0
# 15            15    3246588.0
# 29            29    1479046.0
# 34            34    3771474.0
# 35            35    1353024.0
# 49            49    3560642.0
# 58            58    4079204.0
# 73            73    1810294.0
# 89            89    3327757.0
# 99            99    3169610.0
# 105          105     468629.0
# 110          110     575926.0
# 116          116     631230.0
# 120          120    2730365.0
# 127          127     526274.0
# 134          134     411693.0
# 138          138    1351142.0
# 140          140    1224220.0
# 142          142    2849064.0
# 144          144     585122.0
# 153          153    1316813.0
# 164          164     250070.0
# 165          165    1010958.0
# 171          171     411635.0
# 172          172     556596.0
# 187          187    1464489.0
# 189          189     433365.0
# 192          192    1710713.0
# 193          193    1518321.0
# 196          196     905682.0
# ...

# %%
# Looking through categories with only 1 entry

category = pd.DataFrame(df['category'].value_counts())
category[category['category'] == 1]
# Out:
#                    category
# Music Videos              1
# Mobile Games              1
# Romance                   1
# Fabrication Tools         1
# Movie Theaters            1
# People                    1
# Academic                  1
# Faith                     1
# Zines                     1
# Action                    1
# Dance                     1
# Stationery                1
# Jazz                      1
# Metal                     1
# Jewelry                   1
# Young Adult               1
# Video                     1
# Installations             1
# Drama                     1
# Television                1
# Food Trucks               1
# Photo                     1

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
fuzz.ratio("this is a test", "this is a test!")
# Out:
# 97

# %%
a = 'this is a test!'

# %%
import string

# %%
def normalize_string(s):
    for p in string.punctuation:
        s = s.replace(p, ' ')
    s = s.lower().strip()
    return s

# %%
print normalize_string(a)
# Out:
# this is a test

# %%
df['norm_blurb'] = df['blurb'].apply(normalize_string)
df.head()
# Out:
#    Unnamed: 0  amt.pledged                                              blurb  \
# 0           0    8782571.0  \nThis is a card game for people who are into ...
# 1           1    6465690.0  \nAn unusually addicting, high-quality desk to...
# 2           2    5408916.0  \nBring Reading Rainbow’s library of interacti...
# 3           3    5702153.0  \nUPDATED: This is it. We're making a Veronica...
# 4           4    3336371.0  \nAn adventure game from Tim Schafer, Double F...
#
#          category currency       goal           location  num.backers  \
# 0  Tabletop Games      usd    10000.0    Los Angeles, CA       219382
# 1  Product Design      usd    15000.0         Denver, CO       154926
# 2             Web      usd  1000000.0    Los Angeles, CA       105857
# 3  Narrative Film      usd  2000000.0      San Diego, CA        91585
# 4     Video Games      usd   400000.0  San Francisco, CA        87142
#
#                                     num.backers.tier  \
# ...

# %%
a = df[df['category'] == 'Photo'].norm_blurb.values

# %%
df['photo_fuzz'] = df['norm_blurb'].apply(lambda x: fuzz.ratio(a[0], x))
df['photo_fuzz'].hist(bins = 100)

# %%
df[df['photo_fuzz'] > 50]
# Out:
#       Unnamed: 0  amt.pledged  \
# 2326        2326      96772.0
# 2818        2818     186010.0
# 3438        3438      70301.0
#
#                                                   blurb     category currency  \
# 2326  \nA documentary film exploring the art & impac...  Documentary      usd
# 2818  \nA documentary film exploring the extraordina...  Documentary      usd
# 3438  \nA documentary exploring Afghanistan's recent...        Photo      usd
#
#           goal            location  num.backers  \
# 2326   50000.0     Los Angeles, CA         1724
# 2818  175000.0        New York, NY         1483
# 3438   40000.0  Kabul, Afghanistan         1251
#
#                                        num.backers.tier  \
# 2326      [204, 39, 777, 379, 123, 87, 28, 14, 9, 3, 7]
# 2818  [144, 57, 22, 17, 80, 36, 52, 49, 57, 1, 151, ...
# 3438  [93, 190, 266, 202, 120, 77, 123, 10, 27, 10, ...
#
#                                             pledge.tier  \
# ...

# %%
cat_count = df['category'].value_counts()
cat_count.head(20)
# Out:
# Product Design      769
# Tabletop Games      745
# Video Games         528
# Hardware            182
# Technology          151
# Documentary         124
# Gadgets             121
# Design               99
# Comics               79
# Wearables            64
# Fashion              61
# Animation            49
# Food                 46
# DIY Electronics      42
# Music                41
# Film &amp; Video     40
# Games                37
# Webcomics            33
# Art Books            33
# Apparel              32
# Name: category, dtype: int64

# %%
# Setting threshold to be top 20

threshold = 32

# %%
df['category_count'] = df['category'].apply(lambda x : cat_count.loc[x])

# %%
del df['photo_fuzz']

# %%
df.head(2)
# Out:
#    Unnamed: 0  amt.pledged                                              blurb  \
# 0           0    8782571.0  \nThis is a card game for people who are into ...
# 1           1    6465690.0  \nAn unusually addicting, high-quality desk to...
#
#          category currency     goal         location  num.backers  \
# 0  Tabletop Games      usd  10000.0  Los Angeles, CA       219382
# 1  Product Design      usd  15000.0       Denver, CO       154926
#
#                                     num.backers.tier  \
# 0                            [15505, 202934, 200, 5]
# 1  [788, 250, 43073, 21796, 41727, 21627, 12215, ...
#
#                                          pledge.tier  \
# 0                         [20.0, 35.0, 100.0, 500.0]
# 1  [1.0, 14.0, 19.0, 19.0, 35.0, 35.0, 79.0, 79.0...
#
#                            title  \
# 0              Exploding Kittens
# 1  Fidget Cube: A Vinyl Desk Toy
#
#                                                 url  \
# ...

# %%
df.loc[0,'category']
# Out:
# 'Tabletop Games'

# %%
df.loc[df['City'] == 'TABOR', 'County'] = 'Fremont'

# %%
del df['new_index']

# %%
df.head(2)
# Out:
#    Unnamed: 0  amt.pledged                                              blurb  \
# 0           0    8782571.0  \nThis is a card game for people who are into ...
# 1           1    6465690.0  \nAn unusually addicting, high-quality desk to...
#
#          category currency     goal         location  num.backers  \
# 0  Tabletop Games      usd  10000.0  Los Angeles, CA       219382
# 1  Product Design      usd  15000.0       Denver, CO       154926
#
#                                     num.backers.tier  \
# 0                            [15505, 202934, 200, 5]
# 1  [788, 250, 43073, 21796, 41727, 21627, 12215, ...
#
#                                          pledge.tier  \
# 0                         [20.0, 35.0, 100.0, 500.0]
# 1  [1.0, 14.0, 19.0, 19.0, 35.0, 35.0, 79.0, 79.0...
#
#                            title  \
# 0              Exploding Kittens
# 1  Fidget Cube: A Vinyl Desk Toy
#
#                                                 url  \
# ...

# %%
len(df['category_count'])
# Out:
# 4000

# %%
df['new_category'] = 0

# %%
df.head(1)
# Out:
#    Unnamed: 0  amt.pledged                                              blurb  \
# 0           0    8782571.0  \nThis is a card game for people who are into ...
#
#          category currency     goal         location  num.backers  \
# 0  Tabletop Games      usd  10000.0  Los Angeles, CA       219382
#
#           num.backers.tier                 pledge.tier              title  \
# 0  [15505, 202934, 200, 5]  [20.0, 35.0, 100.0, 500.0]  Exploding Kittens
#
#                                    url  \
# 0  /projects/elanlee/exploding-kittens
#
#                                           norm_blurb  category_count  \
# 0  this is a card game for people who are into ki...             745
#
#    new_category
# 0             0

# %%
for i in range(len(df['category_count'])):
    
    fuzz_list = []
    
    if df.loc[i, 'category_count'] < threshold:
        
        ownblurb = df.loc[i,'norm_blurb']
        
        for j in df['norm_blurb']:
            
            fuzz_ratio = fuzz.ratio(ownblurb, j)
            
            if fuzz_ratio != 100:
                fuzz_list.append(fuzz_ratio)
                
            else:
                fuzz_list.append(0)
        
        df.loc[i, 'new_category'] = df.loc[max(fuzz_list),'category']
    
    else:
        
        df.loc[i, 'new_category'] = df.loc[i, 'category']

# %%
df.head(10)
# Out:
#    Unnamed: 0  amt.pledged                                              blurb  \
# 0           0    8782571.0  \nThis is a card game for people who are into ...
# 1           1    6465690.0  \nAn unusually addicting, high-quality desk to...
# 2           2    5408916.0  \nBring Reading Rainbow’s library of interacti...
# 3           3    5702153.0  \nUPDATED: This is it. We're making a Veronica...
# 4           4    3336371.0  \nAn adventure game from Tim Schafer, Double F...
# 5           5   20338986.0  \nColor e-paper smartwatch with up to 7 days o...
# 6           6    4188927.0  \nA story-driven CRPG set in the world of Mont...
# 7           7    3986929.0  \nPillars of Eternity is an isometric, party-b...
# 8           8    2090104.0  \nThe creative talent behind Banjo-Kazooie and...
# 9           9    3007370.0  \nZNAPS is a magnetic adapter specially design...
#
#          category currency       goal           location  num.backers  \
# ...

# %%
df['new_category'].value_counts()
# Out:
# Video Games             907
# Tabletop Games          863
# Product Design          805
# Hardware                245
# Technology              154
# Documentary             126
# Gadgets                 121
# Design                   99
# Comics                   79
# Wearables                64
# Fashion                  61
# Animation                52
# Food                     46
# DIY Electronics          43
# Music                    41
# Space Exploration        40
# Film &amp; Video         40
# Games                    37
# Art Books                33
# Webcomics                33
# Webseries                32
# Apparel                  32
# Radio &amp; Podcasts     28
# Flight                    9
# Narrative Film            6
# Action                    3
# 3D Printing               1
# Name: new_category, dtype: int64

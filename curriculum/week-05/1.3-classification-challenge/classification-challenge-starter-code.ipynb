# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split

from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import confusion_matrix
# Out:
# //anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df = pd.read_csv('classification_challenge_training.csv') # read in the census-derived data; mind the separator
df.head()
# Out:
#    Unnamed: 0  age type_employer  education  education_num  \
# 0           4   53       Private       11th              7
# 1       14656   32       Private    HS-grad              9
# 2       26677   29       Private       10th              6
# 3        4281   30       Private  Assoc-voc             11
# 4       15668   66       Private    HS-grad              9
#
#                  marital         occupation   relationship   race     sex  \
# 0     Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 1     Married-civ-spouse       Adm-clerical           Wife  White  Female
# 2  Married-spouse-absent       Adm-clerical      Unmarried  White  Female
# 3     Married-civ-spouse  Handlers-cleaners        Husband  White    Male
# 4                Widowed    Priv-house-serv  Not-in-family  White  Female
#
#    capital_gain  capital_loss  hr_per_week        country  income
# 0             0             0           40  United-States       0
# 1             0             0           40  United-States       1
# 2             0             0           40         Mexico       0
# 3             0             0           40         Mexico       0
# 4             0             0            8  United-States       0

# %%
df.head(1)
# Out:
#    Unnamed: 0  age type_employer education  education_num             marital  \
# 0           4   53       Private      11th              7  Married-civ-spouse
#
#           occupation relationship   race   sex  capital_gain  capital_loss  \
# 0  Handlers-cleaners      Husband  Black  Male             0             0
#
#    hr_per_week        country  income
# 0           40  United-States       0

# %%
df['marital'].unique()
# Out:
# array(['Married-civ-spouse', 'Married-spouse-absent', 'Widowed',
#        'Never-married', 'Divorced', 'Separated', 'Married-AF-spouse'], dtype=object)

# %%
df['relationship'].unique()
# Out:
# array(['Husband', 'Wife', 'Unmarried', 'Not-in-family', 'Own-child',
#        'Other-relative'], dtype=object)

# %%
print list(df.columns)
# Out:
# ['Unnamed: 0', 'age', 'type_employer', 'education', 'education_num', 'marital', 'occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hr_per_week', 'country', 'income']

# %%
def get_features(dataframe):
   features = patsy.dmatrix('~ C(type_employer) + C(marital) +\
   C(occupation) + C(relationship) + C(race) + C(sex) + C(country)', dataframe)
   X_df = pd.DataFrame(features, columns=features.design_info.column_names)
   X_df.drop('Intercept', axis=1, inplace=True)
   X_df = pd.concat([X_df, dataframe[['age', 'education_num', 'capital_gain', 'capital_loss', 'hr_per_week']]], axis=1)
   return X_df

# %%
import patsy

df1 = get_features(df)

# %%
df1.dtypes
# Out:
# C(type_employer)[T.Federal-gov]             float64
# C(type_employer)[T.Local-gov]               float64
# C(type_employer)[T.Never-worked]            float64
# C(type_employer)[T.Private]                 float64
# C(type_employer)[T.Self-emp-inc]            float64
# C(type_employer)[T.Self-emp-not-inc]        float64
# C(type_employer)[T.State-gov]               float64
# C(type_employer)[T.Without-pay]             float64
# C(marital)[T.Married-AF-spouse]             float64
# C(marital)[T.Married-civ-spouse]            float64
# C(marital)[T.Married-spouse-absent]         float64
# C(marital)[T.Never-married]                 float64
# C(marital)[T.Separated]                     float64
# C(marital)[T.Widowed]                       float64
# C(occupation)[T.Adm-clerical]               float64
# C(occupation)[T.Armed-Forces]               float64
# C(occupation)[T.Craft-repair]               float64
# C(occupation)[T.Exec-managerial]            float64
# C(occupation)[T.Farming-fishing]            float64
# C(occupation)[T.Handlers-cleaners]          float64
# C(occupation)[T.Machine-op-inspct]          float64
# C(occupation)[T.Other-service]              float64
# C(occupation)[T.Priv-house-serv]            float64
# C(occupation)[T.Prof-specialty]             float64
# C(occupation)[T.Protective-serv]            float64
# C(occupation)[T.Sales]                      float64
# C(occupation)[T.Tech-support]               float64
# C(occupation)[T.Transport-moving]           float64
# C(relationship)[T.Not-in-family]            float64
# C(relationship)[T.Other-relative]           float64
# C(relationship)[T.Own-child]                float64
# C(relationship)[T.Unmarried]                float64
# C(relationship)[T.Wife]                     float64
# C(race)[T.Asian-Pac-Islander]               float64
# C(race)[T.Black]                            float64
# C(race)[T.Other]                            float64
# C(race)[T.White]                            float64
# C(sex)[T.Male]                              float64
# C(country)[T.Cambodia]                      float64
# C(country)[T.Canada]                        float64
# C(country)[T.China]                         float64
# C(country)[T.Columbia]                      float64
# C(country)[T.Cuba]                          float64
# C(country)[T.Dominican-Republic]            float64
# C(country)[T.Ecuador]                       float64
# C(country)[T.El-Salvador]                   float64
# C(country)[T.England]                       float64
# C(country)[T.France]                        float64
# C(country)[T.Germany]                       float64
# C(country)[T.Greece]                        float64
# C(country)[T.Guatemala]                     float64
# C(country)[T.Haiti]                         float64
# C(country)[T.Holand-Netherlands]            float64
# C(country)[T.Honduras]                      float64
# C(country)[T.Hong]                          float64
# C(country)[T.Hungary]                       float64
# C(country)[T.India]                         float64
# C(country)[T.Iran]                          float64
# C(country)[T.Ireland]                       float64
# C(country)[T.Italy]                         float64
# C(country)[T.Jamaica]                       float64
# C(country)[T.Japan]                         float64
# C(country)[T.Laos]                          float64
# C(country)[T.Mexico]                        float64
# C(country)[T.Nicaragua]                     float64
# C(country)[T.Outlying-US(Guam-USVI-etc)]    float64
# C(country)[T.Peru]                          float64
# C(country)[T.Philippines]                   float64
# C(country)[T.Poland]                        float64
# C(country)[T.Portugal]                      float64
# C(country)[T.Puerto-Rico]                   float64
# C(country)[T.Scotland]                      float64
# C(country)[T.South]                         float64
# C(country)[T.Taiwan]                        float64
# C(country)[T.Thailand]                      float64
# C(country)[T.Trinadad&Tobago]               float64
# C(country)[T.United-States]                 float64
# C(country)[T.Vietnam]                       float64
# C(country)[T.Yugoslavia]                    float64
# age                                           int64
# education_num                                 int64
# capital_gain                                  int64
# capital_loss                                  int64
# hr_per_week                                   int64
# dtype: object

# %%
# Check values and their counts
pd.set_option('display.max_rows', 500)
df.apply(lambda c: c.value_counts()).T.stack()
# Out:
# Unnamed: 0    1                                 1.0
#               2                                 1.0
#               4                                 1.0
#               5                                 1.0
#               6                                 1.0
#               7                                 1.0
#               8                                 1.0
#               9                                 1.0
#               10                                1.0
#               12                                1.0
#               14                                1.0
#               15                                1.0
#               17                                1.0
#               18                                1.0
#               19                                1.0
#               20                                1.0
#               21                                1.0
#               22                                1.0
#               23                                1.0
#               24                                1.0
#               25                                1.0
#               26                                1.0
#               27                                1.0
#               29                                1.0
#               31                                1.0
#               32                                1.0
#               33                                1.0
#               34                                1.0
#               35                                1.0
#               37                                1.0
#               38                                1.0
#               40                                1.0
#               41                                1.0
#               42                                1.0
#               45                                1.0
#               47                                1.0
#               48                                1.0
#               50                                1.0
#               51                                1.0
#               52                                1.0
#               53                                1.0
#               54                                1.0
#               55                                1.0
#               57                                1.0
#               60                                1.0
#               62                                1.0
#               63                                1.0
#               64                                1.0
#               65                                1.0
#               68                                1.0
#               69                                1.0
#               70                                1.0
#               72                                1.0
#               74                                1.0
#               75                                1.0
#               76                                1.0
#               77                                1.0
#               78                                1.0
#               79                                1.0
#               80                                1.0
#               81                                1.0
#               83                                1.0
#               84                                1.0
#               87                                1.0
#               88                                1.0
#               89                                1.0
#               90                                1.0
#               91                                1.0
#               93                                1.0
#               94                                1.0
#               96                                1.0
#               97                                1.0
#               98                                1.0
#               99                                1.0
#               100                               1.0
#               101                               1.0
#               102                               1.0
#               103                               1.0
#               104                               1.0
#               106                               1.0
#               107                               1.0
#               108                               1.0
#               109                               1.0
#               110                               1.0
#               111                               1.0
#               112                               1.0
#               113                               1.0
#               114                               1.0
#               115                               1.0
#               116                               1.0
#               117                               1.0
#               118                               1.0
#               120                               1.0
#               121                               1.0
#               122                               1.0
#               124                               1.0
#               125                               1.0
#               126                               1.0
#               127                               1.0
#               128                               1.0
#               129                               1.0
#               131                               1.0
#               132                               1.0
#               133                               1.0
#               134                               1.0
#               135                               1.0
#               136                               1.0
#               137                               1.0
#               138                               1.0
#               139                               1.0
#               140                               1.0
#               141                               1.0
#               142                               1.0
#               143                               1.0
#               144                               1.0
#               145                               1.0
#               146                               1.0
#               147                               1.0
#               148                               1.0
#               149                               1.0
#               150                               1.0
#               151                               1.0
#               152                               1.0
#               153                               1.0
#               154                               1.0
#               155                               1.0
#               156                               1.0
#               160                               1.0
#               161                               1.0
#               163                               1.0
#               164                               1.0
#               165                               1.0
#               166                               1.0
#               170                               1.0
#               172                               1.0
#               173                               1.0
#               174                               1.0
#               175                               1.0
#               176                               1.0
#               177                               1.0
#               178                               1.0
#               179                               1.0
#               180                               1.0
#               182                               1.0
#               183                               1.0
#               184                               1.0
#               185                               1.0
#               187                               1.0
#               188                               1.0
#               189                               1.0
#               191                               1.0
#               192                               1.0
#               194                               1.0
#               195                               1.0
#               196                               1.0
#               197                               1.0
#               198                               1.0
#               199                               1.0
#               200                               1.0
#               201                               1.0
#               205                               1.0
#               206                               1.0
#               207                               1.0
#               208                               1.0
#               209                               1.0
#               210                               1.0
#               211                               1.0
#               212                               1.0
#               213                               1.0
#               214                               1.0
#               215                               1.0
#               216                               1.0
#               217                               1.0
#               218                               1.0
#               219                               1.0
#               220                               1.0
#               222                               1.0
#               223                               1.0
#               224                               1.0
#               225                               1.0
#               228                               1.0
#               229                               1.0
#               230                               1.0
#               231                               1.0
#               232                               1.0
#               233                               1.0
#               234                               1.0
#               235                               1.0
#               236                               1.0
#               237                               1.0
#               239                               1.0
#               240                               1.0
#               244                               1.0
#               245                               1.0
#               246                               1.0
#               247                               1.0
#               249                               1.0
#               250                               1.0
#               251                               1.0
#               252                               1.0
#               253                               1.0
#               255                               1.0
#               258                               1.0
#               259                               1.0
#               260                               1.0
#               261                               1.0
#               264                               1.0
#               265                               1.0
#               266                               1.0
#               267                               1.0
#               268                               1.0
#               270                               1.0
#               271                               1.0
#               272                               1.0
#               273                               1.0
#               274                               1.0
#               275                               1.0
#               276                               1.0
#               278                               1.0
#               279                               1.0
#               280                               1.0
#               281                               1.0
#               282                               1.0
#               283                               1.0
#               284                               1.0
#               285                               1.0
#               286                               1.0
#               287                               1.0
#               288                               1.0
#               289                               1.0
#               290                               1.0
#               291                               1.0
#               292                               1.0
#               293                               1.0
#               294                               1.0
#               295                               1.0
#               296                               1.0
#               299                               1.0
#               300                               1.0
#               301                               1.0
#               302                               1.0
#               303                               1.0
#               304                               1.0
#               305                               1.0
#               306                               1.0
#               307                               1.0
#               310                               1.0
#               311                               1.0
#               312                               1.0
#               314                               1.0
#                                              ...
# capital_gain  8614                             45.0
#               9386                             18.0
#               9562                              3.0
#               10520                            35.0
#               10566                             5.0
#               10605                             6.0
#               11678                             1.0
#               13550                            18.0
#               14084                            27.0
#               14344                            18.0
#               15020                             4.0
#               15024                           265.0
#               15831                             3.0
#               18481                             2.0
#               20051                            26.0
#               25124                             4.0
#               25236                             8.0
#               27828                            24.0
#               34095                             5.0
#               41310                             2.0
#               99999                           119.0
# capital_loss  0                             23293.0
#               155                               1.0
#               213                               1.0
#               323                               2.0
#               419                               2.0
#               625                               8.0
#               653                               2.0
#               810                               2.0
#               880                               5.0
#               974                               2.0
#               1092                              6.0
#               1138                              2.0
#               1258                              3.0
#               1340                              4.0
#               1380                              6.0
#               1408                             13.0
#               1411                              1.0
#               1485                             39.0
#               1504                             15.0
#               1539                              1.0
#               1564                             21.0
#               1573                              4.0
#               1579                             15.0
#               1590                             30.0
#               1594                              4.0
#               1602                             31.0
#               1617                              4.0
#               1628                             14.0
#               1648                              2.0
#               1651                              6.0
#               1668                              3.0
#               1669                             17.0
#               1672                             24.0
#               1719                             17.0
#               1721                             15.0
#               1726                              3.0
#               1735                              2.0
#               1740                             30.0
#               1741                             16.0
#               1755                              2.0
#               1762                              9.0
#               1816                              1.0
#               1825                              2.0
#               1844                              1.0
#               1848                             36.0
#               1876                             29.0
#               1887                            113.0
#               1902                            157.0
#               1944                              1.0
#               1974                             16.0
#               1977                            129.0
#               1980                             14.0
#               2001                             19.0
#               2002                             16.0
#               2042                              4.0
#               2051                             14.0
#               2057                              6.0
#               2080                              1.0
#               2129                              1.0
#               2149                              2.0
#               2163                              1.0
#               2174                              4.0
#               2179                             12.0
#               2201                              1.0
#               2205                              6.0
#               2206                              5.0
#               2231                              2.0
#               2238                              2.0
#               2246                              4.0
#               2258                             19.0
#               2267                              2.0
#               2282                              1.0
#               2339                             16.0
#               2352                              1.0
#               2377                             15.0
#               2392                              4.0
#               2415                             38.0
#               2444                             10.0
#               2457                              3.0
#               2467                              1.0
#               2472                              1.0
#               2489                              1.0
#               2547                              4.0
#               2559                              6.0
#               2603                              3.0
#               2754                              2.0
#               2824                              9.0
#               3683                              2.0
#               3770                              1.0
#               3900                              2.0
#               4356                              3.0
# hr_per_week   1                                14.0
#               2                                25.0
#               3                                33.0
#               4                                37.0
#               5                                45.0
#               6                                43.0
#               7                                20.0
#               8                               107.0
#               9                                14.0
#               10                              202.0
#               11                                7.0
#               12                              135.0
#               13                               14.0
#               14                               23.0
#               15                              295.0
#               16                              155.0
#               17                               20.0
#               18                               58.0
#               19                                9.0
#               20                              914.0
#               21                               16.0
#               22                               31.0
#               23                               20.0
#               24                              187.0
#               25                              487.0
#               26                               21.0
#               27                               24.0
#               28                               64.0
#               29                                4.0
#               30                              884.0
#               31                                4.0
#               32                              202.0
#               33                               33.0
#               34                               22.0
#               35                             1001.0
#               36                              164.0
#               37                              115.0
#               38                              353.0
#               39                               28.0
#               40                            11331.0
#               41                               27.0
#               42                              167.0
#               43                              118.0
#               44                              169.0
#               45                             1385.0
#               46                               62.0
#               47                               41.0
#               48                              372.0
#               49                               21.0
#               50                             2138.0
#               51                               13.0
#               52                              104.0
#               53                               18.0
#               54                               32.0
#               55                              521.0
#               56                               67.0
#               57                               14.0
#               58                               25.0
#               59                                5.0
#               60                             1137.0
#               61                                2.0
#               62                               13.0
#               63                                8.0
#               64                                8.0
#               65                              189.0
#               66                               12.0
#               67                                2.0
#               68                               10.0
#               70                              206.0
#               72                               59.0
#               73                                2.0
#               74                                1.0
#               75                               43.0
#               76                                1.0
#               77                                5.0
#               78                                6.0
#               80                               96.0
#               81                                3.0
#               82                                1.0
#               84                               36.0
#               85                               10.0
#               86                                2.0
#               87                                1.0
#               88                                2.0
#               89                                2.0
#               90                               18.0
#               91                                3.0
#               92                                1.0
#               94                                1.0
#               95                                2.0
#               96                                3.0
#               97                                1.0
#               98                                9.0
#               99                               65.0
# country       ?                               435.0
#               Cambodia                         13.0
#               Canada                           93.0
#               China                            63.0
#               Columbia                         48.0
#               Cuba                             73.0
#               Dominican-Republic               53.0
#               Ecuador                          25.0
#               El-Salvador                      76.0
#               England                          63.0
#               France                           21.0
#               Germany                         102.0
#               Greece                           23.0
#               Guatemala                        47.0
#               Haiti                            31.0
#               Holand-Netherlands                1.0
#               Honduras                          8.0
#               Hong                             15.0
#               Hungary                           8.0
#               India                            78.0
#               Iran                             35.0
#               Ireland                          19.0
#               Italy                            57.0
#               Jamaica                          60.0
#               Japan                            49.0
#               Laos                             15.0
#               Mexico                          490.0
#               Nicaragua                        23.0
#               Outlying-US(Guam-USVI-etc)       10.0
#               Peru                             28.0
#               Philippines                     142.0
#               Poland                           44.0
#               Portugal                         30.0
#               Puerto-Rico                      82.0
#               Scotland                         11.0
#               South                            64.0
#               Taiwan                           35.0
#               Thailand                         17.0
#               Trinadad&Tobago                   9.0
#               United-States                 21859.0
#               Vietnam                          51.0
#               Yugoslavia                       14.0
# income        0                             18559.0
#               1                              5861.0
# dtype: float64

# %%
"""Clean/munge your data."""

X_train, X_test, Y_train, Y_test = train_test_split(df, target) ## create train-test out of the data given

# %%
""" Fit a binary classification predictor."""

y_pred = ?.predict(X_test)
y_score = ?.decision_function(X_test) # Submit these response, the output of model.decision_function
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=5, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=100,
#            multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#            refit=True, scoring=None, solver='lbfgs', tol=0.0001, verbose=0)

# %%
""" Check your performance so far."""

conmat = np.array(confusion_matrix(Y_test, y_pred, labels=[1,0]))
confusion = pd.DataFrame(conmat, index=['over_50k', 'under_50k'],
                            columns=['predicted_over50k','predicted_under50k'])

print(confusion)
print classification_report(Y_test,y_pred)
roc_auc_score(Y_test, y_score)

""" Plot AUC"""

FPR = dict()
TPR = dict()
ROC_AUC = dict()

# For class 1, find the area under the curve
FPR[1], TPR[1], _ = roc_curve(Y_test, y_score)
ROC_AUC[1] = auc(FPR[1], TPR[1])

# Plot of a ROC curve for class 1 (has_cancer)
plt.figure(figsize=[11,9])
plt.plot(FPR[1], TPR[1], label='ROC curve (area = %0.2f)' % ROC_AUC[1], linewidth=4)
plt.plot([0, 1], [0, 1], 'k--', linewidth=4)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('Receiver operating characteristic for high/low income', fontsize=18)
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1c60390d98cb> in <module>()
#       1 """ Check your performance so far."""
#       2
# ----> 3 conmat = np.array(confusion_matrix(Y_test, y_pred, labels=[1,0]))
#       4 confusion = pd.DataFrame(conmat, index=['over_50k', 'under_50k'],
#       5                             columns=['predicted_over50k','predicted_under50k'])
#
# NameError: name 'Y_test' is not defined

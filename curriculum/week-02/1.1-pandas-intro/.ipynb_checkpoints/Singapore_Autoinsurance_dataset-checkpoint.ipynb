# %%
import pandas as pd

# %%
df = pd.read_csv('http://instruction.bus.wisc.edu/jfrees/jfreesbooks/Regression%20Modeling/BookWebDec2010/CSVData/SingaporeAuto.csv')

# %%
df
# Out:
#      SexInsured  Female VehicleType  PC  Clm_Count  Exp_weights  LNWEIGHT  \
# 0             U       0           T   0          0     0.668036 -0.403414
# 1             U       0           T   0          0     0.566735 -0.567863
# 2             U       0           T   0          0     0.503765 -0.685646
# 3             U       0           T   0          0     0.914442 -0.089441
# 4             U       0           T   0          0     0.536619 -0.622467
# 5             U       0           T   0          0     0.752909 -0.283811
# 6             U       0           M   0          0     0.670773 -0.399324
# 7             U       0           M   0          0     0.837782 -0.176997
# 8             U       0           M   0          0     0.167009 -1.789708
# 9             U       0           M   0          0     0.503765 -0.685646
# 10            U       0           M   0          0     0.435318 -0.831678
# 11            U       0           M   0          0     0.605065 -0.502419
# ...

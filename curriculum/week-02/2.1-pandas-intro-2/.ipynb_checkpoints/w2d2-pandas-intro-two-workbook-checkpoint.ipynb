# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Intro to Pandas 2
# Week 2 | Day 2

# %% [markdown]
# ### LEARNING OBJECTIVES
# *After this lesson, you will be able to:*
# - Use the .loc function to slice
# - Set and reset DataFrame Indices
# - Use .isin()
# - Perform boolean indexing on dataframes
# - Perform math functions on pandas Series

# %% [markdown]
# ## Recap of yesterday

# %% [markdown]
# ### Importing pandas:
# ```python
# import pandas as pd
# ```
#
# ### Reading in a csv:
#
# ```python
# df = pd.read_csv()
# ```
#
# ### Viewing the head and tail
#
# ```python
# df.head()
# df.tail()
# ```
#
# ### Viewing the columns and the index
# ```python
# df.columns
# df.index
# ```

# %% [markdown]
# ### Data type info
# ```python
# df.info()
# ```
#
# ### Summary statistics
# ```python
# df.describe()
# df['some_column_name'].max()
# df['some_column_name'].min()
# ```
#
# ### Uniques
# ```python
# df['some_column_name'].nunique()
# df['some_column_name'].unique()
# ```
#
# ### Creating a histogram
# ```python
# df['some_column_name'].hist()
# ```

# %% [markdown]
# ## Slicing with .iloc

# %%
# import pandas
import pandas as pd

# create a dictionary
numbs = {'ones': [1, 2, 3, 4], 'tens': [10, 20, 30, 40], 'hundos': [100, 200, 300, 400]}

# pass dictionary into DataFrame and set the columns to keep the order
df = pd.DataFrame(numbs, columns=['ones', 'tens', 'hundos'])

# %% [markdown]
# ### Slicing with .iloc

# %%
df
# Out:
#    ones  tens  hundos
# 0     1    10     100
# 1     2    20     200
# 2     3    30     300
# 3     4    40     400

# %% [markdown]
# ### How do we get column 1?

# %%
# solution

type(df.iloc[:, 0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### How do we turn it into a DataFrame?

# %%
df.iloc[:, 0:1]

df.iloc[:, 0].to_frame()
# Out:
#    ones
# 0     1
# 1     2
# 2     3
# 3     4

# %% [markdown]
# ## How do we get the first  3 rows and 2 columns?

# %% [markdown]
# ### Notice this is exclusive - we get 0, 1, 2 for rows and 0,1 for columns

# %% [markdown]
# ### One more. How do we get all rows and column 0 and 2?

# %%
df.iloc[:, [0,2]]
# Out:
#    ones  hundos
# 0     1     100
# 1     2     200
# 2     3     300
# 3     4     400

# %% [markdown]
# ### Can we get only columns with an 'o' in them with iloc?

# %%
df.iloc[:, [x for x in df.columns if 'o' in x]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e9cda95aaa47> in <module>()
# ----> 1 df.iloc[:, [x for x in df.columns if 'o' in x]]
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1292
#    1293         if type(key) is tuple:
# -> 1294             return self._getitem_tuple(key)
#    1295         else:
#    1296             return self._getitem_axis(key, axis=0)
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#    1542     def _getitem_tuple(self, tup):
#    1543
# -> 1544         self._has_valid_tuple(tup)
#    1545         try:
#    1546             return self._getitem_lowerdim(tup)
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_tuple(self, key)
#     140             if i >= self.obj.ndim:
#     141                 raise IndexingError('Too many indexers')
# --> 142             if not self._has_valid_type(k, i):
#     143                 raise ValueError("Location based indexing can only have [%s] "
#     144                                  "types" % self._valid_types)
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1512             return self._is_valid_integer(key, axis)
#    1513         elif is_list_like_indexer(key):
# -> 1514             return self._is_valid_list_like(key, axis)
#    1515         return False
#    1516
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _is_valid_list_like(self, key, axis)
#    1535         ax = self.obj._get_axis(axis)
#    1536         l = len(ax)
# -> 1537         if len(arr) and (arr.max() >= l or arr.min() < -l):
#    1538             raise IndexError("positional indexers are out-of-bounds")
#    1539
#
# /Users/ac/anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amax(a, axis, out, keepdims)
#      24 # small reductions
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
#
# TypeError: cannot perform reduce with flexible type

# %% [markdown]
# ## No.

# %% [markdown]
# ## Introducing .loc

# %%
df.loc[:, [x for x in df.columns if 'o' in x]]
# Out:
#    ones  hundos
# 0     1     100
# 1     2     200
# 2     3     300
# 3     4     400

# %% [markdown]
# ### .loc allows us to use combined slicing: numeric and named

# %%
df.loc[:3, ['ones', 'tens']]
# Out:
#    ones  tens
# 0     1    10
# 1     2    20
# 2     3    30
# 3     4    40

# %% [markdown]
# ### Notice that it is inclusive! It includes the last item listed

# %% [markdown]
# ### Notice we can't use the .iloc syntax of all numerics

# %%
df.loc[:2, 1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-dfeb333287c9> in <module>()
# ----> 1 df.loc[:2, 1]
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1292
#    1293         if type(key) is tuple:
# -> 1294             return self._getitem_tuple(key)
#    1295         else:
#    1296             return self._getitem_axis(key, axis=0)
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     782     def _getitem_tuple(self, tup):
#     783         try:
# --> 784             return self._getitem_lowerdim(tup)
#     785         except IndexingError:
#     786             pass
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_lowerdim(self, tup)
#     906         for i, key in enumerate(tup):
#     907             if is_label_like(key) or isinstance(key, tuple):
# --> 908                 section = self._getitem_axis(key, axis=i)
#     909
#     910                 # we have yielded a scalar ?
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1464
#    1465         # fall thru to straight lookup
# -> 1466         self._has_valid_type(key, axis)
#    1467         return self._get_label(key, axis=axis)
#    1468
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1391
#    1392             try:
# -> 1393                 key = self._convert_scalar_indexer(key, axis)
#    1394                 if key not in ax:
#    1395                     error()
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_scalar_indexer(self, key, axis)
#     185         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     186         # a scalar
# --> 187         return ax._convert_scalar_indexer(key, kind=self.name)
#     188
#     189     def _convert_slice_indexer(self, key, axis):
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in _convert_scalar_indexer(self, key, kind)
#    1010             elif kind in ['loc'] and is_integer(key):
#    1011                 if not self.holds_integer():
# -> 1012                     return self._invalid_indexer('label', key)
#    1013
#    1014         return key
#
# /Users/ac/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in _invalid_indexer(self, form, key)
#    1123                         "indexers [{key}] of {kind}".format(
#    1124                             form=form, klass=type(self), key=key,
# -> 1125                             kind=type(key)))
#    1126
#    1127     def get_duplicates(self):
#
# TypeError: cannot do label indexing on <class 'pandas.indexes.base.Index'> with these indexers [1] of <type 'int'>

# %% [markdown]
# ## Let's change the index

# %%
from string import ascii_lowercase

# change the index to be lower case letters
df.index = [x for x in ascii_lowercase[:len(df.index)]]

# %%
df
# Out:
#    ones  tens  hundos
# a     1    10     100
# b     2    20     200
# c     3    30     300
# d     4    40     400

# %% [markdown]
# ## Now we'll use .loc to slice with a named index

# %%
# list of indicies
df.loc[['a','c'], :]
# Out:
#    ones  tens  hundos
# a     1    10     100
# c     3    30     300

# %%
# slicing with named indices
df.loc['b':, :]
# Out:
#    ones  tens  hundos
# b     2    20     200
# c     3    30     300
# d     4    40     400

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
state_df = pd.DataFrame([states.keys(),\
              states.values(),\
              [len(x) for x in states.values()]],\
              index=['abbreviation', 'name', 'name_length']).T

# %% [markdown]
# ## DataFrame of state names

# %%
# we have the index as what currently?
state_df
# Out:
#    abbreviation            name name_length
# 0            WA      Washington          10
# 1            WI       Wisconsin           9
# 2            WV   West Virginia          13
# 3            FL         Florida           7
# 4            WY         Wyoming           7
# 5            NH   New Hampshire          13
# 6            NJ      New Jersey          10
# 7            NM      New Mexico          10
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 10           NE        Nebraska           8
# 11           NY        New York           8
# 12           RI    Rhode Island          12
# 13           NV          Nevada           6
# 14           CO        Colorado           8
# 15           CA      California          10
# 16           GA         Georgia           7
# 17           CT     Connecticut          11
# 18           OK        Oklahoma           8
# 19           OH            Ohio           4
# 20           KS          Kansas           6
# 21           SC  South Carolina          14
# 22           KY        Kentucky           8
# 23           OR          Oregon           6
# 24           SD    South Dakota          12
# 25           DE        Delaware           8
# 26           HI          Hawaii           6
# 27           TX           Texas           5
# 28           LA       Louisiana           9
# 29           TN       Tennessee           9
# 30           PA    Pennsylvania          12
# 31           VA        Virginia           8
# 32           AK          Alaska           6
# 33           AL         Alabama           7
# 34           AR        Arkansas           8
# 35           VT         Vermont           7
# 36           IL        Illinois           8
# 37           IN         Indiana           7
# 38           IA            Iowa           4
# 39           AZ         Arizona           7
# 40           ID           Idaho           5
# 41           ME           Maine           5
# 42           MD        Maryland           8
# 43           MA   Massachusetts          13
# 44           UT            Utah           4
# 45           MO        Missouri           8
# 46           MN       Minnesota           9
# 47           MI        Michigan           8
# 48           MT         Montana           7
# 49           MS     Mississippi          11

# %% [markdown]
# ## Let's change the index

# %% [markdown]
# We have numbers as the index, let's make the index the state's abbreviation

# %%
state_df.set_index('abbreviation')
# Out:
#                         name name_length
# abbreviation
# WA                Washington          10
# WI                 Wisconsin           9
# WV             West Virginia          13
# FL                   Florida           7
# WY                   Wyoming           7
# NH             New Hampshire          13
# NJ                New Jersey          10
# NM                New Mexico          10
# NC            North Carolina          14
# ND              North Dakota          12
# NE                  Nebraska           8
# NY                  New York           8
# RI              Rhode Island          12
# NV                    Nevada           6
# CO                  Colorado           8
# CA                California          10
# GA                   Georgia           7
# CT               Connecticut          11
# OK                  Oklahoma           8
# OH                      Ohio           4
# KS                    Kansas           6
# SC            South Carolina          14
# KY                  Kentucky           8
# OR                    Oregon           6
# SD              South Dakota          12
# DE                  Delaware           8
# HI                    Hawaii           6
# TX                     Texas           5
# LA                 Louisiana           9
# TN                 Tennessee           9
# PA              Pennsylvania          12
# VA                  Virginia           8
# AK                    Alaska           6
# AL                   Alabama           7
# AR                  Arkansas           8
# VT                   Vermont           7
# IL                  Illinois           8
# IN                   Indiana           7
# IA                      Iowa           4
# AZ                   Arizona           7
# ID                     Idaho           5
# ME                     Maine           5
# MD                  Maryland           8
# MA             Massachusetts          13
# UT                      Utah           4
# MO                  Missouri           8
# MN                 Minnesota           9
# MI                  Michigan           8
# MT                   Montana           7
# MS               Mississippi          11

# %% [markdown]
# ## Notice that was just a view, did not change the data

# %%
state_df
# Out:
#    abbreviation            name name_length
# 0            WA      Washington          10
# 1            WI       Wisconsin           9
# 2            WV   West Virginia          13
# 3            FL         Florida           7
# 4            WY         Wyoming           7
# 5            NH   New Hampshire          13
# 6            NJ      New Jersey          10
# 7            NM      New Mexico          10
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 10           NE        Nebraska           8
# 11           NY        New York           8
# 12           RI    Rhode Island          12
# 13           NV          Nevada           6
# 14           CO        Colorado           8
# 15           CA      California          10
# 16           GA         Georgia           7
# 17           CT     Connecticut          11
# 18           OK        Oklahoma           8
# 19           OH            Ohio           4
# 20           KS          Kansas           6
# 21           SC  South Carolina          14
# 22           KY        Kentucky           8
# 23           OR          Oregon           6
# 24           SD    South Dakota          12
# 25           DE        Delaware           8
# 26           HI          Hawaii           6
# 27           TX           Texas           5
# 28           LA       Louisiana           9
# 29           TN       Tennessee           9
# 30           PA    Pennsylvania          12
# 31           VA        Virginia           8
# 32           AK          Alaska           6
# 33           AL         Alabama           7
# 34           AR        Arkansas           8
# 35           VT         Vermont           7
# 36           IL        Illinois           8
# 37           IN         Indiana           7
# 38           IA            Iowa           4
# 39           AZ         Arizona           7
# 40           ID           Idaho           5
# 41           ME           Maine           5
# 42           MD        Maryland           8
# 43           MA   Massachusetts          13
# 44           UT            Utah           4
# 45           MO        Missouri           8
# 46           MN       Minnesota           9
# 47           MI        Michigan           8
# 48           MT         Montana           7
# 49           MS     Mississippi          11

# %% [markdown]
# ## Have to save as a new DataFrame or use inplace=True

# %%
state_df.set_index('abbreviation', inplace=True)

# %% [markdown]
# ## Now we can see the changes 'stuck'

# %%
state_df
# Out:
#                         name name_length
# abbreviation
# WA                Washington          10
# WI                 Wisconsin           9
# WV             West Virginia          13
# FL                   Florida           7
# WY                   Wyoming           7
# NH             New Hampshire          13
# NJ                New Jersey          10
# NM                New Mexico          10
# NC            North Carolina          14
# ND              North Dakota          12
# NE                  Nebraska           8
# NY                  New York           8
# RI              Rhode Island          12
# NV                    Nevada           6
# CO                  Colorado           8
# CA                California          10
# GA                   Georgia           7
# CT               Connecticut          11
# OK                  Oklahoma           8
# OH                      Ohio           4
# KS                    Kansas           6
# SC            South Carolina          14
# KY                  Kentucky           8
# OR                    Oregon           6
# SD              South Dakota          12
# DE                  Delaware           8
# HI                    Hawaii           6
# TX                     Texas           5
# LA                 Louisiana           9
# TN                 Tennessee           9
# PA              Pennsylvania          12
# VA                  Virginia           8
# AK                    Alaska           6
# AL                   Alabama           7
# AR                  Arkansas           8
# VT                   Vermont           7
# IL                  Illinois           8
# IN                   Indiana           7
# IA                      Iowa           4
# AZ                   Arizona           7
# ID                     Idaho           5
# ME                     Maine           5
# MD                  Maryland           8
# MA             Massachusetts          13
# UT                      Utah           4
# MO                  Missouri           8
# MN                 Minnesota           9
# MI                  Michigan           8
# MT                   Montana           7
# MS               Mississippi          11

# %% [markdown]
# ## What if we want to go back?

# %%
state_df
# Out:
#                         name name_length
# abbreviation
# WA                Washington          10
# WI                 Wisconsin           9
# WV             West Virginia          13
# FL                   Florida           7
# WY                   Wyoming           7
# NH             New Hampshire          13
# NJ                New Jersey          10
# NM                New Mexico          10
# NC            North Carolina          14
# ND              North Dakota          12
# NE                  Nebraska           8
# NY                  New York           8
# RI              Rhode Island          12
# NV                    Nevada           6
# CO                  Colorado           8
# CA                California          10
# GA                   Georgia           7
# CT               Connecticut          11
# OK                  Oklahoma           8
# OH                      Ohio           4
# KS                    Kansas           6
# SC            South Carolina          14
# KY                  Kentucky           8
# OR                    Oregon           6
# SD              South Dakota          12
# DE                  Delaware           8
# HI                    Hawaii           6
# TX                     Texas           5
# LA                 Louisiana           9
# TN                 Tennessee           9
# PA              Pennsylvania          12
# VA                  Virginia           8
# AK                    Alaska           6
# AL                   Alabama           7
# AR                  Arkansas           8
# VT                   Vermont           7
# IL                  Illinois           8
# IN                   Indiana           7
# IA                      Iowa           4
# AZ                   Arizona           7
# ID                     Idaho           5
# ME                     Maine           5
# MD                  Maryland           8
# MA             Massachusetts          13
# UT                      Utah           4
# MO                  Missouri           8
# MN                 Minnesota           9
# MI                  Michigan           8
# MT                   Montana           7
# MS               Mississippi          11

# %% [markdown]
# ## Need to reset it!

# %%
state_df.reset_index(inplace=True)

# %%
state_df
# Out:
#    abbreviation            name name_length
# 0            WA      Washington          10
# 1            WI       Wisconsin           9
# 2            WV   West Virginia          13
# 3            FL         Florida           7
# 4            WY         Wyoming           7
# 5            NH   New Hampshire          13
# 6            NJ      New Jersey          10
# 7            NM      New Mexico          10
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 10           NE        Nebraska           8
# 11           NY        New York           8
# 12           RI    Rhode Island          12
# 13           NV          Nevada           6
# 14           CO        Colorado           8
# 15           CA      California          10
# 16           GA         Georgia           7
# 17           CT     Connecticut          11
# 18           OK        Oklahoma           8
# 19           OH            Ohio           4
# 20           KS          Kansas           6
# 21           SC  South Carolina          14
# 22           KY        Kentucky           8
# 23           OR          Oregon           6
# 24           SD    South Dakota          12
# 25           DE        Delaware           8
# 26           HI          Hawaii           6
# 27           TX           Texas           5
# 28           LA       Louisiana           9
# 29           TN       Tennessee           9
# 30           PA    Pennsylvania          12
# 31           VA        Virginia           8
# 32           AK          Alaska           6
# 33           AL         Alabama           7
# 34           AR        Arkansas           8
# 35           VT         Vermont           7
# 36           IL        Illinois           8
# 37           IN         Indiana           7
# 38           IA            Iowa           4
# 39           AZ         Arizona           7
# 40           ID           Idaho           5
# 41           ME           Maine           5
# 42           MD        Maryland           8
# 43           MA   Massachusetts          13
# 44           UT            Utah           4
# 45           MO        Missouri           8
# 46           MN       Minnesota           9
# 47           MI        Michigan           8
# 48           MT         Montana           7
# 49           MS     Mississippi          11

# %% [markdown]
# ## Exercise
#
# Using the states_df:
# - set the index to the state name and save it as new_state
# - use the .loc method to select all the states that begin with the letter 'N'
# - reset the index back to a zero-based index and do so inplace

# %%
state_df.set_index('name', inplace = True)
state_df
# Out:
#                abbreviation name_length
# name
# Washington               WA          10
# Wisconsin                WI           9
# West Virginia            WV          13
# Florida                  FL           7
# Wyoming                  WY           7
# New Hampshire            NH          13
# New Jersey               NJ          10
# New Mexico               NM          10
# North Carolina           NC          14
# North Dakota             ND          12
# Nebraska                 NE           8
# New York                 NY           8
# Rhode Island             RI          12
# Nevada                   NV           6
# Colorado                 CO           8
# California               CA          10
# Georgia                  GA           7
# Connecticut              CT          11
# Oklahoma                 OK           8
# Ohio                     OH           4
# Kansas                   KS           6
# South Carolina           SC          14
# Kentucky                 KY           8
# Oregon                   OR           6
# South Dakota             SD          12
# Delaware                 DE           8
# Hawaii                   HI           6
# Texas                    TX           5
# Louisiana                LA           9
# Tennessee                TN           9
# Pennsylvania             PA          12
# Virginia                 VA           8
# Alaska                   AK           6
# Alabama                  AL           7
# Arkansas                 AR           8
# Vermont                  VT           7
# Illinois                 IL           8
# Indiana                  IN           7
# Iowa                     IA           4
# Arizona                  AZ           7
# Idaho                    ID           5
# Maine                    ME           5
# Maryland                 MD           8
# Massachusetts            MA          13
# Utah                     UT           4
# Missouri                 MO           8
# Minnesota                MN           9
# Michigan                 MI           8
# Montana                  MT           7
# Mississippi              MS          11

# %%
state_df.loc[[x for x in state_df.index if "n" in x or "N" in x],:]
# Out:
#                abbreviation name_length
# name
# Washington               WA          10
# Wisconsin                WI           9
# West Virginia            WV          13
# Wyoming                  WY           7
# New Hampshire            NH          13
# New Jersey               NJ          10
# New Mexico               NM          10
# North Carolina           NC          14
# North Dakota             ND          12
# Nebraska                 NE           8
# New York                 NY           8
# Rhode Island             RI          12
# Nevada                   NV           6
# California               CA          10
# Connecticut              CT          11
# Kansas                   KS           6
# South Carolina           SC          14
# Kentucky                 KY           8
# Oregon                   OR           6
# Louisiana                LA           9
# Tennessee                TN           9
# Pennsylvania             PA          12
# Virginia                 VA           8
# Arkansas                 AR           8
# Vermont                  VT           7
# Illinois                 IL           8
# Indiana                  IN           7
# Arizona                  AZ           7
# Maine                    ME           5
# Maryland                 MD           8
# Minnesota                MN           9
# Michigan                 MI           8
# Montana                  MT           7

# %%
state_df.reset_index(inplace = True)
state_df
# Out:
#               name abbreviation name_length
# 0       Washington           WA          10
# 1        Wisconsin           WI           9
# 2    West Virginia           WV          13
# 3          Florida           FL           7
# 4          Wyoming           WY           7
# 5    New Hampshire           NH          13
# 6       New Jersey           NJ          10
# 7       New Mexico           NM          10
# 8   North Carolina           NC          14
# 9     North Dakota           ND          12
# 10        Nebraska           NE           8
# 11        New York           NY           8
# 12    Rhode Island           RI          12
# 13          Nevada           NV           6
# 14        Colorado           CO           8
# 15      California           CA          10
# 16         Georgia           GA           7
# 17     Connecticut           CT          11
# 18        Oklahoma           OK           8
# 19            Ohio           OH           4
# 20          Kansas           KS           6
# 21  South Carolina           SC          14
# 22        Kentucky           KY           8
# 23          Oregon           OR           6
# 24    South Dakota           SD          12
# 25        Delaware           DE           8
# 26          Hawaii           HI           6
# 27           Texas           TX           5
# 28       Louisiana           LA           9
# 29       Tennessee           TN           9
# 30    Pennsylvania           PA          12
# 31        Virginia           VA           8
# 32          Alaska           AK           6
# 33         Alabama           AL           7
# 34        Arkansas           AR           8
# 35         Vermont           VT           7
# 36        Illinois           IL           8
# 37         Indiana           IN           7
# 38            Iowa           IA           4
# 39         Arizona           AZ           7
# 40           Idaho           ID           5
# 41           Maine           ME           5
# 42        Maryland           MD           8
# 43   Massachusetts           MA          13
# 44            Utah           UT           4
# 45        Missouri           MO           8
# 46       Minnesota           MN           9
# 47        Michigan           MI           8
# 48         Montana           MT           7
# 49     Mississippi           MS          11

# %% [markdown]
# ## Using .isin()

# %%
state_df
# Out:
#    abbreviation            name name_length
# 0            WA      Washington          10
# 1            WI       Wisconsin           9
# 2            WV   West Virginia          13
# 3            FL         Florida           7
# 4            WY         Wyoming           7
# 5            NH   New Hampshire          13
# 6            NJ      New Jersey          10
# 7            NM      New Mexico          10
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 10           NE        Nebraska           8
# 11           NY        New York           8
# 12           RI    Rhode Island          12
# 13           NV          Nevada           6
# 14           CO        Colorado           8
# 15           CA      California          10
# 16           GA         Georgia           7
# 17           CT     Connecticut          11
# 18           OK        Oklahoma           8
# 19           OH            Ohio           4
# 20           KS          Kansas           6
# 21           SC  South Carolina          14
# 22           KY        Kentucky           8
# 23           OR          Oregon           6
# 24           SD    South Dakota          12
# 25           DE        Delaware           8
# 26           HI          Hawaii           6
# 27           TX           Texas           5
# 28           LA       Louisiana           9
# 29           TN       Tennessee           9
# 30           PA    Pennsylvania          12
# 31           VA        Virginia           8
# 32           AK          Alaska           6
# 33           AL         Alabama           7
# 34           AR        Arkansas           8
# 35           VT         Vermont           7
# 36           IL        Illinois           8
# 37           IN         Indiana           7
# 38           IA            Iowa           4
# 39           AZ         Arizona           7
# 40           ID           Idaho           5
# 41           ME           Maine           5
# 42           MD        Maryland           8
# 43           MA   Massachusetts          13
# 44           UT            Utah           4
# 45           MO        Missouri           8
# 46           MN       Minnesota           9
# 47           MI        Michigan           8
# 48           MT         Montana           7
# 49           MS     Mississippi          11

# %% [markdown]
# ## We get a boolean (True/False) Series back

# %%
states_with_direction = ['North Dakota', 'North Carolina',\
                         'South Carolina', 'South Dakota',\
                         'West Virginia']

state_df['name'].isin(states_with_direction)
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: name, dtype: bool

# %% [markdown]
# ## Wrapping that in state_df[ ] gives us only the True rows

# %%
state_df[state_df['name'].isin(states_with_direction)]
# Out:
#    abbreviation            name name_length
# 2            WV   West Virginia          13
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 21           SC  South Carolina          14
# 24           SD    South Dakota          12

# %% [markdown]
# ## Exercise
#
# Using the state_df DataFrame:
# - use .isin() to select only those rows that have a name_length of 10 or 12 characters
# - use another .isin() with a list comprehension to select only the columns that are abbreviated that begin with an 'N' or a 'S'

# %%
state_df[state_df['name_length'].isin([10,12])]
# Out:
#             name abbreviation name_length
# 0     Washington           WA          10
# 6     New Jersey           NJ          10
# 7     New Mexico           NM          10
# 9   North Dakota           ND          12
# 12  Rhode Island           RI          12
# 15    California           CA          10
# 24  South Dakota           SD          12
# 30  Pennsylvania           PA          12

# %%
state_df[state_df['abbreviation'].isin([x for x in state_df['abbreviation'] if x[0] == 'N' or x[0] == 'S'])]
# Out:
#               name abbreviation name_length
# 5    New Hampshire           NH          13
# 6       New Jersey           NJ          10
# 7       New Mexico           NM          10
# 8   North Carolina           NC          14
# 9     North Dakota           ND          12
# 10        Nebraska           NE           8
# 11        New York           NY           8
# 13          Nevada           NV           6
# 21  South Carolina           SC          14
# 24    South Dakota           SD          12

# %% [markdown]
# ## Futher into Boolean indexing

# %%
state_df['name_length'] > 10
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49     True
# Name: name_length, dtype: bool

# %% [markdown]
# ## Again, we can wrap that

# %%
# gives us the only rows that have a length greater than 10
state_df[state_df['name_length']>10]
# Out:
#    abbreviation            name name_length
# 2            WV   West Virginia          13
# 5            NH   New Hampshire          13
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 12           RI    Rhode Island          12
# 17           CT     Connecticut          11
# 21           SC  South Carolina          14
# 24           SD    South Dakota          12
# 30           PA    Pennsylvania          12
# 43           MA   Massachusetts          13
# 49           MS     Mississippi          11

# %% [markdown]
# ## Another example

# %%
state_df[state_df['name'].str.contains('South')]
# Out:
#    abbreviation            name name_length
# 21           SC  South Carolina          14
# 24           SD    South Dakota          12

# %% [markdown]
# ## Let's use an 'and' here to combine requirements

# %%
state_df[(state_df['name_length']>12)\
          &(state_df['name'].str.contains('South'))]
# Out:
#    abbreviation            name name_length
# 21           SC  South Carolina          14

# %% [markdown]
# ## Let's use an 'or' statement

# %%
state_df[(state_df['name'].str.contains('North'))\
          |(state_df['name'].str.contains('South'))]
# Out:
#    abbreviation            name name_length
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 21           SC  South Carolina          14
# 24           SD    South Dakota          12

# %% [markdown]
# ## Exercise
#
# Using the state_df DataFrame:
# - use Boolean indexing to select all states with a y in their name
# - using the same code from the line above add another condition to only return states that have 10 or fewer characters in their name

# %% [markdown]
# ## Math with pandas columns

# %%
state_df
# Out:
#    abbreviation            name name_length
# 0            WA      Washington          10
# 1            WI       Wisconsin           9
# 2            WV   West Virginia          13
# 3            FL         Florida           7
# 4            WY         Wyoming           7
# 5            NH   New Hampshire          13
# 6            NJ      New Jersey          10
# 7            NM      New Mexico          10
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 10           NE        Nebraska           8
# 11           NY        New York           8
# 12           RI    Rhode Island          12
# 13           NV          Nevada           6
# 14           CO        Colorado           8
# 15           CA      California          10
# 16           GA         Georgia           7
# 17           CT     Connecticut          11
# 18           OK        Oklahoma           8
# 19           OH            Ohio           4
# 20           KS          Kansas           6
# 21           SC  South Carolina          14
# 22           KY        Kentucky           8
# 23           OR          Oregon           6
# 24           SD    South Dakota          12
# 25           DE        Delaware           8
# 26           HI          Hawaii           6
# 27           TX           Texas           5
# 28           LA       Louisiana           9
# 29           TN       Tennessee           9
# 30           PA    Pennsylvania          12
# 31           VA        Virginia           8
# 32           AK          Alaska           6
# 33           AL         Alabama           7
# 34           AR        Arkansas           8
# 35           VT         Vermont           7
# 36           IL        Illinois           8
# 37           IN         Indiana           7
# 38           IA            Iowa           4
# 39           AZ         Arizona           7
# 40           ID           Idaho           5
# 41           ME           Maine           5
# 42           MD        Maryland           8
# 43           MA   Massachusetts          13
# 44           UT            Utah           4
# 45           MO        Missouri           8
# 46           MN       Minnesota           9
# 47           MI        Michigan           8
# 48           MT         Montana           7
# 49           MS     Mississippi          11

# %% [markdown]
# ## Let's add a new column that is 100x name_length

# %%
tmp_df = state_df.copy()

tmp_df['name_length_x100'] = tmp_df['name_length'] * 100

tmp_df
# Out:
#    abbreviation            name name_length name_length_x100
# 0            WA      Washington          10             1000
# 1            WI       Wisconsin           9              900
# 2            WV   West Virginia          13             1300
# 3            FL         Florida           7              700
# 4            WY         Wyoming           7              700
# 5            NH   New Hampshire          13             1300
# 6            NJ      New Jersey          10             1000
# 7            NM      New Mexico          10             1000
# 8            NC  North Carolina          14             1400
# 9            ND    North Dakota          12             1200
# 10           NE        Nebraska           8              800
# 11           NY        New York           8              800
# 12           RI    Rhode Island          12             1200
# 13           NV          Nevada           6              600
# 14           CO        Colorado           8              800
# 15           CA      California          10             1000
# 16           GA         Georgia           7              700
# 17           CT     Connecticut          11             1100
# 18           OK        Oklahoma           8              800
# 19           OH            Ohio           4              400
# 20           KS          Kansas           6              600
# 21           SC  South Carolina          14             1400
# 22           KY        Kentucky           8              800
# 23           OR          Oregon           6              600
# 24           SD    South Dakota          12             1200
# 25           DE        Delaware           8              800
# 26           HI          Hawaii           6              600
# 27           TX           Texas           5              500
# 28           LA       Louisiana           9              900
# 29           TN       Tennessee           9              900
# 30           PA    Pennsylvania          12             1200
# 31           VA        Virginia           8              800
# 32           AK          Alaska           6              600
# 33           AL         Alabama           7              700
# 34           AR        Arkansas           8              800
# 35           VT         Vermont           7              700
# 36           IL        Illinois           8              800
# 37           IN         Indiana           7              700
# 38           IA            Iowa           4              400
# 39           AZ         Arizona           7              700
# 40           ID           Idaho           5              500
# 41           ME           Maine           5              500
# 42           MD        Maryland           8              800
# 43           MA   Massachusetts          13             1300
# 44           UT            Utah           4              400
# 45           MO        Missouri           8              800
# 46           MN       Minnesota           9              900
# 47           MI        Michigan           8              800
# 48           MT         Montana           7              700
# 49           MS     Mississippi          11             1100

# %% [markdown]
# ## Let's add two columns together

# %%
tmp_df['name_added_cols'] = tmp_df['name_length'] + tmp_df['name_length_x100']

tmp_df
# Out:
#    abbreviation            name name_length name_length_x100 name_added_cols
# 0            WA      Washington          10             1000            1010
# 1            WI       Wisconsin           9              900             909
# 2            WV   West Virginia          13             1300            1313
# 3            FL         Florida           7              700             707
# 4            WY         Wyoming           7              700             707
# 5            NH   New Hampshire          13             1300            1313
# 6            NJ      New Jersey          10             1000            1010
# 7            NM      New Mexico          10             1000            1010
# 8            NC  North Carolina          14             1400            1414
# 9            ND    North Dakota          12             1200            1212
# 10           NE        Nebraska           8              800             808
# 11           NY        New York           8              800             808
# 12           RI    Rhode Island          12             1200            1212
# 13           NV          Nevada           6              600             606
# 14           CO        Colorado           8              800             808
# 15           CA      California          10             1000            1010
# 16           GA         Georgia           7              700             707
# 17           CT     Connecticut          11             1100            1111
# 18           OK        Oklahoma           8              800             808
# 19           OH            Ohio           4              400             404
# 20           KS          Kansas           6              600             606
# 21           SC  South Carolina          14             1400            1414
# 22           KY        Kentucky           8              800             808
# 23           OR          Oregon           6              600             606
# 24           SD    South Dakota          12             1200            1212
# 25           DE        Delaware           8              800             808
# 26           HI          Hawaii           6              600             606
# 27           TX           Texas           5              500             505
# 28           LA       Louisiana           9              900             909
# 29           TN       Tennessee           9              900             909
# 30           PA    Pennsylvania          12             1200            1212
# 31           VA        Virginia           8              800             808
# 32           AK          Alaska           6              600             606
# 33           AL         Alabama           7              700             707
# 34           AR        Arkansas           8              800             808
# 35           VT         Vermont           7              700             707
# 36           IL        Illinois           8              800             808
# 37           IN         Indiana           7              700             707
# 38           IA            Iowa           4              400             404
# 39           AZ         Arizona           7              700             707
# 40           ID           Idaho           5              500             505
# 41           ME           Maine           5              500             505
# 42           MD        Maryland           8              800             808
# 43           MA   Massachusetts          13             1300            1313
# 44           UT            Utah           4              400             404
# 45           MO        Missouri           8              800             808
# 46           MN       Minnesota           9              900             909
# 47           MI        Michigan           8              800             808
# 48           MT         Montana           7              700             707
# 49           MS     Mississippi          11             1100            1111

# %% [markdown]
# ## Exercise
#
# Using the state_df DataFrame again:
# - Save temp_df as a copy of state_df
# - Double the name_length column by adding it to itself
# - Double the doubled column you created by multiplying it by 2

# %% [markdown]
# ## Conclusion
#
# In this lecture we covered:
# - How to use the .loc function to slice and how it differs from .iloc
# - How to set and reset DataFrame Indices
# - How to use .isin()
# - How to perform boolean indexing on dataframes
# - How to combine conditions using '|' and '&'
# - How to perform math on pandas Series

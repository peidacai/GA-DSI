# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Let's use the Star Wars dataset again. Load it in and pull up the head.
#
# ```../../../1.2-study-design/assets/datasets/StarWars.csv```

# %% [markdown]
# #### Create a hypothesis involving different subsections of the data.
#
# For example:
# - Are respondents more likely to respond "Han" to the question "Who shot first?" if they also say they are fans of Star Trek?
#
# Type your hypothesis in a markdown cell below:

# %% [markdown]
# Use boolean indexing to create subsets of the data to support your hypothesis. See if you can answer questions using mutiple variables.

# %%
sw = pd.read_csv('starwars.csv')
sw
# Out:
#       RespondentID  \
# 0              NaN
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# 6     3.292719e+09
# 7     3.292685e+09
# 8     3.292664e+09
# 9     3.292654e+09
# 10    3.292640e+09
# 11    3.292638e+09
# 12    3.292635e+09
# 13    3.292609e+09
# 14    3.292597e+09
# 15    3.292587e+09
# 16    3.292583e+09
# 17    3.292581e+09
# 18    3.292573e+09
# 19    3.292565e+09
# 20    3.292562e+09
# 21    3.292522e+09
# 22    3.292521e+09
# 23    3.292512e+09
# 24    3.292483e+09
# 25    3.292465e+09
# 26    3.292448e+09
# 27    3.292420e+09
# 28    3.292384e+09
# 29    3.292380e+09
# ...            ...
# 1157  3.288426e+09
# 1158  3.288423e+09
# 1159  3.288423e+09
# 1160  3.288422e+09
# 1161  3.288421e+09
# 1162  3.288418e+09
# 1163  3.288418e+09
# 1164  3.288417e+09
# 1165  3.288415e+09
# 1166  3.288414e+09
# 1167  3.288413e+09
# 1168  3.288410e+09
# 1169  3.288410e+09
# 1170  3.288409e+09
# 1171  3.288403e+09
# ...

# %%
# Create a separate dataframe using only the two features

sw_df = sw.loc[:,['Do you consider yourself to be a fan of the Star Wars film franchise?','Which character shot first?']]
sw_df
# Out:
#      Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                              Response
# 1                                                   Yes
# 2                                                   NaN
# 3                                                    No
# 4                                                   Yes
# 5                                                   Yes
# 6                                                   Yes
# 7                                                   Yes
# 8                                                   Yes
# 9                                                   Yes
# 10                                                   No
# 11                                                  NaN
# 12                                                  NaN
# 13                                                   No
# 14                                                  Yes
# ...

# %%
# Renaming the columns

new_col = ['fan', 'shot']
sw_df.columns = new_col
sw_df
# Out:
#            fan                              shot
# 0     Response                          Response
# 1          Yes  I don't understand this question
# 2          NaN                               NaN
# 3           No  I don't understand this question
# 4          Yes  I don't understand this question
# 5          Yes                            Greedo
# 6          Yes                               Han
# 7          Yes                               Han
# 8          Yes                               Han
# 9          Yes                               Han
# 10          No  I don't understand this question
# 11         NaN                               NaN
# 12         NaN                               NaN
# 13          No                            Greedo
# 14         Yes  I don't understand this question
# 15         Yes                               Han
# 16         Yes                               Han
# 17         Yes                               Han
# ...

# %%
# Drop all rows with "NaN" inputs

sw_df.dropna(inplace = True)
sw_df
# Out:
#            fan                              shot
# 0     Response                          Response
# 1          Yes  I don't understand this question
# 3           No  I don't understand this question
# 4          Yes  I don't understand this question
# 5          Yes                            Greedo
# 6          Yes                               Han
# 7          Yes                               Han
# 8          Yes                               Han
# 9          Yes                               Han
# 10          No  I don't understand this question
# 13          No                            Greedo
# 14         Yes  I don't understand this question
# 15         Yes                               Han
# 16         Yes                               Han
# 17         Yes                               Han
# 18         Yes                            Greedo
# 19         Yes                               Han
# 20         Yes                            Greedo
# ...

# %%
sw_df['fan'].value_counts()
# Out:
# Yes         545
# No          283
# Response      1
# Name: fan, dtype: int64

# %%
sw_df['shot'].value_counts()
# Out:
# Han                                 325
# I don't understand this question    306
# Greedo                              197
# Response                              1
# Name: shot, dtype: int64

# %%
sw_df = sw_df.iloc[1:,:]

# %%
sw_df
# Out:
#       fan                              shot
# 1     Yes  I don't understand this question
# 3      No  I don't understand this question
# 4     Yes  I don't understand this question
# 5     Yes                            Greedo
# 6     Yes                               Han
# 7     Yes                               Han
# 8     Yes                               Han
# 9     Yes                               Han
# 10     No  I don't understand this question
# 13     No                            Greedo
# 14    Yes  I don't understand this question
# 15    Yes                               Han
# 16    Yes                               Han
# 17    Yes                               Han
# 18    Yes                            Greedo
# 19    Yes                               Han
# 20    Yes                            Greedo
# 21    Yes                               Han
# 22     No  I don't understand this question
# 23    Yes                            Greedo
# ...

# %% [markdown]
# ### Test hypotheses
#
# H0: P(H|SWF)- P(H|Not_SWF) <= 0
#
# H1: P(H|SWF) -P(H|Not_SWF) > 0

# %%
# %matplotlib inline
import seaborn as sns

# %%
df = pd.DataFrame(sw_df.groupby(['fan'])['shot'].value_counts())
df
# Out:
#                                       shot
# fan shot
# No  I don't understand this question   180
#     Han                                 57
#     Greedo                              46
# Yes Han                                268
#     Greedo                             151
#     I don't understand this question   126

# %%
ax1 = sw_df['fan'].value_counts()
ax2 = sw_df['shot'].value_counts()

# %%
ax1.plot(kind = 'barh')

# %%
ax2.plot(kind = 'barh')

# %%
sns.set_style("whitegrid")
ax = sns.barplot(x=sw_df["fan"], y=sw_df["shot"], data=sw_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-b47daba2096c> in <module>()
#       1 sns.set_style("whitegrid")
# ----> 2 ax = sns.barplot(x=sw_df["fan"], y=sw_df["shot"], data=sw_df)
#
# //anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, ax, **kwargs)
#    2897                           estimator, ci, n_boot, units,
#    2898                           orient, color, palette, saturation,
# -> 2899                           errcolor, errwidth, capsize)
#    2900
#    2901     if ax is None:
#
# //anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize)
# ...

# %%
sw_df.groupby(['fan'])['shot'].count()
# Out:
# fan
# No     283
# Yes    545
# Name: shot, dtype: int64

# %%
p_h_swf =

# %% [markdown]
# **Bonus** : Use matplotlib or seaborn to present your findings.

# %% [markdown]
# **Bonus 2** : Create another, more complex hypothesis, support it, and plot it below.
